# %%
import requests
import pprint
from bs4 import BeautifulSoup

# %%
# https://www.digitalocean.com/community/tutorials/how-to-work-with-web-data-using-requests-and-beautiful-soup-with-python-3

url = 'https://weather.com/weather/tenday/l/BRSP3446:1:BR'
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text, 'html.parser')

data = []
table = soup.find('table', attrs={'class':'twc-table'})
print(table.prettify())
# Out:
# <table class="twc-table" classname="twc-table">
#  <thead>
#   <tr>
#    <th class="twc-sticky-col" classname=" twc-sticky-col" id="day">
#     Day
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </th>
#    <th class="description" classname="description" id="description">
#     Description
#    </th>
#    <th class="temp" classname="temp" id="hi-lo">
#     High / Low
#    </th>
#    <th class="precip" classname="precip" id="precip">
#     Precip
#    </th>
#    <th class="wind" classname="wind" id="wind">
#     Wind
#    </th>
#    <th class="humidity" classname="humidity" id="humidity">
#     Humidity
#    </th>
#   </tr>
#  </thead>
#  <tbody>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="Rain showers this evening with mostly clear conditions overnight. Low 61F. Winds ENE at 5 to 10 mph. Chance of rain 50%.">
#     <div>
#      <div>
#       <span class="date-time">
#        Tonight
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-scattered-showers-night icon-45" classname="icon icon-svg icon-svg-dark icon-scattered-showers-night icon-45">
#        <svg class="svg-scattered-showers-night svg-night" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <defs>
#          <mask id="scattered-showers-night-mask">
#           <rect fill="#FFF" height="100%" width="100%">
#           </rect>
#           <use stroke="#000" stroke-linejoin="round" stroke-width="10" transform="matrix(.91 0 0 .91 6 46)" xlink:href="#svg-symbol-moon">
#           </use>
#          </mask>
#         </defs>
#         <use class="svg-drop" transform="matrix(1.7 0 0 2 -13 -120)" xlink:href="#svg-symbol-drop">
#         </use>
#         <use class="svg-drop" transform="translate(16)" xlink:href="#svg-symbol-drop">
#         </use>
#         <use class="svg-cloud" mask="url(#scattered-showers-night-mask)" stroke-width="5.7" transform="matrix(.96 0 0 .96 3 -33)" xlink:href="#svg-symbol-cloud">
#         </use>
#         <use class="svg-moon" stroke-linejoin="round" stroke-width="6" transform="matrix(.87 0 0 .87 8.7 11.31)" xlink:href="#svg-symbol-moon">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       JUN 1
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="Rain showers this evening with mostly clear conditions overnight. Low 61F. Winds ENE at 5 to 10 mph. Chance of rain 50%.">
#     <span>
#      Showers Early
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="Rain showers this evening with mostly clear conditions overnight. Low 61F. Winds ENE at 5 to 10 mph. Chance of rain 50%.">
#     <div>
#      <span>
#       --
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       61
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="Rain showers this evening with mostly clear conditions overnight. Low 61F. Winds ENE at 5 to 10 mph. Chance of rain 50%.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        50
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="Rain showers this evening with mostly clear conditions overnight. Low 61F. Winds ENE at 5 to 10 mph. Chance of rain 50%.">
#     <span class="">
#      ENE 6 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="Rain showers this evening with mostly clear conditions overnight. Low 61F. Winds ENE at 5 to 10 mph. Chance of rain 50%.">
#     <span class="">
#      <span>
#       78
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="Mostly sunny in the morning with isolated thunderstorms developing later in the day. High 84F. Winds NW at 5 to 10 mph. Chance of rain 30%.">
#     <div>
#      <div>
#       <span class="date-time">
#        Sun
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-isolated-thunderstorms icon-37" classname="icon icon-svg icon-svg-dark icon-isolated-thunderstorms icon-37">
#        <svg class="svg-isolated-thunderstorms" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <defs>
#          <mask id="isolated-thunderstorms-mask">
#           <g>
#            <rect fill="#FFF" height="100%" width="100%">
#            </rect>
#            <path d="M143 42h52v120h-52z" stroke="#fff" xmlns="http://www.w3.org/2000/svg">
#            </path>
#            <path d="M116 143h40v50h-40z" stroke="#fff" xmlns="http://www.w3.org/2000/svg">
#            </path>
#            <use stroke="#000" stroke-width="3" transform="matrix(.65 0 0 .65 83.2 20.15)" xlink:href="#svg-symbol-cloud">
#            </use>
#           </g>
#          </mask>
#         </defs>
#         <use class="svg-sun" mask="url(#isolated-thunderstorms-mask)" transform="matrix(.86 0 0 .86 8.6 13.76)" xlink:href="#svg-symbol-sun">
#         </use>
#         <use class="svg-lightning" transform="matrix(.66 0 0 .66 102 42)" xlink:href="#svg-symbol-lightning-bolt">
#         </use>
#         <use class="svg-drop" transform="translate(95 26)" xlink:href="#svg-symbol-drop">
#         </use>
#         <use class="svg-cloud" transform="matrix(.5 0 0 .5 86 38.5)" xlink:href="#svg-symbol-cloud">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       JUN 2
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="Mostly sunny in the morning with isolated thunderstorms developing later in the day. High 84F. Winds NW at 5 to 10 mph. Chance of rain 30%.">
#     <span>
#      Isolated Thunderstorms
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="Mostly sunny in the morning with isolated thunderstorms developing later in the day. High 84F. Winds NW at 5 to 10 mph. Chance of rain 30%.">
#     <div>
#      <span class="">
#       84
#       <sup>
#        °
#       </sup>
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       60
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="Mostly sunny in the morning with isolated thunderstorms developing later in the day. High 84F. Winds NW at 5 to 10 mph. Chance of rain 30%.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        30
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="Mostly sunny in the morning with isolated thunderstorms developing later in the day. High 84F. Winds NW at 5 to 10 mph. Chance of rain 30%.">
#     <span class="">
#      NW 8 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="Mostly sunny in the morning with isolated thunderstorms developing later in the day. High 84F. Winds NW at 5 to 10 mph. Chance of rain 30%.">
#     <span class="">
#      <span>
#       56
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="Rain early...then remaining cloudy with showers in the afternoon. High 73F. Winds S at 5 to 10 mph. Chance of rain 60%.">
#     <div>
#      <div>
#       <span class="date-time">
#        Mon
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-rain icon-12" classname="icon icon-svg icon-svg-dark icon-rain icon-12">
#        <svg class="svg-rain" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use class="svg-cloud" transform="translate(0 -41)" xlink:href="#svg-symbol-cloud">
#         </use>
#         <use class="svg-drop" xlink:href="#svg-symbol-drop">
#         </use>
#         <use class="svg-drop" transform="matrix(1.7 0 0 2 -27 -120)" xlink:href="#svg-symbol-drop">
#         </use>
#         <use class="svg-drop" transform="translate(60)" xlink:href="#svg-symbol-drop">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       JUN 3
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="Rain early...then remaining cloudy with showers in the afternoon. High 73F. Winds S at 5 to 10 mph. Chance of rain 60%.">
#     <span>
#      Rain
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="Rain early...then remaining cloudy with showers in the afternoon. High 73F. Winds S at 5 to 10 mph. Chance of rain 60%.">
#     <div>
#      <span class="">
#       73
#       <sup>
#        °
#       </sup>
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       55
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="Rain early...then remaining cloudy with showers in the afternoon. High 73F. Winds S at 5 to 10 mph. Chance of rain 60%.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        60
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="Rain early...then remaining cloudy with showers in the afternoon. High 73F. Winds S at 5 to 10 mph. Chance of rain 60%.">
#     <span class="">
#      S 7 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="Rain early...then remaining cloudy with showers in the afternoon. High 73F. Winds S at 5 to 10 mph. Chance of rain 60%.">
#     <span class="">
#      <span>
#       76
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="Partly cloudy skies. High near 75F. Winds SSE at 10 to 15 mph.">
#     <div>
#      <div>
#       <span class="date-time">
#        Tue
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-partly-cloudy icon-30" classname="icon icon-svg icon-svg-dark icon-partly-cloudy icon-30">
#        <svg class="svg-partly-cloudy" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <defs>
#          <mask id="partly-cloudy-mask">
#           <rect fill="#FFF" height="100%" width="100%">
#           </rect>
#           <use stroke="#000" stroke-width="13" transform="translate(3.571 -44.642) scale(1.7857)" xlink:href="#svg-symbol-cloud">
#           </use>
#          </mask>
#         </defs>
#         <use class="svg-sun" mask="url(#partly-cloudy-mask)" transform="matrix(.56 0 0 .56 0 16.8)" xlink:href="#svg-symbol-sun">
#         </use>
#         <use class="svg-cloud" transform="translate(0 -10)" xlink:href="#svg-symbol-cloud">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       JUN 4
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="Partly cloudy skies. High near 75F. Winds SSE at 10 to 15 mph.">
#     <span>
#      Partly Cloudy
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="Partly cloudy skies. High near 75F. Winds SSE at 10 to 15 mph.">
#     <div>
#      <span class="">
#       75
#       <sup>
#        °
#       </sup>
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       51
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="Partly cloudy skies. High near 75F. Winds SSE at 10 to 15 mph.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        10
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="Partly cloudy skies. High near 75F. Winds SSE at 10 to 15 mph.">
#     <span class="">
#      SSE 11 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="Partly cloudy skies. High near 75F. Winds SSE at 10 to 15 mph.">
#     <span class="">
#      <span>
#       60
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="Mainly sunny. High 74F. Winds ESE at 10 to 15 mph.">
#     <div>
#      <div>
#       <span class="date-time">
#        Wed
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-sunny icon-32" classname="icon icon-svg icon-svg-dark icon-sunny icon-32">
#        <svg class="svg-sunny" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use class="svg-sun" xlink:href="#svg-symbol-sun">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       JUN 5
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="Mainly sunny. High 74F. Winds ESE at 10 to 15 mph.">
#     <span>
#      Sunny
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="Mainly sunny. High 74F. Winds ESE at 10 to 15 mph.">
#     <div>
#      <span class="">
#       74
#       <sup>
#        °
#       </sup>
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       51
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="Mainly sunny. High 74F. Winds ESE at 10 to 15 mph.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        10
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="Mainly sunny. High 74F. Winds ESE at 10 to 15 mph.">
#     <span class="">
#      ESE 10 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="Mainly sunny. High 74F. Winds ESE at 10 to 15 mph.">
#     <span class="">
#      <span>
#       55
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="A mainly sunny sky. High 76F. Winds E at 5 to 10 mph.">
#     <div>
#      <div>
#       <span class="date-time">
#        Thu
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-sunny icon-32" classname="icon icon-svg icon-svg-dark icon-sunny icon-32">
#        <svg class="svg-sunny" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use class="svg-sun" xlink:href="#svg-symbol-sun">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       JUN 6
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="A mainly sunny sky. High 76F. Winds E at 5 to 10 mph.">
#     <span>
#      Sunny
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="A mainly sunny sky. High 76F. Winds E at 5 to 10 mph.">
#     <div>
#      <span class="">
#       76
#       <sup>
#        °
#       </sup>
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       52
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="A mainly sunny sky. High 76F. Winds E at 5 to 10 mph.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        10
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="A mainly sunny sky. High 76F. Winds E at 5 to 10 mph.">
#     <span class="">
#      E 9 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="A mainly sunny sky. High 76F. Winds E at 5 to 10 mph.">
#     <span class="">
#      <span>
#       53
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="Sunny skies. High 79F. Winds NE at 5 to 10 mph.">
#     <div>
#      <div>
#       <span class="date-time">
#        Fri
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-sunny icon-32" classname="icon icon-svg icon-svg-dark icon-sunny icon-32">
#        <svg class="svg-sunny" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use class="svg-sun" xlink:href="#svg-symbol-sun">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       JUN 7
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="Sunny skies. High 79F. Winds NE at 5 to 10 mph.">
#     <span>
#      Sunny
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="Sunny skies. High 79F. Winds NE at 5 to 10 mph.">
#     <div>
#      <span class="">
#       79
#       <sup>
#        °
#       </sup>
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       53
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="Sunny skies. High 79F. Winds NE at 5 to 10 mph.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        10
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="Sunny skies. High 79F. Winds NE at 5 to 10 mph.">
#     <span class="">
#      NE 7 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="Sunny skies. High 79F. Winds NE at 5 to 10 mph.">
#     <span class="">
#      <span>
#       52
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="Sunny. High around 80F. Winds light and variable.">
#     <div>
#      <div>
#       <span class="date-time">
#        Sat
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-sunny icon-32" classname="icon icon-svg icon-svg-dark icon-sunny icon-32">
#        <svg class="svg-sunny" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use class="svg-sun" xlink:href="#svg-symbol-sun">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       JUN 8
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="Sunny. High around 80F. Winds light and variable.">
#     <span>
#      Sunny
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="Sunny. High around 80F. Winds light and variable.">
#     <div>
#      <span class="">
#       80
#       <sup>
#        °
#       </sup>
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       54
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="Sunny. High around 80F. Winds light and variable.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        0
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="Sunny. High around 80F. Winds light and variable.">
#     <span class="">
#      ENE 4 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="Sunny. High around 80F. Winds light and variable.">
#     <span class="">
#      <span>
#       49
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="Sunny. High around 80F. Winds ESE at 5 to 10 mph.">
#     <div>
#      <div>
#       <span class="date-time">
#        Sun
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-sunny icon-32" classname="icon icon-svg icon-svg-dark icon-sunny icon-32">
#        <svg class="svg-sunny" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use class="svg-sun" xlink:href="#svg-symbol-sun">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       JUN 9
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="Sunny. High around 80F. Winds ESE at 5 to 10 mph.">
#     <span>
#      Sunny
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="Sunny. High around 80F. Winds ESE at 5 to 10 mph.">
#     <div>
#      <span class="">
#       80
#       <sup>
#        °
#       </sup>
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       54
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="Sunny. High around 80F. Winds ESE at 5 to 10 mph.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        0
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="Sunny. High around 80F. Winds ESE at 5 to 10 mph.">
#     <span class="">
#      ESE 6 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="Sunny. High around 80F. Winds ESE at 5 to 10 mph.">
#     <span class="">
#      <span>
#       49
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="Sunny. High near 80F. Winds E at 5 to 10 mph.">
#     <div>
#      <div>
#       <span class="date-time">
#        Mon
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-sunny icon-32" classname="icon icon-svg icon-svg-dark icon-sunny icon-32">
#        <svg class="svg-sunny" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use class="svg-sun" xlink:href="#svg-symbol-sun">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       JUN 10
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="Sunny. High near 80F. Winds E at 5 to 10 mph.">
#     <span>
#      Sunny
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="Sunny. High near 80F. Winds E at 5 to 10 mph.">
#     <div>
#      <span class="">
#       80
#       <sup>
#        °
#       </sup>
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       54
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="Sunny. High near 80F. Winds E at 5 to 10 mph.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        10
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="Sunny. High near 80F. Winds E at 5 to 10 mph.">
#     <span class="">
#      E 7 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="Sunny. High near 80F. Winds E at 5 to 10 mph.">
#     <span class="">
#      <span>
#       53
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="A mainly sunny sky. High 81F. Winds ENE at 5 to 10 mph.">
#     <div>
#      <div>
#       <span class="date-time">
#        Tue
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-sunny icon-32" classname="icon icon-svg icon-svg-dark icon-sunny icon-32">
#        <svg class="svg-sunny" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use class="svg-sun" xlink:href="#svg-symbol-sun">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       JUN 11
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="A mainly sunny sky. High 81F. Winds ENE at 5 to 10 mph.">
#     <span>
#      Sunny
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="A mainly sunny sky. High 81F. Winds ENE at 5 to 10 mph.">
#     <div>
#      <span class="">
#       81
#       <sup>
#        °
#       </sup>
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       55
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="A mainly sunny sky. High 81F. Winds ENE at 5 to 10 mph.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        10
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="A mainly sunny sky. High 81F. Winds ENE at 5 to 10 mph.">
#     <span class="">
#      ENE 7 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="A mainly sunny sky. High 81F. Winds ENE at 5 to 10 mph.">
#     <span class="">
#      <span>
#       52
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="A mainly sunny sky. High 81F. Winds NE at 5 to 10 mph.">
#     <div>
#      <div>
#       <span class="date-time">
#        Wed
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-sunny icon-32" classname="icon icon-svg icon-svg-dark icon-sunny icon-32">
#        <svg class="svg-sunny" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use class="svg-sun" xlink:href="#svg-symbol-sun">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       JUN 12
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="A mainly sunny sky. High 81F. Winds NE at 5 to 10 mph.">
#     <span>
#      Sunny
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="A mainly sunny sky. High 81F. Winds NE at 5 to 10 mph.">
#     <div>
#      <span class="">
#       81
#       <sup>
#        °
#       </sup>
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       57
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="A mainly sunny sky. High 81F. Winds NE at 5 to 10 mph.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        10
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="A mainly sunny sky. High 81F. Winds NE at 5 to 10 mph.">
#     <span class="">
#      NE 7 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="A mainly sunny sky. High 81F. Winds NE at 5 to 10 mph.">
#     <span class="">
#      <span>
#       51
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="Mainly sunny. High 83F. Winds NE at 5 to 10 mph.">
#     <div>
#      <div>
#       <span class="date-time">
#        Thu
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-sunny icon-32" classname="icon icon-svg icon-svg-dark icon-sunny icon-32">
#        <svg class="svg-sunny" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use class="svg-sun" xlink:href="#svg-symbol-sun">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       JUN 13
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="Mainly sunny. High 83F. Winds NE at 5 to 10 mph.">
#     <span>
#      Sunny
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="Mainly sunny. High 83F. Winds NE at 5 to 10 mph.">
#     <div>
#      <span class="">
#       83
#       <sup>
#        °
#       </sup>
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       58
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="Mainly sunny. High 83F. Winds NE at 5 to 10 mph.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        10
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="Mainly sunny. High 83F. Winds NE at 5 to 10 mph.">
#     <span class="">
#      NE 7 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="Mainly sunny. High 83F. Winds NE at 5 to 10 mph.">
#     <span class="">
#      <span>
#       51
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="Sunny skies. High 83F. Winds NE at 5 to 10 mph.">
#     <div>
#      <div>
#       <span class="date-time">
#        Fri
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-sunny icon-32" classname="icon icon-svg icon-svg-dark icon-sunny icon-32">
#        <svg class="svg-sunny" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use class="svg-sun" xlink:href="#svg-symbol-sun">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       JUN 14
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="Sunny skies. High 83F. Winds NE at 5 to 10 mph.">
#     <span>
#      Sunny
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="Sunny skies. High 83F. Winds NE at 5 to 10 mph.">
#     <div>
#      <span class="">
#       83
#       <sup>
#        °
#       </sup>
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       59
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="Sunny skies. High 83F. Winds NE at 5 to 10 mph.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        10
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="Sunny skies. High 83F. Winds NE at 5 to 10 mph.">
#     <span class="">
#      NE 7 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="Sunny skies. High 83F. Winds NE at 5 to 10 mph.">
#     <span class="">
#      <span>
#       52
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="A mainly sunny sky. High 84F. Winds NNE at 5 to 10 mph.">
#     <div>
#      <div>
#       <span class="date-time">
#        Sat
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-sunny icon-32" classname="icon icon-svg icon-svg-dark icon-sunny icon-32">
#        <svg class="svg-sunny" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use class="svg-sun" xlink:href="#svg-symbol-sun">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       JUN 15
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="A mainly sunny sky. High 84F. Winds NNE at 5 to 10 mph.">
#     <span>
#      Sunny
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="A mainly sunny sky. High 84F. Winds NNE at 5 to 10 mph.">
#     <div>
#      <span class="">
#       84
#       <sup>
#        °
#       </sup>
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       59
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="A mainly sunny sky. High 84F. Winds NNE at 5 to 10 mph.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        10
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="A mainly sunny sky. High 84F. Winds NNE at 5 to 10 mph.">
#     <span class="">
#      NNE 7 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="A mainly sunny sky. High 84F. Winds NNE at 5 to 10 mph.">
#     <span class="">
#      <span>
#       53
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#  </tbody>
# </table>

# %%
table_body = table.find('tbody')

rows = table_body.find_all('tr')
for row in rows:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    data.append([ele for ele in cols if ele])

# %%
print(data)
# Out:
# [['Tonight\nJUN 1', 'Showers Early', '--61°', '50%', 'ENE 6 mph', '78%'], ['Sun\nJUN 2', 'Isolated Thunderstorms', '84°60°', '30%', 'NW 8 mph', '56%'], ['MonJUN 3', 'Rain', '73°55°', '60%', 'S 7 mph', '76%'], ['Tue\nJUN 4', 'Partly Cloudy', '75°51°', '10%', 'SSE 11 mph', '60%'], ['WedJUN 5', 'Sunny', '74°51°', '10%', 'ESE 10 mph', '55%'], ['ThuJUN 6', 'Sunny', '76°52°', '10%', 'E 9 mph', '53%'], ['FriJUN 7', 'Sunny', '79°53°', '10%', 'NE 7 mph', '52%'], ['SatJUN 8', 'Sunny', '80°54°', '0%', 'ENE 4 mph', '49%'], ['SunJUN 9', 'Sunny', '80°54°', '0%', 'ESE 6 mph', '49%'], ['MonJUN 10', 'Sunny', '80°54°', '10%', 'E 7 mph', '53%'], ['TueJUN 11', 'Sunny', '81°55°', '10%', 'ENE 7 mph', '52%'], ['WedJUN 12', 'Sunny', '81°57°', '10%', 'NE 7 mph', '51%'], ['ThuJUN 13', 'Sunny', '83°58°', '10%', 'NE 7 mph', '51%'], ['FriJUN 14', 'Sunny', '83°59°', '10%', 'NE 7 mph', '52%'], ['SatJUN 15', 'Sunny', '84°59°', '10%', 'NNE 7 mph', '53%']]
