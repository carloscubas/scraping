# %%
import requests
import pprint
from bs4 import BeautifulSoup
import re
import logging
import json
from time import sleep

# %%
url = 'https://guiadacozinha.com.br/torta-de-batata-e-estrogonofe/'
page = requests.get(url)

# %%
print(page.text)
# Out:
# <!doctype html>
# <html lang="pt-BR" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
# <head>
# 	<meta charset="UTF-8">
# 	<meta name="viewport" content="width=device-width, initial-scale=1">
# 	<link rel="profile" href="https://gmpg.org/xfn/11">
#
#   <!-- DFP -->
#   <!-- Start GPT Async Tag -->
#   <script async='async' src='https://www.googletagservices.com/tag/js/gpt.js'></script>
#   <script>
#   var gptadslots = [];
#   var googletag = googletag || {cmd:[]};
#   </script>
#   <script>
#   googletag.cmd.push(function() {
#
#     gptadslots.push(googletag.defineSlot('/1694668/guiadacozinha1', [[970, 250], [970, 90], [728, 90]], 'div-gpt-ad-1550090883521-0')
#                              .addService(googletag.pubads()
#                              .setTargeting("pageCategories","Jantar prático")
#                              .setTargeting("pageTags","Array")
#                              .setTargeting("pageType","single")
#                              .setTargeting("urlPath","https://guiadacozinha.com.br/torta-de-batata-e-estrogonofe/")
#                              ));
#     gptadslots.push(googletag.defineSlot('/1694668/guiadacozinha2', [[300, 600], [160, 600], [300, 250]], 'div-gpt-ad-1550090971441-0')
#                              .addService(googletag.pubads()
#                              .setTargeting("pageCategories","Jantar prático")
#                              .setTargeting("pageTags","Array")
#                              .setTargeting("pageType","single")
#                              .setTargeting("urlPath","https://guiadacozinha.com.br/torta-de-batata-e-estrogonofe/")
#                              ));
#    gptadslots.push(googletag.defineSlot('/1694668/guiadacozinha3', [[160, 600], [300, 250], [300, 600]], 'div-gpt-ad-1550091036448-0')
#                             .addService(googletag.pubads()
#                             .setTargeting("pageCategories","Jantar prático")
#                             .setTargeting("pageTags","Array")
#                             .setTargeting("pageType","single")
#                             .setTargeting("urlPath","https://guiadacozinha.com.br/torta-de-batata-e-estrogonofe/")
#                             ));
#   gptadslots.push(googletag.defineSlot('/1694668/guiadacozinha12', [[320, 50], [300, 100], [300, 50]], 'div-gpt-ad-1550143022858-0')
#                            .addService(googletag.pubads()
#                            .setTargeting("pageCategories","Jantar prático")
#                            .setTargeting("pageTags","Array")
#                            .setTargeting("pageType","single")
#                            .setTargeting("urlPath","https://guiadacozinha.com.br/torta-de-batata-e-estrogonofe/")
#                            ));
#   gptadslots.push(googletag.defineSlot('/1694668/guiadacozinha13', [300, 250], 'div-gpt-ad-1550143083887-0')
#                           .addService(googletag.pubads()
#                           .setTargeting("pageCategories","Jantar prático")
#                           .setTargeting("pageTags","Array")
#                           .setTargeting("pageType","single")
#                           .setTargeting("urlPath","https://guiadacozinha.com.br/torta-de-batata-e-estrogonofe/")
#                           ));
#
#   gptadslots.push(googletag.defineSlot('/1694668/guiadacozinha14', [300, 250], 'div-gpt-ad-1550143151735-0')
#                       .addService(googletag.pubads()
#                       .setTargeting("pageCategories","Jantar prático")
#                       .setTargeting("pageTags","Array")
#                       .setTargeting("pageType","single")
#                       .setTargeting("urlPath","https://guiadacozinha.com.br/torta-de-batata-e-estrogonofe/")
#                       ));
#
#    gptadslots.push(googletag.defineSlot('/1694668/guiadacozinha15', [300, 250], 'div-gpt-ad-1550143230089-0')
#                       .addService(googletag.pubads()
#                       .setTargeting("pageCategories","Jantar prático")
#                       .setTargeting("pageTags","Array")
#                       .setTargeting("pageType","single")
#                       .setTargeting("urlPath","https://guiadacozinha.com.br/torta-de-batata-e-estrogonofe/")
#                       ));
#   gptadslots.push(googletag.defineSlot('/1694668/guiadacozinha4', [[728, 90], [970, 90], [970, 250]], 'div-gpt-ad-1550091192975-0')
#                      .addService(googletag.pubads()
#                      .setTargeting("pageCategories","Jantar prático")
#                      .setTargeting("pageTags","Array")
#                      .setTargeting("pageType","single")
#                      .setTargeting("urlPath","https://guiadacozinha.com.br/torta-de-batata-e-estrogonofe/")
#                      ));
#
#   gptadslots.push(googletag.defineSlot('/1694668/guiadacozinha5', [[160, 600], [300, 600], [300, 250]], 'div-gpt-ad-1550091378670-0')
#                     .addService(googletag.pubads()
#                     .setTargeting("pageCategories","Jantar prático")
#                     .setTargeting("pageTags","Array")
#                     .setTargeting("pageType","single")
#                     .setTargeting("urlPath","https://guiadacozinha.com.br/torta-de-batata-e-estrogonofe/")
#                     ));
#   gptadslots.push(googletag.defineSlot('/1694668/guiadacozinha6', [[300, 600], [160, 600], [300, 250]], 'div-gpt-ad-1550091457862-0')
#                     .addService(googletag.pubads()
#                     .setTargeting("pageCategories","Jantar prático")
#                     .setTargeting("pageTags","Array")
#                     .setTargeting("pageType","single")
#                     .setTargeting("urlPath","https://guiadacozinha.com.br/torta-de-batata-e-estrogonofe/")
#                     ));
#
#   gptadslots.push(googletag.defineSlot('/1694668/guiadacozinha16', [[300, 50], [320, 50], [300, 100]], 'div-gpt-ad-1550150401899-0')
#                     .addService(googletag.pubads()
#                     .setTargeting("pageCategories","Jantar prático")
#                     .setTargeting("pageTags","Array")
#                     .setTargeting("pageType","single")
#                     .setTargeting("urlPath","https://guiadacozinha.com.br/torta-de-batata-e-estrogonofe/")
#                     ));
#   gptadslots.push(googletag.defineSlot('/1694668/guiadacozinha17', [300, 250], 'div-gpt-ad-1550150608369-0')
#                     .addService(googletag.pubads()
#                     .setTargeting("pageCategories","Jantar prático")
#                     .setTargeting("pageTags","Array")
#                     .setTargeting("pageType","single")
#                     .setTargeting("urlPath","https://guiadacozinha.com.br/torta-de-batata-e-estrogonofe/")
#                     ));
#   gptadslots.push(googletag.defineSlot('/1694668/guiadacozinha18', [300, 250], 'div-gpt-ad-1550150688932-0')
#                     .addService(googletag.pubads()
#                     .setTargeting("pageCategories","Jantar prático")
#                     .setTargeting("pageTags","Array")
#                     .setTargeting("pageType","single")
#                     .setTargeting("urlPath","https://guiadacozinha.com.br/torta-de-batata-e-estrogonofe/")
#                     ));
#
#   gptadslots.push(googletag.defineSlot('/1694668/guiadacozinha7', [[970, 250], [970, 90], [728, 90]], 'div-gpt-ad-1550091566019-0')
#                     .addService(googletag.pubads()
#                     .setTargeting("pageCategories","Jantar prático")
#                     .setTargeting("pageTags","Array")
#                     .setTargeting("pageType","single")
#                     .setTargeting("urlPath","https://guiadacozinha.com.br/torta-de-batata-e-estrogonofe/")
#                     ));
#
#
#   gptadslots.push(googletag.defineSlot('/1694668/guiadacozinha8', [[300, 250], [336, 280]], 'div-gpt-ad-1550091676975-0')
#                     .addService(googletag.pubads()
#                     .setTargeting("pageCategories","Jantar prático")
#                     .setTargeting("pageTags","Array")
#                     .setTargeting("pageType","single")
#                     .setTargeting("urlPath","https://guiadacozinha.com.br/torta-de-batata-e-estrogonofe/")
#                     ));
#
#   gptadslots.push(googletag.defineSlot('/1694668/guiadacozinha9', [300, 250], 'div-gpt-ad-1550091965033-0')
#                     .addService(googletag.pubads()
#                     .setTargeting("pageCategories","Jantar prático")
#                     .setTargeting("pageTags","Array")
#                     .setTargeting("pageType","single")
#                     .setTargeting("urlPath","https://guiadacozinha.com.br/torta-de-batata-e-estrogonofe/")
#                     ));
#
#
#
#   gptadslots.push(googletag.defineSlot('/1694668/guiadacozinha10', [[336, 280], [300, 250]], 'div-gpt-ad-1550092039314-0')
#                      .addService(googletag.pubads()
#                      .setTargeting("pageCategories","Jantar prático")
#                      .setTargeting("pageTags","Array")
#                      .setTargeting("pageType","single")
#                      .setTargeting("urlPath","https://guiadacozinha.com.br/torta-de-batata-e-estrogonofe/")
#                      ));
#   gptadslots.push(googletag.defineSlot('/1694668/guiadacozinha11', [[300, 250], [300, 600], [160, 600]], 'div-gpt-ad-1550092121806-0')
#                     .addService(googletag.pubads()
#                     .setTargeting("pageCategories","Jantar prático")
#                     .setTargeting("pageTags","Array")
#                     .setTargeting("pageType","single")
#                     .setTargeting("urlPath","https://guiadacozinha.com.br/torta-de-batata-e-estrogonofe/")
#                     ));
#   gptadslots.push(googletag.defineSlot('/1694668/guiadacozinha19', [[320, 50], [300, 100], [300, 50]], 'div-gpt-ad-1550150838235-0')
#                     .addService(googletag.pubads()
#                     .setTargeting("pageCategories","Jantar prático")
#                     .setTargeting("pageTags","Array")
#                     .setTargeting("pageType","single")
#                     .setTargeting("urlPath","https://guiadacozinha.com.br/torta-de-batata-e-estrogonofe/")
#                     ));
#
#   gptadslots.push(googletag.defineSlot('/1694668/guiadacozinha20', [300, 250], 'div-gpt-ad-1550150904721-0')
#                     .addService(googletag.pubads()
#                     .setTargeting("pageCategories","Jantar prático")
#                     .setTargeting("pageTags","Array")
#                     .setTargeting("pageType","single")
#                     .setTargeting("urlPath","https://guiadacozinha.com.br/torta-de-batata-e-estrogonofe/")
#                     ));
#
#   gptadslots.push(googletag.defineSlot('/1694668/guiadacozinha21', [300, 250], 'div-gpt-ad-1550150959724-0')
#                     .addService(googletag.pubads()
#                     .setTargeting("pageCategories","Jantar prático")
#                     .setTargeting("pageTags","Array")
#                     .setTargeting("pageType","single")
#                     .setTargeting("urlPath","https://guiadacozinha.com.br/torta-de-batata-e-estrogonofe/")
#                     ));
#
#
#   gptadslots.push(googletag.defineSlot('/1694668/guiadacozinha23', [300, 250], 'div-gpt-ad-1550151018618-0')
#                     .addService(googletag.pubads()
#                     .setTargeting("pageCategories","Jantar prático")
#                     .setTargeting("pageTags","Array")
#                     .setTargeting("pageType","single")
#                     .setTargeting("urlPath","https://guiadacozinha.com.br/torta-de-batata-e-estrogonofe/")
#                     ));
#
# gptadslots.push(googletag.defineSlot('/1694668/GuiadaCozinha_1x1', [1, 1], 'div-gpt-ad-1550780848820-0')
#                   .addService(googletag.pubads()
#                   .setTargeting("pageCategories","Jantar prático")
#                   .setTargeting("pageTags","Array")
#                   .setTargeting("pageType","single")
#                   .setTargeting("urlPath","https://guiadacozinha.com.br/torta-de-batata-e-estrogonofe/")
#                   ));
#
#
#
#
#   googletag.pubads().collapseEmptyDivs(true);
#   googletag.pubads().setCentering(true);
#   googletag.enableServices();
#
#     });
#   </script>
#
# <script>
# googletag.cmd.push(function() {
# googletag.defineSlot('/1694668/StickyAds', [320, 50], 'x').addService(googletag.pubads());
# googletag.pubads().collapseEmptyDivs();
# googletag.enableServices();
# });
# </script>
# <!-- End GPT Async Tag -->
# <!-- Hotjar Tracking Code for https://guiadacozinha.com.br/ -->
# <script>
#     (function(h,o,t,j,a,r){
#         h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#         h._hjSettings={hjid:583793,hjsv:6};
#         a=o.getElementsByTagName('head')[0];
#         r=o.createElement('script');r.async=1;
#         r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#         a.appendChild(r);
#     })(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');
# </script>
#
# <!-- Start Hands Tag -->
# <script type="text/javascript">
# sas_pageid = 'guiadacozinha/151040/780600';</script>
# <script async type="text/javascript" src="https://ec-ns.sascdn.com/diff/857/sasmobile.js" ></script>
# <!-- End Hands Tag -->
#
#
#
#
# <!-- Navegg tag -->
# <script id="navegg" type="text/javascript" src="https://tag.navdmp.com/tm47543.js"></script>
# <!-- /Navegg tag -->
#
# <!-- GCS Tag -->
# <script type="text/javascript">
# (function() {
#   var ARTICLE_URL = window.location.href;
#   var CONTENT_ID = 'everything';
#   document.write(
#     '<scr'+'ipt '+
#     'src="//survey.g.doubleclick.net/survey?site=_gfbl62cokry2r6ezyxcd5wjwum'+
#     '&amp;url='+encodeURIComponent(ARTICLE_URL)+
#     (CONTENT_ID ? '&amp;cid='+encodeURIComponent(CONTENT_ID) : '')+
#     '&amp;random='+(new Date).getTime()+
#     '" type="text/javascript">'+'\x3C/scr'+'ipt>');
# })();
# </script>
# <!-- /GCS Tag -->
#
#
# <script src="//api.nobeta.com.br/sl&b=guiadacozinha.inter"></script>
# <script type="text/javascript">
#     window._seedtagq = window._seedtagq || [];
#     window._seedtagq.push(['_setId', '6115-8371-01']);
#
#     window._seedtagq.push(['iframe_mode']);
#     (function () {
#       var st = document.createElement('script');
#       st.type = 'text/javascript';
#       st.async = true;
#       st.src = ('https:' == document.location.protocol
#         ? 'https'
#         : 'http') + '://config.seedtag.com/loader.js?v=' + Math.random();
#       var s = document.getElementsByTagName('script')[0];
#       s.parentNode.insertBefore(st, s);
#     })();
#     </script>
# 	<!-- nao funfou dando Enqueue -->
# 	<link href="https://fonts.googleapis.com/css?family=Satisfy|Poppins:300,400,700" rel="stylesheet">
#
# 	<!-- Facebook Pixel Code -->
# 	<script>
# 		!function(f,b,e,v,n,t,s)
# 		{if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# 		n.callMethod.apply(n,arguments):n.queue.push(arguments)};
# 		if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
# 		n.queue=[];t=b.createElement(e);t.async=!0;
# 		t.src=v;s=b.getElementsByTagName(e)[0];
# 		s.parentNode.insertBefore(t,s)}(window, document,'script',
# 		'https://connect.facebook.net/en_US/fbevents.js');
# 		fbq('init', '139184130031482');
# 		fbq('track', 'PageView');
# 	</script>
# 	<noscript><img height="1" width="1" style="display:none"
# 		src="https://www.facebook.com/tr?id=139184130031482&ev=PageView&noscript=1"
# 	/></noscript>
# 	<!-- End Facebook Pixel Code -->
#
# 	<link rel="shortcut icon" href="https://guiadacozinha.com.br/wp-content/themes/guia-da-cozinha/assets/images/favicon.ico" type="image/x-icon">
#   <link rel="icon" href="https://guiadacozinha.com.br/wp-content/themes/guia-da-cozinha/assets/images/favicon.ico" type="image/x-icon">
#
# 	<link rel="apple-touch-icon" sizes="76x76" href="https://guiadacozinha.com.br/wp-content/themes/guia-da-cozinha/assets/images/favicon.png">
# <link rel="icon" type="image/png" sizes="32x32" href="https://guiadacozinha.com.br/wp-content/themes/guia-da-cozinha/assets/images/favicon32.png">
# <link rel="icon" type="image/png" sizes="16x16" href="https://guiadacozinha.com.br/wp-content/themes/guia-da-cozinha/assets/images/favicon16.png">
# <meta name="msapplication-TileColor" content="#da532c">
#
#
#
# 	<title>Torta de batata e estrogonofe: deliciosa e prática de fazer</title>
#
# <!-- This site is optimized with the Yoast SEO Premium plugin v7.0.2 - https://yoast.com/wordpress/plugins/seo/ -->
# <meta name="description" content="Confira esta receita de torta de batata e estrogonofe, que além de ficar uma delícia, é uma opção superdiferente para fazer em casa e surpreender a família!"/>
# <link rel="canonical" href="https://guiadacozinha.com.br/torta-de-batata-e-estrogonofe/" />
# <meta property="og:locale" content="pt_BR" />
# <meta property="og:type" content="article" />
# <meta property="og:title" content="Torta de batata e estrogonofe: deliciosa e prática de fazer" />
# <meta property="og:description" content="Confira esta receita de torta de batata e estrogonofe, que além de ficar uma delícia, é uma opção superdiferente para fazer em casa e surpreender a família!" />
# <meta property="og:url" content="https://guiadacozinha.com.br/torta-de-batata-e-estrogonofe/" />
# <meta property="og:site_name" content="Guia da Cozinha" />
# <meta property="article:publisher" content="http://facebook.com/guiadacozinha/" />
# <meta property="article:tag" content="como fazer estrogonofe" />
# <meta property="article:tag" content="receita de estrogonofe" />
# <meta property="article:tag" content="receitas de torta" />
# <meta property="article:tag" content="torta de batata" />
# <meta property="article:tag" content="torta na travessa" />
# <meta property="article:section" content="Jantar prático" />
# <meta property="article:published_time" content="2019-02-23T08:45:21+00:00" />
# <meta property="article:modified_time" content="2019-01-15T10:41:46+00:00" />
# <meta property="og:updated_time" content="2019-01-15T10:41:46+00:00" />
# <meta property="fb:app_id" content="1867919556781585" />
# <meta property="og:image" content="https://guiadacozinha.com.br/wp-content/uploads/2018/01/torta-batata-estrogonofe.jpg" />
# <meta property="og:image:secure_url" content="https://guiadacozinha.com.br/wp-content/uploads/2018/01/torta-batata-estrogonofe.jpg" />
# <meta property="og:image:width" content="945" />
# <meta property="og:image:height" content="630" />
# <meta name="twitter:card" content="summary_large_image" />
# <meta name="twitter:description" content="Confira esta receita de torta de batata e estrogonofe, que além de ficar uma delícia, é uma opção superdiferente para fazer em casa e surpreender a família!" />
# <meta name="twitter:title" content="Torta de batata e estrogonofe: deliciosa e prática de fazer" />
# <meta name="twitter:site" content="@guiadacozinha" />
# <meta name="twitter:image" content="https://guiadacozinha.com.br/wp-content/uploads/2018/01/torta-batata-estrogonofe.jpg" />
# <meta name="twitter:creator" content="@guiadacozinha" />
# <!-- / Yoast SEO Premium plugin. -->
#
# <link rel='dns-prefetch' href='//guiadacozinha.com.br' />
# <link rel='dns-prefetch' href='//maxcdn.bootstrapcdn.com' />
# <link rel='dns-prefetch' href='//cdnjs.cloudflare.com' />
# <link rel='dns-prefetch' href='//use.fontawesome.com' />
# <link rel='dns-prefetch' href='//s.w.org' />
# <link rel="alternate" type="application/rss+xml" title="Feed para Guia da Cozinha &raquo;" href="https://guiadacozinha.com.br/feed/" />
# <link rel="alternate" type="application/rss+xml" title="Feed de comentários para Guia da Cozinha &raquo;" href="https://guiadacozinha.com.br/comments/feed/" />
# <link rel="alternate" type="application/rss+xml" title="Feed de comentários para Guia da Cozinha &raquo; Torta de batata e estrogonofe" href="https://guiadacozinha.com.br/torta-de-batata-e-estrogonofe/feed/" />
# <link rel='stylesheet' id='sb_instagram_styles-css'  href='https://guiadacozinha.com.br/wp-content/plugins/instagram-feed/css/sb-instagram.min.css?ver=1.10.2' type='text/css' media='all' />
# <link rel='stylesheet' id='sb-font-awesome-css'  href='https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css' type='text/css' media='all' />
# <link rel='stylesheet' id='bootstrap-css'  href='https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css?ver=4.9.8' type='text/css' media='all' />
# <link rel='stylesheet' id='font-awesome-css'  href='https://use.fontawesome.com/releases/v5.3.1/css/all.css?ver=4.9.8' type='text/css' media='all' />
# <link rel='stylesheet' id='guia-da-cozinha-style-css'  href='https://guiadacozinha.com.br/wp-content/themes/guia-da-cozinha/style.css' type='text/css' media='all' />
# <link rel='stylesheet' id='um_fonticons_ii-css'  href='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/css/um-fonticons-ii.css?ver=2.0.33' type='text/css' media='all' />
# <link rel='stylesheet' id='um_fonticons_fa-css'  href='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/css/um-fonticons-fa.css?ver=2.0.33' type='text/css' media='all' />
# <link rel='stylesheet' id='select2-css'  href='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/css/select2/select2.min.css?ver=2.0.33' type='text/css' media='all' />
# <link rel='stylesheet' id='um_crop-css'  href='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/css/um-crop.css?ver=2.0.33' type='text/css' media='all' />
# <link rel='stylesheet' id='um_modal-css'  href='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/css/um-modal.css?ver=2.0.33' type='text/css' media='all' />
# <link rel='stylesheet' id='um_styles-css'  href='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/css/um-styles.css?ver=2.0.33' type='text/css' media='all' />
# <link rel='stylesheet' id='um_members-css'  href='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/css/um-members.css?ver=2.0.33' type='text/css' media='all' />
# <link rel='stylesheet' id='um_profile-css'  href='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/css/um-profile.css?ver=2.0.33' type='text/css' media='all' />
# <link rel='stylesheet' id='um_account-css'  href='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/css/um-account.css?ver=2.0.33' type='text/css' media='all' />
# <link rel='stylesheet' id='um_misc-css'  href='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/css/um-misc.css?ver=2.0.33' type='text/css' media='all' />
# <link rel='stylesheet' id='um_fileupload-css'  href='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/css/um-fileupload.css?ver=2.0.33' type='text/css' media='all' />
# <link rel='stylesheet' id='um_datetime-css'  href='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/css/pickadate/default.css?ver=2.0.33' type='text/css' media='all' />
# <link rel='stylesheet' id='um_datetime_date-css'  href='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/css/pickadate/default.date.css?ver=2.0.33' type='text/css' media='all' />
# <link rel='stylesheet' id='um_datetime_time-css'  href='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/css/pickadate/default.time.css?ver=2.0.33' type='text/css' media='all' />
# <link rel='stylesheet' id='um_raty-css'  href='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/css/um-raty.css?ver=2.0.33' type='text/css' media='all' />
# <link rel='stylesheet' id='um_scrollbar-css'  href='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/css/um-scrollbar.css?ver=2.0.33' type='text/css' media='all' />
# <link rel='stylesheet' id='um_tipsy-css'  href='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/css/um-tipsy.css?ver=2.0.33' type='text/css' media='all' />
# <link rel='stylesheet' id='um_responsive-css'  href='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/css/um-responsive.css?ver=2.0.33' type='text/css' media='all' />
# <link rel='stylesheet' id='um_default_css-css'  href='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/css/um-old-default.css?ver=2.0.33' type='text/css' media='all' />
# <script type='text/javascript' src='https://guiadacozinha.com.br/wordpress-core/wp-includes/js/jquery/jquery.js?ver=1.12.4'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wordpress-core/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/js/um-gdpr.min.js?ver=2.0.33'></script>
# <link rel='https://api.w.org/' href='https://guiadacozinha.com.br/wp-json/' />
# <link rel="alternate" type="application/json+oembed" href="https://guiadacozinha.com.br/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fguiadacozinha.com.br%2Ftorta-de-batata-e-estrogonofe%2F" />
# <link rel="alternate" type="text/xml+oembed" href="https://guiadacozinha.com.br/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fguiadacozinha.com.br%2Ftorta-de-batata-e-estrogonofe%2F&#038;format=xml" />
# <meta property="fb:app_id" content=""/>		<style type="text/css">
# 			.request_name {
# 				display: none !important;
# 			}
# 		</style>
# 	<link rel="amphtml" href="https://guiadacozinha.com.br/torta-de-batata-e-estrogonofe/amp/">
# 	<!-- pinterest validation -->
#   <meta name="p:domain_verify" content="08b2241e214440faa12b4dc5d1920b18"/>
#
# 	<script type="text/javascript" src="//ads.vidoomy.com/guiadacozinha_3860.js" ></script>
#
# </head>
#
# <body class="post-template-default single single-post postid-538738 single-format-standard no-sidebar">
# 	<script>
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 		(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 		m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
# 	ga('create', 'UA-49315504-4', 'auto');
# 	ga('create', 'UA-49315504-20', 'auto', 'altoastralTracker');
#
#
#
#
# 	ga('send', 'pageview');
# 	ga('altoastralTracker.send', 'pageview');
# </script>
#
# <!-- End GPT Async Tag -->
# <!-- Hotjar Tracking Code for https://guiadacozinha.com.br/ -->
# <script>
#     (function(h,o,t,j,a,r){
#         h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#         h._hjSettings={hjid:583793,hjsv:6};
#         a=o.getElementsByTagName('head')[0];
#         r=o.createElement('script');r.async=1;
#         r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#         a.appendChild(r);
#     })(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');
# </script>
#
# <!-- /1694668/GuiadaCozinha_1x1 -->
# <div id='div-gpt-ad-1550780848820-0' style='height:1px; width:1px;'>
# <script>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1550780848820-0'); });
# </script>
# </div>
# <script type="text/javascript" async src="https://d335luupugsy2.cloudfront.net/js/loader-scripts/13c1c734-e6cc-46aa-9238-180db56352fc-loader.js"></script>
# <!-- Start Hands Tag -->
# <script type="text/javascript">
# sas_pageid = 'guiadacozinha/151040/780600';</script>
# <script async type="text/javascript" src="https://ec-ns.sascdn.com/diff/857/sasmobile.js" ></script>
# <!-- End Hands Tag -->
#
#
# <script type="text/javascript" async src="https://d335luupugsy2.cloudfront.net/js/loader-scripts/13c1c734-e6cc-46aa-9238-180db56352fc-loader.js"></script>
#
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-KC9695W"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
#
# <!-- Begin comScore Tag -->
# <script>
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "8", c2: "6035239" ,c3: "12" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
# </script>
# <noscript>
#   <img src="https://b.scorecardresearch.com/p?c1=8&c2=6035239&c3=12&c15=&cv=2.0&cj=1" />
# </noscript>
# <!-- End comScore Tag -->
#
# <script type="text/javascript">var isMobile = /Android|webOS|iPhone|iPad|iPod|BlackBerry/i.test(navigator.userAgent) ? true : false; </script>
#
#
# <div id="page" class="site">
# 	<header id="masthead" class="site-header">
# 		<header role="banner" class="navbar navbar-fixed-top navbar-inverse">
# 	<div class="container">
# 		<h1 class="logo-gc">
# 			<a alt="Guia da Cozinha" href="/">
# 				Guia da Cozinha
#
# 			</a>
# 		</h1>
# 		<div class="social-media visible-md visible-lg">
#
# <span>SIGA-NOS</span>
# 			<ul class="social-set">
#
#
# 				<li><a title="Siga nosso perfil no Instagram" href="https://instagram.com/guiadacozinha" class="sociali" target="_blank" aria-label="Siga nosso perfil no Instagram">
# 						<i class="fab fa-instagram fa-fw" title="Siga nosso perfil no Instagram"></i></a></li>
#
#
#
#
# 				<li><a title="Curta nossa página do Facebook" href="https://www.facebook.com/guiadacozinha/" class="sociali" target="_blank" aria-label="Curta nossa página do Facebook">
# 						<i class="fab fa-facebook-f fa-fw" title="Curta nossa página do Facebook"></i></a></li>
#
#
# 				<li><a title="Siga o nosso Twitter" href="https://www.twitter.com/guiadacozinha/" class="sociali" target="_blank" aria-label="Siga o nosso Twitter">
# 						<i class="fab fa-twitter fa-fw" title="Siga o nosso Twitter"></i></a></li>
#
#
# 				<li><a title="Siga o nosso canal no Youtube" href="https://www.youtube.com/guiadacozinhaoficial"	class="sociali" target="_blank" aria-label="Siga o nosso canal no Youtube">
# 						<i class="fab fa-youtube fa-fw" title="Siga o nosso canal no Youtube"></i></a></li>
#
#
# 				<li><a title="Visite o nosso Pinterest" href="https://br.pinterest.com/guiadacozinha/" class="sociali" target="_blank" aria-label="Visite o nosso Pinterest">
# 						<i class="fab fa-pinterest fa-fw" title="Visite o nosso Pinterest"></i></a></li>
#
#
# 			</ul>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		</div>
#
# 		<div class="srcInput">
# 			<i class="glyphicon glyphicon-search"></i>
# 			<form method="get" id="searchform" action="https://guiadacozinha.com.br/">
# 				<input type="text" class="form-control srcRecipe" name="s" id="s" placeholder="Pesquisar..." />
# 			</form>
# 		</div>
# 		<ul class="nav menu-navb navbar-nav">
# 			<!--<li class="visible-md visible-lg"><a href="#"> Envie sua receita</a></li>-->
# 							<li class="visible-md visible-lg"><a href="#" data-toggle="modal" data-target="#loginGC"><?xml version="1.0" encoding="utf-8"?>
# <!-- Generator: Adobe Illustrator 16.0.0, SVG Export Plug-In . SVG Version: 6.00 Build 0)  -->
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg version="1.1" id="Layer_1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px"
# 	 width="101.544px" height="82.287px" viewBox="0 0 101.544 82.287" enable-background="new 0 0 101.544 82.287"
# 	 xml:space="preserve">
# <g>
# 	<g>
# 		<polygon fill="#F1585E" points="51.069,36.728 33.435,19.093 33.435,28.396 14.057,28.396 14.057,45.06 33.435,45.06
# 			33.435,54.363 		"/>
# 	</g>
# 	<g>
# 		<path fill="#F1585E" d="M83.338,66.922H48.926c-2.288,0-4.15-1.861-4.15-4.149V52.435c0-1.111,0.9-2.011,2.012-2.011
# 			c1.11,0,2.011,0.9,2.011,2.011v10.337c0,0.07,0.058,0.127,0.128,0.127h34.412c0.07,0,0.128-0.057,0.128-0.127V10.684
# 			c0-0.07-0.058-0.127-0.128-0.127H48.926c-0.07,0-0.128,0.057-0.128,0.127v10.035c0,1.11-0.9,2.011-2.011,2.011
# 			c-1.111,0-2.012-0.9-2.012-2.011V10.684c0-2.288,1.862-4.15,4.15-4.15h34.412c2.288,0,4.149,1.862,4.149,4.15v52.088
# 			C87.487,65.061,85.626,66.922,83.338,66.922z"/>
# 	</g>
# 	<g>
# 		<path fill-rule="evenodd" clip-rule="evenodd" fill="#F1585E" d="M60.815,73.615c0,1.181,0.958,2.138,2.139,2.138l20.384-10.842
# 			c1.181,0,2.139-0.957,2.139-2.138V10.684c0-1.181-0.958-2.139-2.139-2.139L62.954,19.388c-1.181,0-2.139,2.507-2.139,3.687V73.615
# 			z"/>
# 	</g>
# </g>
# </svg>
#  Entre | Cadastre-se</a></li>
# 						<li class="icon-search visible-xs"><i class="fas fa-search"></i></li>
# 			<li class="icon-menu"><i class="fas fa-bars"></i></li>
# 		</ul>
# 	</div>
#
# 	<div class="hidden-nav">
# 		<ul>
# 							<li class="svgfix"><a href="#" data-toggle="modal" data-target="#loginGC"><?xml version="1.0" encoding="utf-8"?>
# <!-- Generator: Adobe Illustrator 16.0.0, SVG Export Plug-In . SVG Version: 6.00 Build 0)  -->
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg version="1.1" id="Layer_1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px"
# 	 width="101.544px" height="82.287px" viewBox="0 0 101.544 82.287" enable-background="new 0 0 101.544 82.287"
# 	 xml:space="preserve">
# <g>
# 	<g>
# 		<polygon fill="#F1585E" points="51.069,36.728 33.435,19.093 33.435,28.396 14.057,28.396 14.057,45.06 33.435,45.06
# 			33.435,54.363 		"/>
# 	</g>
# 	<g>
# 		<path fill="#F1585E" d="M83.338,66.922H48.926c-2.288,0-4.15-1.861-4.15-4.149V52.435c0-1.111,0.9-2.011,2.012-2.011
# 			c1.11,0,2.011,0.9,2.011,2.011v10.337c0,0.07,0.058,0.127,0.128,0.127h34.412c0.07,0,0.128-0.057,0.128-0.127V10.684
# 			c0-0.07-0.058-0.127-0.128-0.127H48.926c-0.07,0-0.128,0.057-0.128,0.127v10.035c0,1.11-0.9,2.011-2.011,2.011
# 			c-1.111,0-2.012-0.9-2.012-2.011V10.684c0-2.288,1.862-4.15,4.15-4.15h34.412c2.288,0,4.149,1.862,4.149,4.15v52.088
# 			C87.487,65.061,85.626,66.922,83.338,66.922z"/>
# 	</g>
# 	<g>
# 		<path fill-rule="evenodd" clip-rule="evenodd" fill="#F1585E" d="M60.815,73.615c0,1.181,0.958,2.138,2.139,2.138l20.384-10.842
# 			c1.181,0,2.139-0.957,2.139-2.138V10.684c0-1.181-0.958-2.139-2.139-2.139L62.954,19.388c-1.181,0-2.139,2.507-2.139,3.687V73.615
# 			z"/>
# 	</g>
# </g>
# </svg>
#  Entre | Cadastre-se</a></li>
# 										<li class="cat-item cat-item-142629"><a href="https://guiadacozinha.com.br/category/acompanhamentos/" >Acompanhamentos</a>
#
# 		</div>
# 	</div>
#
# 	<div class="visible-xs hidden-search">
# 		<form method="get" id="searchform" action="https://guiadacozinha.com.br/">
# 			<input type="text" class="form-control srcMobile srcRecipe" name="s" id="s" placeholder="Pesquisar..." />
# 		</form>
# 	</div>
#
#
#
# </header>
# <script>
# 	jQuery(document).ready(function() {
# 		var sideslider = jQuery('[data-toggle=collapse-side]');
# 		var sel = sideslider.attr('data-target');
# 		var sel2 = sideslider.attr('data-target-2');
# 		sideslider.click(function(event){
# 			jQuery(sel).toggleClass('in');
# 			jQuery(sel2).toggleClass('out');
# 		});
# 	});
# </script>
#
#
# <script>
# 	jQuery(document).ready(function() {
# 		jQuery('.icon-menu').click(function(){
# 			jQuery('.hidden-nav').toggleClass('nav-view');
# 			jQuery('.icon-menu i').toggleClass( 'fa-times');
# 			jQuery('.icon-menu i').toggleClass( 'fa-bars');
#
# 		});
# 	});
# </script>
#
#
# <script>
# 	jQuery(document).ready(function() {
# 		jQuery('.icon-search').click(function(){
# 			jQuery('.hidden-search').toggleClass('search-view');
# 			jQuery('.icon-search i').toggleClass( 'fa-times');
# 			jQuery('.icon-search i').toggleClass( 'fa-search');
# 			jQuery('.srcMobile').focus();
# 		});
# 	});
# </script>
#
#
# <!-- Modal Login -->
# <div class="modal fade" id="loginGC" tabindex="-1" role="dialog" aria-labelledby="myModalLabel">
#   <div class="modal-dialog" role="document">
#     <div class="modal-content">
#       <div class="modal-header">
#         <button type="button" class="close" data-dismiss="modal" aria-label="Close"><span aria-hidden="true">&times;</span></button>
#         <a class="holdlogo" href="" title="Guia da Cozinha" alt="Guia da Cozinha"><span class="logo"></span></a>
#       </div>
#       <div class="modal-body">
#         <h3>Venha fazer parte da nossa área exclusiva!</h3>
# 				<p>Já possui cadastro? <a href="/login/" alt="Entrar">Entre aqui</a></p>
# 				<p>Ainda não faz parte? <a alt="Cadastre-se" href="/registrar/" target="_blank">Cadastre-se aqui</a></p>
#       </div>
#       <div class="modal-footer">
#         <button type="button" class="btn btn-default" data-dismiss="modal">Fechar</button>
#       </div>
#     </div>
#   </div>
# </div>
# 	</header><!-- #masthead -->
#
# 	<div id="content" class="site-content">
# 	<div id="primary" class="content-area">
# 		<main id="main" class="site-main">
# 			<div class="container">
# 	<div class="ads-top">
# 		<div id='div-gpt-ad-1550091566019-0' class='hidden-xs'>
# <script>
# if( !/Android|webOS|iPhone|iPad|iPod|BlackBerry|IEMobile|Opera Mini/i.test(navigator.userAgent) ) {
#   googletag.cmd.push(function() { googletag.display('div-gpt-ad-1550091566019-0'); });
# }
# </script>
# </div>
#
# <div id='div-gpt-ad-1550150838235-0' class="visible-xs">
# <script>
# if( /Android|webOS|iPhone|iPad|iPod|BlackBerry|IEMobile|Opera Mini/i.test(navigator.userAgent) ) {
#   googletag.cmd.push(function() { googletag.display('div-gpt-ad-1550150838235-0'); });
# }
# </script>
# </div>
# 	</div>
#
# 	<div class="row">
# 		<div class="col-md-8 content-column-1 col-xs-12">
# 			<article class="content-body" id="post-538738">
# 				<header class="header">
# 					<h1 class="title">Torta de batata e estrogonofe</h1>					<div class="sub-infos">
# 						<ul class="recipe-details">
# 							<li><?xml version="1.0" encoding="utf-8"?>
# <!-- Generator: Adobe Illustrator 16.0.0, SVG Export Plug-In . SVG Version: 6.00 Build 0)  -->
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg version="1.1" id="Layer_1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px"
# 	 width="248px" height="206px" viewBox="0 0 248 206" enable-background="new 0 0 248 206" xml:space="preserve">
# <g>
# 	<path fill-rule="evenodd" clip-rule="evenodd" fill="none" stroke="#f0575e" stroke-width="8" stroke-miterlimit="10" d="
# 		M1479.669,461.329c0,28.103-22.78,50.882-50.882,50.882s-50.882-22.779-50.882-50.882"/>
# 	<path fill-rule="evenodd" clip-rule="evenodd" fill="none" stroke="#f0575e" stroke-width="8" stroke-miterlimit="10" d="
# 		M
# 			<polygon fill-rule="evenodd" clip-rule="evenodd" points="85.301,31.989 88.75,31.989 88.75,12.504 92.364,12.504 92.364,9.261
# 				81.687,9.261 81.687,12.504 85.301,12.504 			"/>
# 			<path fill-rule="evenodd" clip-rule="evenodd" d="M120.403,14.792L120.403,14.792c2.517,0,4.576,2.059,4.576,4.576v4.601h-6.038
# 				v3.857c0,0.804,0.658,1.461,1.462,1.461l0,0c0.804,0,1.462-0.657,1.462-1.461v-1.893h3.114v1.479c0,2.517-2.06,4.576-4.576,4.576
# 				l0,0c-2.518,0-4.576-2.06-4.576-4.576v-8.045C115.827,16.851,117.886,14.792,120.403,14.792L120.403,14.792z M121.865,21.38
# 				v-2.396c0-0.804-0.658-1.461-1.462-1.461l0,0c-0.804,0-1.462,0.658-1.462,1.461v2.396H121.865z"/>
# 		</g>
# 	</g>
# 	<g>
# 		<path fill-rule="evenodd" clip-rule="evenodd" fill="#E11B22" d="M28.649,7.001c3.385,0.005,7.862,0.049,11.168,0.356
# 			c2.642,0.246,3.303,0.641,3.998,1.271c1.801,1.632,2.203,6.052,2.262,10.45c0.013,0.947,0.013,1.896,0,2.843
# 			c-0.06,4.398-0.461,8.818-2.262,10.451c-0.695,0.63-1.356,1.025-3.998,1.271c-3.306,0.308-7.783,0.351-11.168,0.356
# 			c-1.397,0.002-2.794,0.002-4.191,0c-3.385-0.006-7.862-0.049-11.168-0.356c-2.642-0.245-3.302-0.641-3.998-1.271
# 			c-1.816-1.647-2.21-6.129-2.264-10.565c-0.01-0.833-0.01-1.668-0.001-2.501C7.076,14.834,7.46,10.29,9.292,8.629
# 			c0.695-0.63,1.356-1.026,3.998-1.271c3.306-0.307,7.784-0.35,11.168-0.356C25.854,7,27.252,7,28.649,7.001z"/>
# 		<polygon fill-rule="evenodd" clip-rule="evenodd" fill="#FFFFFF" points="22.73,14.885 22.73,26.474 32.587,20.5 		"/>
# 	</g>
# </g>
# </svg>
# <a href="https://youtube.com/guiadacozinhaoficial">guiadacozinhaoficial</a>
# 	<iframe width="100%" src="https://www.youtube.com/embed/Ku4fgMJP48g" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# 	<h3><a class="ytanchor" href="https://www.youtube.com/watch?v=Ku4fgMJP48g">Rocambole de carne | Receitas Guia da Cozinha</a></h3>
# </div>
# 		</div>
#
# 		</aside>
# 		<div class="arroba sticky-1">
# 			<div id='div-gpt-ad-1550092121806-0' class='hidden-xs'>
# <script>
# if( !/Android|webOS|iPhone|iPad|iPod|BlackBerry|IEMobile|Opera Mini/i.test(navigator.userAgent) ) {
#   googletag.cmd.push(function() { googletag.display('div-gpt-ad-1550092121806-0'); });
# }
# </script>
# </div>
# 		</div>
# 	</div>
# 		</aside>
# 	</div>
# </div>
#
#
# <script type="text/javascript">
# jQuery(document).ready(function(){
# 	jQuery('.sticky-1').fixTo('.content-column-1', {
# 		useNativeSticky: false,
#     top: 100
# 		});
# 	});
# </script>
#
# <script type="text/javascript">
#
#   if (jQuery(".recipe-details em").html() == "") {
#       jQuery(".sub-infos").css("display", "none");
#   }
#   else {
#       jQuery(".sub-infos").css("display", "block");
#   }
#
# </script>
#
# 	</div><!-- #content -->
#
# 	<footer id="footer" class="site-footer">
# 				<div class="container">
# 			<div class="row">
# 				<div class="col-xs-12 col-md-4">
# 					<a class="holdlogo" href="" title="Guia da Cozinha" alt="Guia da Cozinha"><span class="logo"></span></a>
# 				</div>
# 				<div class="col-xs-12 menu-footer col-md-4">
# 					<h2>Menu</h2>
# 					<ul>
# 						<li><a href="http://altoastralcomunicacao.com.br/" target="_blank">QUEM SOMOS</a></li>
# 													<li><a href="#" data-toggle="modal" data-target="#loginGC"> ENTRE | CADASTRE-SE</a></li>
# 												<!--<li><a href="#">ENVIE SUA RECEITA</a></li>-->
# 						<li><a href="http://altoastralcomunicacao.com.br/midiakit.pdf" target="_blank">ANUNCIE</a></li>
# 						<li><a href="http://bolos.paravender.com.br/" target="_blank">CURSOS</a></li>
# 						<li><a href="https://www.astralshopping.com.br/culinaria" target="_blank">LOJA</a></li>
#
#
#
#
# 						<li><a href="mailto:guiadacozinha@astral.com.br" target="_blank">CONTATO</a></li>
# 					</ul>
#
# 				</div>
# 				<div class="col-xs-12 col-md-4">
# 					<h2>SIGA-NOS</h2>
# 					<ul class="social-set">
#
#
# 						<li><a title="Siga nosso perfil no Instagram" href="https://instagram.com/guiadacozinha" class="sociali" target="_blank" aria-label="Siga nosso perfil no Instagram">
# 								<i class="fab fa-instagram fa-fw" title="Siga nosso perfil no Instagram"></i></a></li>
#
#
#
#
# 						<li><a title="Curta nossa página do Facebook" href="https://www.facebook.com/guiadacozinha/" class="sociali" target="_blank" aria-label="Curta nossa página do Facebook">
# 								<i class="fab fa-facebook-f fa-fw" title="Curta nossa página do Facebook"></i></a></li>
#
#
# 						<li><a title="Siga o nosso Twitter" href="https://www.twitter.com/guiadacozinha/" class="sociali" target="_blank" aria-label="Siga o nosso Twitter">
# 								<i class="fab fa-twitter fa-fw" title="Siga o nosso Twitter"></i></a></li>
#
#
# 						<li><a title="Siga o nosso canal no Youtube" href="https://www.youtube.com/guiadacozinhaoficial"	class="sociali" target="_blank" aria-label="Siga o nosso canal no Youtube">
# 								<i class="fab fa-youtube fa-fw" title="Siga o nosso canal no Youtube"></i></a></li>
#
#
# 						<li><a title="Visite o nosso Pinterest" href="https://br.pinterest.com/guiadacozinha/" class="sociali" target="_blank" aria-label="Visite o nosso Pinterest">
# 								<i class="fab fa-pinterest fa-fw" title="Visite o nosso Pinterest"></i></a></li>
#
#
# 					</ul>
# 				</div>
# 			</div>
# 		</div>
# 		<span class="footer-do-footer">
# 			<h2>2019 - Grupo Alto Astral - Todos direitos reservados</h2>
# 		</span>
# 	</footer><!-- #colophon -->
#
#
# 	<div id="msgSalvarReceita">Receita salva com sucesso... <a style="text-decoration:underline" href="http://guiadacozinha.com.br/minha-conta/saved_recipes/">Veja o seu Livro de receitas</a></div>
# </div><!-- #page -->
#
# <div id="um_upload_single" style="display:none">
#
# </div><div id="um_view_photo" style="display:none">
#
# 	<a href="#" data-action="um_remove_modal" class="um-modal-close"><i class="um-faicon-times"></i></a>
#
# 	<div class="um-modal-body photo">
#
# 		<div class="um-modal-photo">
#
# 		</div>
#
# 	</div>
#
# </div>        <div id="fb-root"></div>
#         <script>(function(d, s, id) {
#           var js, fjs = d.getElementsByTagName(s)[0];
#           if (d.getElementById(id)) return;
#           js = d.createElement(s); js.id = id;
#           js.src = "//connect.facebook.net/pt_BR/sdk.js#xfbml=1&appId=&version=v2.3";
#           fjs.parentNode.insertBefore(js, fjs);
#         }(document, 'script', 'facebook-jssdk'));</script>
#     <!-- Instagram Feed JS -->
# <script type="text/javascript">
# var sbiajaxurl = "https://guiadacozinha.com.br/wordpress-core/wp-admin/admin-ajax.php";
# </script>
# <link rel='stylesheet' id='dashicons-css'  href='https://guiadacozinha.com.br/wordpress-core/wp-includes/css/dashicons.min.css?ver=4.9.8' type='text/css' media='all' />
# <link rel='stylesheet' id='thickbox-css'  href='https://guiadacozinha.com.br/wordpress-core/wp-includes/js/thickbox/thickbox.css?ver=4.9.8' type='text/css' media='all' />
# <script type='text/javascript'>
# /* <![CDATA[ */
# var sb_instagram_js_options = {"sb_instagram_at":"","font_method":"svg"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wp-content/plugins/instagram-feed/js/sb-instagram.min.js?ver=1.10.2'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wp-content/themes/guia-da-cozinha/app.min.js?ver=4.9.8'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wp-content/themes/guia-da-cozinha/js/navigation.js?ver=20151215'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wp-content/themes/guia-da-cozinha/js/skip-link-focus-fix.js?ver=20151215'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wp-content/themes/guia-da-cozinha/js/fixTo.js?ver=20151215'></script>
# <script type='text/javascript' src='https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js?ver=4.9.8'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wordpress-core/wp-includes/js/comment-reply.min.js?ver=4.9.8'></script>
# <script type='text/javascript' src='//cdnjs.cloudflare.com/ajax/libs/jquery.touchswipe/1.6.4/jquery.touchSwipe.min.js?ver=4.9.8#asyncload'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wordpress-core/wp-includes/js/imagesloaded.min.js?ver=3.2.0'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wordpress-core/wp-includes/js/masonry.min.js?ver=3.3.2'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wordpress-core/wp-includes/js/jquery/jquery.masonry.min.js?ver=3.1.2b'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/js/select2/select2.full.min.js?ver=2.0.33'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wordpress-core/wp-includes/js/underscore.min.js?ver=1.8.3'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var _wpUtilSettings = {"ajax":{"url":"\/wordpress-core\/wp-admin\/admin-ajax.php"}};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wordpress-core/wp-includes/js/wp-util.min.js?ver=4.9.8'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/js/um-crop.min.js?ver=2.0.33'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/js/um-modal.min.js?ver=2.0.33'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/js/um-jquery-form.min.js?ver=2.0.33'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/js/um-fileupload.min.js?ver=2.0.33'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/js/pickadate/picker.js?ver=2.0.33'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/js/pickadate/picker.date.js?ver=2.0.33'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/js/pickadate/picker.time.js?ver=2.0.33'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/js/pickadate/legacy.js?ver=2.0.33'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/js/pickadate/translations/pt_BR.js?ver=2.0.33'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/js/um-raty.min.js?ver=2.0.33'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/js/um-tipsy.min.js?ver=2.0.33'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/js/um-scrollbar.min.js?ver=2.0.33'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/js/um-functions.min.js?ver=2.0.33'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/js/um-responsive.min.js?ver=2.0.33'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/js/um-conditional.min.js?ver=2.0.33'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var um_scripts = {"nonce":"3269247193"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/js/um-scripts.min.js?ver=2.0.33'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/js/um-members.min.js?ver=2.0.33'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/js/um-profile.min.js?ver=2.0.33'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wp-content/plugins/ultimate-member/assets/js/um-account.min.js?ver=2.0.33'></script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wordpress-core/wp-includes/js/wp-embed.min.js?ver=4.9.8'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var thickboxL10n = {"next":"Pr\u00f3ximo \u00bb","prev":"\u00ab Anterior","image":"Imagem","of":"de","close":"Fechar","noiframes":"Este recurso necessita frames em linha. Os iframes est\u00e3o desativados por voc\u00ea ou seu navegador n\u00e3o os suporta.","loadingAnimation":"https:\/\/guiadacozinha.com.br\/wordpress-core\/wp-includes\/js\/thickbox\/loadingAnimation.gif"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wordpress-core/wp-includes/js/thickbox/thickbox.js?ver=3.1-20121105'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var alm_localize = {"ajaxurl":"https:\/\/guiadacozinha.com.br\/wordpress-core\/wp-admin\/admin-ajax.php","alm_nonce":"3ca037caf9","pluginurl":"https:\/\/guiadacozinha.com.br\/wp-content\/plugins\/ajax-load-more","scrolltop":"false","ajax_object":{"is_single":true,"is_singular":true}};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://guiadacozinha.com.br/wp-content/plugins/ajax-load-more/core/dist/js/ajax-load-more.min.js?ver=4.0'></script>
# 		<script type="text/javascript">
# 			jQuery( '#request' ).val( '' );
# 		</script>
# 	<!-- rd station -->
# <script type="text/javascript" async src="https://d335luupugsy2.cloudfront.net/js/loader-scripts/13c1c734-e6cc-46aa-9238-180db56352fc-loader.js" ></script>
# <!-- /rd station -->
# </body>
# <div class="visible-xs" id='div-gpt-ad-1509539983263-0' style='height:50px; width:320px;position:fixed; bottom:0; left: 0; width: 100%; padding:2 ; z-index:2;'>
# 	<script>
# if( /Android|webOS|iPhone|iPad|iPod|BlackBerry/i.test(navigator.userAgent) ) {
#   googletag.cmd.push(function() { googletag.display('div-gpt-ad-1509539983263-0'); });
# }
# </script>
# </html>
# <div id='banner-1x1' style="width: 0;height: 0;">
# 		</main>
# 	</div>

# %%
recipe = BeautifulSoup(page.text, 'html.parser')
print(recipe)
