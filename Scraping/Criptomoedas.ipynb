# %%
import requests
import pprint
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
page = requests.get("https://coinmarketcap.com/pt-br/")

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html lang="pt-br">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <script type="text/javascript">
#    (window.NREUM||(NREUM={})).loader_config={xpid:"VQ4BV1dWDxACVVZTAAUEUVI="};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(21),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{l?l-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(22),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError",l=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(13),t(12),"addEventListener"in window&&t(6),c.xhrWrappable&&t(14),d=!0)}s.on("fn-start",function(t,e,n){d&&(l+=1)}),s.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(){M++,N=y.hash,this[u]=g.now()}function o(){M--,y.hash!==N&&i(0,!0);var t=g.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+y,e])}function a(t,e){t.on(e,function(){this[e]=g.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,p="cb"+s,l="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,y=w.location,g=t("loader");if(w[v]&&g.xhrWrappable){var b=t(10),x=t(11),E=t(8),O=t(6),P=t(13),R=t(7),T=t(14),L=t(9),j=t("ee"),S=j.get("tracer");t(15),g.features.spa=!0;var N,M=0;j.on(u,r),j.on(p,r),j.on(d,o),j.on(l,o),j.buffer([u,d,"xhr-done","xhr-resolved"]),O.buffer([u]),P.buffer(["setTimeout"+c,"clearTimeout"+s,u]),T.buffer([u,"new-xhr","send-xhr"+s]),R.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),b.buffer([u]),x.buffer(["propagate",p,l,"executor-err","resolve"+s]),S.buffer([u,"no-"+u]),L.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(T,"send-xhr"+s),a(j,"xhr-resolved"),a(j,"xhr-done"),a(R,m+s),a(R,m+"-done"),a(L,"new-jsonp"),a(L,"jsonp-end"),a(L,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,!0),w[v]("load",i,!0),w[v]("popstate",function(){i(0,M>1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(13),s=t(12),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",p="resource",l="-start",h="-end",m="fn"+l,v="fn"+h,w="bstTimer",y="pushState",g=t("loader");g.features.stn=!0,t(8);var b=NREUM.o.EV;o.on(m,function(t,e){var n=t[0];n instanceof b&&(this.bstStart=g.now())}),o.on(v,function(t,e){var n=t[0];n instanceof b&&i("bst",[n,e,this.bstStart,g.now()])}),a.on(m,function(t,e,n){this.bstStart=g.now(),this.bstType=n}),a.on(v,function(t,e){i(w,[e,this.bstStart,g.now(),this.bstType])}),s.on(m,function(){this.bstStart=g.now()}),s.on(v,function(t,e){i(w,[e,this.bstStart,g.now(),"requestAnimationFrame"])}),o.on(y+l,function(t){this.time=g.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.t ...
#   </script>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","queueTime":0,"licenseKey":"6d0ece54b7","agent":"","transactionName":"NFBbY0VUXEEEARUPXg0af0JZVkZbCgxOBV4KW1RWRV5XRgYDEUhHClBORBlBQFMLEQ0HRQZRA1pWR1lXET0CB0E8V0BoVkNTWwkDAwpUPEZMR0dZS20EDg0=","applicationID":"217174376","errorBeacon":"bam.nr-data.net","applicationTime":7}
#   </script>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Capitalizações do Mercado de Criptomoeda | CoinMarketCap
#   </title>
#   <link as="font" crossorigin="" href="https://s2.coinmarketcap.com/static/cloud/fonts/glyphicons-regular.woff2" rel="preload" type="font/woff2"/>
#   <link crossorigin="" href="https://s2.coinmarketcap.com" rel="preconnect"/>
#   <link href="https://files.coinmarketcap.com" rel="preconnect"/>
#   <link href="//www.googletagmanager.com" rel="preconnect"/>
#   <meta content="EDc1reqlQ-zAgeRrrgAxRXNK-Zs9JgpE9a0wdaoSO9A" name="google-site-verification"/>
#   <meta content="website" property="og:type"/>
#   <meta content="CoinMarketCap" property="og:site_name"/>
#   <meta content="https://s2.coinmarketcap.com/static/cloud/img/splash_600x315_1.png" property="og:image"/>
#   <meta content="image/png" property="og:image:type"/>
#   <meta content="600" property="og:image:width"/>
#   <meta content="315" property="og:image:height"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="Capitalizações do Mercado de Criptomoeda | CoinMarketCap" property="og:title">
#    <meta content="Classificações, gráficos, e outros de capitalização do mercado de criptomoeda" name="description">
#     <meta content="Classificações, gráficos, e outros de capitalização do mercado de criptomoeda" property="og:description">
#      <link href="/apple-touch-icon.png" rel="apple-touch-icon"/>
#      <link href="https://coinmarketcap.com/pt-br/" rel="canonical">
#       <meta content="https://coinmarketcap.com/pt-br/" property="og:url"/>
#       <link href="https://coinmarketcap.com/de/" hreflang="de" rel="alternate"/>
#       <link href="https://coinmarketcap.com/" hreflang="en" rel="alternate"/>
#       <link href="https://coinmarketcap.com/es/" hreflang="es" rel="alternate"/>
#       <link href="https://coinmarketcap.com/fil/" hreflang="fil" rel="alternate"/>
#       <link href="https://coinmarketcap.com/fr/" hreflang="fr" rel="alternate"/>
#       <link href="https://coinmarketcap.com/hi/" hreflang="hi" rel="alternate"/>
#       <link href="https://coinmarketcap.com/it/" hreflang="it" rel="alternate"/>
#       <link href="https://coinmarketcap.com/ja/" hreflang="ja" rel="alternate"/>
#       <link href="https://coinmarketcap.com/ko/" hreflang="ko" rel="alternate"/>
#       <link href="https://coinmarketcap.com/pt-br/" hreflang="pt-br" rel="alternate"/>
#       <link href="https://coinmarketcap.com/ru/" hreflang="ru" rel="alternate"/>
#       <link href="https://coinmarketcap.com/tr/" hreflang="tr" rel="alternate"/>
#       <link href="https://coinmarketcap.com/vi/" hreflang="vi" rel="alternate"/>
#       <link href="https://coinmarketcap.com/zh/" hreflang="zh" rel="alternate"/>
#       <link href="https://coinmarketcap.com/zh-tw/" hreflang="zh-tw" rel="alternate"/>
#       <meta content="app-id=1282107098" name="apple-itunes-app"/>
#       <link href="https://s2.coinmarketcap.com/static/cloud/compressed/base.d1b19bab.min.css" rel="stylesheet"/>
#       <link href="https://files.coinmarketcap.com/static/header_banner/header-banner-production.css" rel="stylesheet"/>
#       <script>
#        function getCookie(e){var n=" "+document.cookie,t=" "+e+"=",i=null,o=0,u=0;return n.length>0&&-1!=(o=n.indexOf(t))&&(o+=t.length,-1==(u=n.indexOf(";",o))&&(u=n.length),i=unescape(n.substring(o,u))),i}
#
#         var DEFAULT_CURRENCY = 'BRL';
#         dataLayer = [{
#             'section': 'Market Cap',
#             'subSection': 'Cryptocurrencies',
#             'firstSessionDate': getCookie('gtm_session_first'),
#             'lastSessionDate': getCookie('gtm_session_last'),
#             'language': 'pt-br',
#             'currency': getCookie('currency') || DEFAULT_CURRENCY,
#             'siteTheme': getCookie('theme') || 'day'
#         }];
#       </script>
#       <script>
#        (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-MNVXW26');
#       </script>
#       <script src="https://s2.coinmarketcap.com/static/cloud/compressed/basehead.443c6f62.min.js">
#       </script>
#       <script type="text/javascript">
#        var PWT={};
#         var notifyId;
#         var googletag = googletag || {};
#         googletag.cmd = googletag.cmd || [];
#         PWT.jsLoaded = function(){
#             (function() {
#                 var gads = document.createElement('script');
#                 var useSSL = 'https:' == document.location.protocol;
#                 gads.src = (useSSL ? 'https:' : 'http:') + '//www.googletagservices.com/tag/js/gpt.js';
#                 var node = document.getElementsByTagName('script')[0];
#                 node.parentNode.insertBefore(gads, node);
#             })();
#         };
#         (function() {
#             var purl = window.location.href;
#             var url = '//ads.pubmatic.com/AdServer/js/pwt/157006/915';
#             var profileVersionId = '';
#             if(purl.indexOf('pwtv=')>0){
#                 var regexp = /pwtv=(.*?)(&|$)/g;
#                 var matches = regexp.exec(purl);
#                 if(matches.length >= 2 && matches[1].length > 0){
#                     profileVersionId = '/'+matches[1];
#                 }
#             }
#             var wtads = document.createElement('script');
#             wtads.async = true;
#             wtads.type = 'text/javascript';
#             wtads.src = url+profileVersionId+'/pwt.js';
#             var node = document.getElementsByTagName('script')[0];
#             node.parentNode.insertBefore(wtads, node);
#         })();
#       </script>
#       <script>
#        var listingsAdSlots = [
#
#                     {
#                         slotName: '/48901027/listings_top',
#                         sizes: [[320, 50], [728, 90], [320, 100]],
#                         slotID: 'div-gpt-ad-1542211140769-0',
#                         mapping: [
#                           { browserSize: [768, 0], slotSizes: [[728, 90]] },
#                           { browserSize: [0, 0], slotSizes: [[320, 50], [320, 100]] }
#                         ]
#                     },
#                     {
#                         slotName: '/48901027/listings_bottom',
#                         sizes: [[320, 50], [728, 90], [320, 100]],
#                         slotID: 'div-gpt-ad-1542211140769-2',
#                         mapping: [
#                           { browserSize: [768, 0], slotSizes: [[728, 90]] },
#                           { browserSize: [0, 0], slotSizes: [[320, 50], [320, 100]] }
#                         ]
#                     },
#                     {
#                         slotName: '/48901027/listings_side',
#                         sizes: [[160, 600]],
#                         slotID: 'div-gpt-ad-1542211140769-1',
#                         mapping: [
#                           { browserSize: [1440, 0], slotSizes: [[160, 600]] },
#                           { browserSize: [0, 0], slotSizes: [] }
#                         ]
#                     }
#
#             ];
#
#           googletag.cmd.push(function() {
#             var slotIds = [];
#
#                 for (var i = 0, slotLen = listingsAdSlots.length; i < slotLen; i++) {
#                     var adSlot = listingsAdSlots[i];
#
#                     var slotMapping = [];
#                     for (var j = 0, mapLen = adSlot.mapping.length; j < mapLen; j++) {
#                           var mapping = adSlot.mapping[j];
#                           slotMapping.push([mapping.browserSize, mapping.slotSizes]);
#                     }
#
#                     googletag.defineSlot(adSlot.slotName, adSlot.sizes[0], adSlot.slotID).
#                         defineSizeMapping(slotMapping).
#                         addService(googletag.pubads());
#                     slotIds.push(adSlot.slotID);
#                 }
#
#
#
#
#
#             notifyId = window.OWT.registerExternalBidders(slotIds);
#
#             var mapping = googletag.sizeMapping()
#               .addSize([1280,0], [1280, 90])
#               .addSize([970,0], [970, 90])
#               .addSize([750,0], [750, 90])
#               .addSize([0,0], [320, 100])
#               .build();
#             var headerBannerSlot = googletag.defineSlot('/48901027/full_width_top', [960, 90], 'div-gpt-ad-1517714727704-0')
#                 .defineSizeMapping(mapping)
#                 .addService(googletag.pubads())
#                 .setCollapseEmptyDiv(true);
#
#             googletag.pubads().addEventListener('slotRenderEnded', function(event) {
#                 if (event.slot === headerBannerSlot) {
#                     var display = document.getElementById('div-gpt-ad-1517714727704-0').style.display,
#                         el = document.getElementById('header-banner-wrapper');
#                     if (display === 'none') {
#                         el.style.display = 'none';
#                     } else {
#                         el.style.visibility = 'visible';
#                     }
#                 }
#             });
#
#             googletag.pubads().enableSingleRequest();
#             googletag.enableServices();
#           });
#       </script>
#       <script>
#        //Load the UAM JavaScript Library
#         !function(a9,a,p,s,t,A,g){if(a[a9])return;function
#         q(c,r){a[a9]._Q.push([c,r])}a[a9]={init:function(){q("i",arguments)},fetchBids:function(){q("f",arguments)},setDisplayBids:function(){},targetingKeys:function(){return[]},_Q:[]};A=p.createElement(s);A.async=!0;A.src=t;g=p.getElementsByTagName(s)[0];g.parentNode.insertBefore(A,g)}("apstag",window,document,"script","//c.amazon-adsystem.com/aax2/apstag.js");
#
#         apstag.init({
#             pubID: '1edde03c-121e-457d-9c35-ad4fca989bac',
#             adServer: 'googletag',
#             bidTimeout: 1e3,
#             simplerGPT: true
#         });
#         googletag.cmd.push(function () {
#             apstag.fetchBids({}, function () {
#                 apstag.setDisplayBids();
#                 window.OWT.notifyExternalBiddingComplete(notifyId);
#             });
#         });
#       </script>
#       <script type="application/ld+json">
#        {
#                 "@context": "http://schema.org",
#                 "@type": "Organization",
#                 "name": "CoinMarketCap",
#                 "url": "https://coinmarketcap.com",
#                 "logo": "https://coinmarketcap.com/apple-touch-icon.png",
#                 "sameAs": [
#                     "https://www.facebook.com/CoinMarketCap/",
#                     "https://twitter.com/coinmarketcap"
#                 ]
#             }
#       </script>
#       <script type="application/ld+json">
#        {
#                 "@context": "http://schema.org",
#                 "@type": "Table",
#                 "about": "Cryptocurrency Prices Today"
#             }
#       </script>
#       <script>
#        window.lazySizesConfig = {
#             expFactor: 4
#         };
#       </script>
#       <script src="https://s2.coinmarketcap.com/static/cloud/compressed/currencies_top.06f5ed29.min.js">
#       </script>
#      </link>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-MNVXW26" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!--[if lt IE 7]>
#             <p class="chromeframe">You are using an <strong>outdated</strong> browser. Please <a href="http://browsehappy.com/">upgrade your browser</a> or <a href="http://www.google.com/chromeframe/?redirect=true">activate Google Chrome Frame</a> to improve your experience.</p>
#         <![endif]-->
#   <script>
#    NightMode.init();
#   </script>
#   <div id="header-banner-wrapper">
#    <div class="centered" id="div-gpt-ad-1517714727704-0">
#     <script>
#      googletag.cmd.push(function() { googletag.display('div-gpt-ad-1517714727704-0'); });
#     </script>
#    </div>
#    <div class="header-banner-close banner-alert-close pointer">
#     ×
#    </div>
#   </div>
#   <script>
#    if (getCookie("header-banner-noshow") === "1") {
#                 document.getElementById('header-banner-wrapper').style.display = 'none';
#             }
#   </script>
#   <header class="global-stats desktop text-small hidden-xs">
#    <div class="container global-stats-container">
#     <div class="pull-right dropdowns-col hidden-sm">
#      <div class="btn-group">
#       <button class="btn btn-default btn-xs dropdown-toggle language-dropdown" data-toggle="dropdown" type="button">
#        <span data-language-dropdown="">
#         English
#        </span>
#        <span class="caret">
#        </span>
#       </button>
#       <ul class="dropdown-menu language-dropdown-menu text-center" role="menu">
#        <li class="pointer">
#         <a data-language-toggle="de" href="/de/">
#          Deutsch
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-language-toggle="en" href="/">
#          English
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-language-toggle="es" href="/es/">
#          Español
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-language-toggle="fil" href="/fil/">
#          Filipino
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-language-toggle="fr" href="/fr/">
#          Français
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-language-toggle="hi" href="/hi/">
#          हिन्दी
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-language-toggle="it" href="/it/">
#          Italiano
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-language-toggle="ja" href="/ja/">
#          日本語
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-language-toggle="ko" href="/ko/">
#          한국어
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-language-toggle="pt-br" href="/pt-br/">
#          Português Brasil
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-language-toggle="ru" href="/ru/">
#          Русский
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-language-toggle="tr" href="/tr/">
#          Türkçe
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-language-toggle="vi" href="/vi/">
#          Tiếng Việt
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-language-toggle="zh" href="/zh/">
#          简体中文
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-language-toggle="zh-tw" href="/zh-tw/">
#          繁體中文
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="btn-group global-currency-dropdown-container" data-global-currency-switch="">
#       <button class="btn btn-default btn-xs dropdown-toggle global-currency-dropdown" data-toggle="dropdown" type="button">
#        <span data-currency-display="">
#         USD
#        </span>
#        <span class="caret">
#        </span>
#       </button>
#       <ul class="dropdown-menu global-currency-dropdown-menu text-center" role="menu">
#        <li class="pointer">
#         <a data-currency-toggle="">
#          USD
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          DKK
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          JPY
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          PLN
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          AUD
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          EUR
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          KRW
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          RUB
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          BRL
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          GBP
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          MXN
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          SEK
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          CAD
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          HKD
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          MYR
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          SGD
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          CHF
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          HUF
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          NOK
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          THB
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          CLP
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          IDR
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          NZD
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          TRY
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          CNY
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          ILS
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          PHP
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          TWD
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          CZK
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          INR
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          PKR
#         </a>
#        </li>
#        <li class="pointer">
#         <a data-currency-toggle="">
#          ZAR
#         </a>
#        </li>
#       </ul>
#      </div>
#      <button class="btn btn-default btn-xs js-theme-switch" title="Day/Night Mode" type="button">
#       <span class="glyphicons glyphicons-moon glyphicons--in-button">
#       </span>
#      </button>
#     </div>
#     <ul class="global-stats-list list-inline hidden js-global-stats text-bold">
#      <li>
#       Criptomoedas:
#       <strong>
#        <a href="/pt-br/all/views/all/">
#         <span class="js-global-stats-cryptocurrencies">
#         </span>
#        </a>
#       </strong>
#      </li>
#      <li>
#       <span class="icon-bullet">
#        •
#       </span>
#       Mercados:
#       <strong>
#        <a href="/pt-br/currencies/volume/24-hour/">
#         <span class="js-global-stats-markets">
#         </span>
#        </a>
#       </strong>
#      </li>
#      <li>
#       <span class="icon-bullet">
#        •
#       </span>
#       Cap. de Mercado:
#       <strong>
#        <a href="/pt-br/charts/">
#         <span class="js-global-stats-market-cap" data-global-currency-market-cap="">
#         </span>
#        </a>
#       </strong>
#      </li>
#      <li>
#       <span class="icon-bullet">
#        •
#       </span>
#       Vol 24h:
#       <strong>
#        <a href="/pt-br/charts/">
#         <span class="js-global-stats-volume" data-global-currency-volume="">
#         </span>
#        </a>
#       </strong>
#      </li>
#      <li>
#       <span class="icon-bullet">
#        •
#       </span>
#       Domínio de BTC:
#       <strong>
#        <a href="/pt-br/charts/#dominance-percentage">
#         <span class="js-global-stats-btc-dominance">
#         </span>
#         %
#        </a>
#       </strong>
#      </li>
#     </ul>
#    </div>
#   </header>
#   <nav class="navbar navbar-default sitenav sitenav--tablet hidden-md hidden-lg">
#    <div class="container">
#     <div class="sitenav-navbar flex-container js-sitenav">
#      <div class="sitenav-menu-toggle">
#       <button aria-expanded="false" class="btn-transparent padding-0x menu-toggle collapsed" data-target="#sitenav-tablet" data-toggle="collapse" type="button">
#        <span class="sr-only">
#         Alternar de navegação
#        </span>
#        <span class="glyphicons glyphicons-menu-hamburger sitenav__main-icon">
#        </span>
#       </button>
#      </div>
#      <div class="sitenav-logo">
#       <a href="/pt-br/">
#        <span class="cmc-logo cmc-logo_color_black cmc-logo_size_responsive">
#        </span>
#       </a>
#      </div>
#      <div class="sitenav-search-box js-sitenav-search-box">
#       <form action="/pt-br/search/" class="navbar-form quick-search-container" role="search">
#        <div class="form-group has-feedback !bottom-margin-0x">
#         <input class="form-control quick-search-box quick-search-box--tablet js-quick-search" name="q" placeholder="Procurar Moedas" type="text"/>
#         <span aria-hidden="true" class="glyphicons glyphicons-remove form-control-feedback js-sitenav-search-collapse">
#         </span>
#        </div>
#       </form>
#      </div>
#      <div class="sitenav-search-trigger js-sitenav-search-trigger">
#       <span class="glyphicons glyphicons-search sitenav__main-icon">
#       </span>
#      </div>
#     </div>
#    </div>
#    <div class="collapse" id="sitenav-tablet">
#     <ul class="list-group text-small bottom-margin-0x">
#      <li class="list-group-item">
#       <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#        Ranking
#        <span class="caret">
#        </span>
#       </a>
#       <ul class="dropdown-menu" role="menu">
#        <li>
#         <a href="/pt-br/">
#          Cap. de Mercado - Top 100
#         </a>
#        </li>
#        <li>
#         <a href="/pt-br/coins/">
#          Cap. de Mercado - Top 100 (Moedas)
#         </a>
#        </li>
#        <li>
#         <a href="/pt-br/tokens/">
#          Cap. de Mercado - Top 100 (Tokens)
#         </a>
#        </li>
#        <li>
#         <a href="/pt-br/rankings/exchanges/">
#          Câmbios - Top 100 (Volume Ajustado)
#         </a>
#        </li>
#        <li>
#         <a href="/pt-br/rankings/exchanges/reported/">
#          Câmbios - Top 100 (Volume Informado)
#         </a>
#        </li>
#        <li>
#         <a href="/pt-br/exchanges/volume/24-hour/">
#          Câmbios - Todos (Volume de 24h)
#         </a>
#        </li>
#        <li>
#         <a href="/pt-br/currencies/volume/24-hour/">
#          Criptomoedas - Todos (Volume de 24h)
#         </a>
#        </li>
#        <li>
#         <a href="/pt-br/currencies/volume/monthly/">
#          Criptomoedas - Todos (Volume de 30d)
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="list-group-item">
#       <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#        Tendência
#        <span class="caret">
#        </span>
#       </a>
#       <ul class="dropdown-menu" role="menu">
#        <li>
#         <a href="/pt-br/gainers-losers/">
#          Ganhadores e Perdedores
#         </a>
#        </li>
#        <li>
#         <a href="/pt-br/new/">
#          Adicionado Recentemente
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="list-group-item">
#       <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#        Ferramentas
#        <span class="caret">
#        </span>
#       </a>
#       <ul class="dropdown-menu" role="menu">
#        <li>
#         <a href="/pt-br/charts/">
#          Gráficos Globais
#         </a>
#        </li>
#        <li>
#         <a href="/pt-br/historical/">
#          Instantâneos Históricos
#         </a>
#        </li>
#        <li>
#         <a href="/pt-br/converter/">
#          Calculadora Conversora de Moeda
#         </a>
#        </li>
#        <li>
#         <a href="/pt-br/glossary/">
#          Cripto Glossário
#         </a>
#        </li>
#        <li>
#         <a href="/pt-br/watchlist/">
#          Lista de interesse
#         </a>
#        </li>
#        <li>
#         <a href="/pt-br/widget/">
#          Widgets do Site
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="list-group-item">
#       <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#        Serviços
#        <span class="caret">
#        </span>
#       </a>
#       <ul class="dropdown-menu" role="menu">
#        <li>
#         <a href="https://coinmarketcap.com/advertising" rel="noopener" target="_blank">
#          Publicidade
#         </a>
#        </li>
#        <li>
#         <a href="/api/" target="_blank">
#          Crypto API
#         </a>
#        </li>
#        <li>
#         <a href="/pt-br/events/">
#          Calendário de eventos
#         </a>
#        </li>
#        <li>
#         <a href="/newsletter/" rel="noopener" target="_blank">
#          Newsletter
#         </a>
#        </li>
#        <li>
#         <a href="https://t.me/CoinMarketCap" rel="nofollow noopener" target="_blank">
#          Telegram
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="list-group-item">
#       <div class="btn-group">
#        <button class="btn btn-default btn-xs dropdown-toggle language-dropdown" data-toggle="dropdown" type="button">
#         <span data-language-dropdown="">
#          English
#         </span>
#         <span class="caret">
#         </span>
#        </button>
#        <ul class="dropdown-menu language-dropdown-menu text-center" role="menu">
#         <li class="pointer">
#          <a data-language-toggle="de" href="/de/">
#           Deutsch
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-language-toggle="en" href="/">
#           English
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-language-toggle="es" href="/es/">
#           Español
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-language-toggle="fil" href="/fil/">
#           Filipino
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-language-toggle="fr" href="/fr/">
#           Français
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-language-toggle="hi" href="/hi/">
#           हिन्दी
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-language-toggle="it" href="/it/">
#           Italiano
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-language-toggle="ja" href="/ja/">
#           日本語
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-language-toggle="ko" href="/ko/">
#           한국어
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-language-toggle="pt-br" href="/pt-br/">
#           Português Brasil
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-language-toggle="ru" href="/ru/">
#           Русский
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-language-toggle="tr" href="/tr/">
#           Türkçe
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-language-toggle="vi" href="/vi/">
#           Tiếng Việt
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-language-toggle="zh" href="/zh/">
#           简体中文
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-language-toggle="zh-tw" href="/zh-tw/">
#           繁體中文
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="btn-group global-currency-dropdown-container" data-global-currency-switch="">
#        <button class="btn btn-default btn-xs dropdown-toggle global-currency-dropdown" data-toggle="dropdown" type="button">
#         <span data-currency-display="">
#          USD
#         </span>
#         <span class="caret">
#         </span>
#        </button>
#        <ul class="dropdown-menu global-currency-dropdown-menu text-center" role="menu">
#         <li class="pointer">
#          <a data-currency-toggle="">
#           USD
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           DKK
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           JPY
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           PLN
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           AUD
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           EUR
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           KRW
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           RUB
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           BRL
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           GBP
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           MXN
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           SEK
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           CAD
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           HKD
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           MYR
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           SGD
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           CHF
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           HUF
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           NOK
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           THB
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           CLP
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           IDR
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           NZD
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           TRY
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           CNY
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           ILS
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           PHP
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           TWD
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           CZK
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           INR
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           PKR
#          </a>
#         </li>
#         <li class="pointer">
#          <a data-currency-toggle="">
#           ZAR
#          </a>
#         </li>
#        </ul>
#       </div>
#       <button class="btn btn-default btn-xs js-theme-switch" title="Day/Night Mode" type="button">
#        <span class="glyphicons glyphicons-moon glyphicons--in-button">
#        </span>
#       </button>
#      </li>
#      <li class="list-group-item">
#       <a href="https://www.facebook.com/CoinMarketCap" rel="noopener" target="_blank">
#        <span class="social social-facebook icon_size_lg icon_color_facebook-blue">
#        </span>
#       </a>
#       <a href="https://twitter.com/CoinMarketCap" rel="noopener" target="_blank">
#        <span class="social social-twitter icon_size_lg icon_color_twitter-blue">
#        </span>
#       </a>
#      </li>
#     </ul>
#    </div>
#   </nav>
#   <header class="global-stats mobile text-small text-bold visible-xs js-global-stats">
#    <div class="global-stats-uncollapsed">
#     Cap. de Mercado:
#     <strong>
#      <a href="/pt-br/charts/">
#       <span class="js-global-stats-market-cap" data-global-currency-market-cap="">
#       </span>
#      </a>
#     </strong>
#     <button aria-controls="global-stats-mobile-1" aria-expanded="false" class="pull-right dropdown-toggle" data-target="#global-stats-mobile-1" data-toggle="collapse">
#      <span class="caret">
#      </span>
#     </button>
#    </div>
#    <div class="collapse" id="global-stats-mobile-1">
#     <ul class="list-group bottom-margin-0x">
#      <li class="list-group-item">
#       Vol 24h:
#       <strong>
#        <a href="/pt-br/charts/">
#         <span class="js-global-stats-volume" data-global-currency-volume="">
#         </span>
#        </a>
#       </strong>
#      </li>
#      <li class="list-group-item">
#       Domínio de BTC:
#       <strong>
#        <a href="/pt-br/charts/#dominance-percentage">
#         <span class="js-global-stats-btc-dominance">
#         </span>
#         %
#        </a>
#       </strong>
#      </li>
#      <li class="list-group-item">
#       Criptomoedas:
#       <strong>
#        <a href="/pt-br/all/views/all/">
#         <span class="js-global-stats-cryptocurrencies">
#         </span>
#        </a>
#       </strong>
#      </li>
#      <li class="list-group-item last">
#       Mercados:
#       <strong>
#        <a href="/pt-br/currencies/volume/24-hour/">
#         <span class="js-global-stats-markets">
#         </span>
#        </a>
#       </strong>
#      </li>
#     </ul>
#    </div>
#   </header>
#   <nav class="navbar navbar-default sitenav sitenav--desktop hidden-xs hidden-sm bottom-margin-1x">
#    <div class="container">
#     <div class="sitenav-block">
#      <a href="/pt-br/">
#       <span class="cmc-logo cmc-logo_color_black cmc-logo_size_lg">
#       </span>
#      </a>
#     </div>
#     <div class="sitenav-block">
#      <ul class="nav navbar-nav">
#       <li class="dropdown">
#        <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#         Ranking
#         <span class="caret">
#         </span>
#        </a>
#        <ul class="dropdown-menu" role="menu">
#         <li>
#          <a href="/pt-br/">
#           Cap. de Mercado - Top 100
#          </a>
#         </li>
#         <li>
#          <a href="/pt-br/coins/">
#           Cap. de Mercado - Top 100 (Moedas)
#          </a>
#         </li>
#         <li>
#          <a href="/pt-br/tokens/">
#           Cap. de Mercado - Top 100 (Tokens)
#          </a>
#         </li>
#         <li>
#          <a href="/pt-br/rankings/exchanges/">
#           Câmbios - Top 100 (Volume Ajustado)
#          </a>
#         </li>
#         <li>
#          <a href="/pt-br/rankings/exchanges/reported/">
#           Câmbios - Top 100 (Volume Informado)
#          </a>
#         </li>
#         <li>
#          <a href="/pt-br/exchanges/volume/24-hour/">
#           Câmbios - Todos (Volume de 24h)
#          </a>
#         </li>
#         <li>
#          <a href="/pt-br/currencies/volume/24-hour/">
#           Criptomoedas - Todos (Volume de 24h)
#          </a>
#         </li>
#         <li>
#          <a href="/pt-br/currencies/volume/monthly/">
#           Criptomoedas - Todos (Volume de 30d)
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="dropdown">
#        <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#         Tendência
#         <span class="caret">
#         </span>
#        </a>
#        <ul class="dropdown-menu" role="menu">
#         <li>
#          <a href="/pt-br/gainers-losers/">
#           Ganhadores e Perdedores
#          </a>
#         </li>
#         <li>
#          <a href="/pt-br/new/">
#           Adicionado Recentemente
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="dropdown">
#        <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#         Ferramentas
#         <span class="caret">
#         </span>
#        </a>
#        <ul class="dropdown-menu" role="menu">
#         <li>
#          <a href="/pt-br/charts/">
#           Gráficos Globais
#          </a>
#         </li>
#         <li>
#          <a href="/pt-br/historical/">
#           Instantâneos Históricos
#          </a>
#         </li>
#         <li>
#          <a href="/pt-br/converter/">
#           Calculadora Conversora de Moeda
#          </a>
#         </li>
#         <li>
#          <a href="/pt-br/glossary/">
#           Cripto Glossário
#          </a>
#         </li>
#         <li>
#          <a href="/pt-br/watchlist/">
#           Lista de interesse
#          </a>
#         </li>
#         <li>
#          <a href="/pt-br/widget/">
#           Widgets do Site
#          </a>
#         </li>
#        </ul>
#        <li class="dropdown">
#         <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#          Serviços
#          <span class="caret">
#          </span>
#         </a>
#         <ul class="dropdown-menu" role="menu">
#          <li>
#           <a href="https://coinmarketcap.com/advertising" rel="noopener" target="_blank">
#            Publicidade
#           </a>
#          </li>
#          <li>
#           <a href="/api/" target="_blank">
#            Crypto API
#           </a>
#          </li>
#          <li>
#           <a href="/pt-br/events/">
#            Calendário de eventos
#           </a>
#          </li>
#          <li>
#           <a href="/newsletter/" rel="noopener" target="_blank">
#            Newsletter
#           </a>
#          </li>
#          <li>
#           <a href="https://t.me/CoinMarketCap" rel="nofollow noopener" target="_blank">
#            Telegram
#           </a>
#          </li>
#         </ul>
#        </li>
#       </li>
#      </ul>
#     </div>
#     <div class="sitenav-block">
#      <form action="/pt-br/search/" class="navbar-form quick-search-container" role="search">
#       <div class="form-group has-feedback">
#        <input class="form-control quick-search-box js-quick-search" name="q" placeholder="Procurar Moedas" type="text"/>
#        <span aria-hidden="true" class="glyphicons glyphicons-search form-control-feedback">
#        </span>
#       </div>
#      </form>
#     </div>
#    </div>
#   </nav>
#   <div class="container main-section">
#    <div class="row">
#     <div class="col-xl-10 padding-top-1x">
#      <div class="text-center" id="leaderboard">
#       <div class="responsive-leaderboard" id="div-gpt-ad-1542211140769-0">
#        <script>
#         googletag.cmd.push(function() { googletag.display('div-gpt-ad-1542211140769-0'); });
#        </script>
#       </div>
#      </div>
#      <div class="row">
#       <div class="col-xs-12">
#        <div class="header header-1x">
#         <h1 class="text-center h2">
#          Top 100 Criptomoedas por Capitalização de Mercado
#         </h1>
#        </div>
#       </div>
#      </div>
#      <div class="row bottom-margin-1x">
#       <div class="col-xs-12">
#        <div>
#         <div class="pull-right margin-bottom--lv1">
#          <div class="pull-left">
#           <div class="btn-group" id="currency-switch">
#            <button class="btn btn-default dropdown-toggle" data-toggle="dropdown" id="currency-switch-button" type="button">
#             USD
#             <span class="caret">
#             </span>
#            </button>
#            <ul class="dropdown-menu" role="menu">
#             <li class="pointer" data-fiat-item="">
#              <a class="price-toggle" data-currency="usd" data-fiat="">
#               USD
#              </a>
#             </li>
#             <li class="pointer">
#              <a class="price-toggle" data-currency="usd">
#               USD
#              </a>
#             </li>
#             <li class="pointer">
#              <a class="price-toggle" data-currency="btc" data-currencyid="bitcoin">
#               BTC
#              </a>
#             </li>
#             <li class="pointer">
#              <a class="price-toggle" data-currency="eth" data-currencyid="ethereum">
#               ETH
#              </a>
#             </li>
#             <li class="pointer">
#              <a class="price-toggle" data-currency="xrp" data-currencyid="ripple">
#               XRP
#              </a>
#             </li>
#             <li class="pointer">
#              <a class="price-toggle" data-currency="bch" data-currencyid="bitcoin-cash">
#               BCH
#              </a>
#             </li>
#             <li class="pointer">
#              <a class="price-toggle" data-currency="ltc" data-currencyid="litecoin">
#               LTC
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#          <ul class="pull-left margin-left--lv1 pagination top-paginator">
#           <li>
#            <a href="2">
#             Seguinte 100 →
#            </a>
#           </li>
#           <li>
#            <a href="/pt-br/all/views/all/">
#             Ver Todos
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="pull-left">
#          <ul class="nav nav-tabs text-left no-border-bottom" id="category-tabs" role="tablist">
#           <li class="visible-xs active">
#            <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#             Ranking
#             <span class="caret">
#             </span>
#            </a>
#            <ul class="dropdown-menu" role="menu">
#             <li class="section-heading">
#              Todas as Criptomoedas
#             </li>
#             <li>
#              <a href="/pt-br/">
#               Top 100
#              </a>
#             </li>
#             <li>
#              <a href="/pt-br/all/views/all/">
#               Lista Completa
#              </a>
#             </li>
#             <li class="section-heading">
#              Somente moedas
#             </li>
#             <li>
#              <a href="/pt-br/coins/">
#               Top 100
#              </a>
#             </li>
#             <li>
#              <a href="/pt-br/coins/views/all/">
#               Lista Completa
#              </a>
#             </li>
#             <li class="divider">
#             </li>
#             <li>
#              <a href="/pt-br/coins/">
#               Capitalização de Mercado por Fornecimento Circulante
#              </a>
#             </li>
#             <li>
#              <a href="/pt-br/coins/views/market-cap-by-total-supply/">
#               Capitalização de Mercado por Fornecimento Total
#              </a>
#             </li>
#             <li>
#              <a href="/pt-br/coins/views/filter-non-mineable/">
#               Filtro Não Minerável
#              </a>
#             </li>
#             <li class="section-heading">
#              Somente tokens
#             </li>
#             <li>
#              <a href="/pt-br/tokens/">
#               Top 100
#              </a>
#             </li>
#             <li>
#              <a href="/pt-br/tokens/views/all/">
#               Lista Completa
#              </a>
#             </li>
#             <li class="divider">
#             </li>
#             <li>
#              <a href="/pt-br/tokens/">
#               Capitalização de Mercado por Fornecimento Circulante
#              </a>
#             </li>
#             <li>
#              <a href="/pt-br/tokens/views/market-cap-by-total-supply/">
#               Capitalização de Mercado por Fornecimento Total
#              </a>
#             </li>
#             <li class="section-heading visible-xs">
#              Trocas
#             </li>
#             <li class="visible-xs">
#              <a href="/pt-br/rankings/exchanges/">
#               Top 100 por volume ajustado
#              </a>
#             </li>
#             <li class="visible-xs">
#              <a href="/pt-br/rankings/exchanges/reported/">
#               Top 100 por volume informado
#              </a>
#             </li>
#            </ul>
#           </li>
# ...
#          <strong>
#           0x0074709077B8AE5a245E4ED161C971Dc4c3C8E2B
#          </strong>
#          <br>
#           <img alt="Doar Ethereum" src="https://s2.coinmarketcap.com/static/cloud/img/qrcodes/donate_ethereum.png"/>
#           <br>
#           </br>
#          </br>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div aria-hidden="true" aria-labelledby="donate_bch_label" class="modal fade" id="donate_bch" role="dialog" tabindex="-1">
#       <div class="modal-dialog">
#        <div class="modal-content">
#         <div class="modal-header text-center">
#          <button aria-hidden="true" class="close" data-dismiss="modal" type="button">
#           ×
#          </button>
#          <h4 class="modal-title" id="donate_bch_label">
#           Doar Bitcoin Cash
#          </h4>
#         </div>
#         <div class="modal-body text-center">
#          <strong>
#           1LVXG4Z4oF6TrJfmUfSuLX8nqb8c5eCwha
#          </strong>
#          <br>
#           <img alt="Doar Bitcoin Cash" src="https://s2.coinmarketcap.com/static/cloud/img/qrcodes/donate_bitcoin_cash.png"/>
#           <br>
#           </br>
#          </br>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="col-xl-2 padding-top-2x">
#      <div class="pull-right visible-xl">
#       <div class="skyscraper" id="div-gpt-ad-1542211140769-1">
#        <script>
#         googletag.cmd.push(function() { googletag.display('div-gpt-ad-1542211140769-1'); });
#        </script>
#       </div>
#      </div>
#      <div class="clearfix">
#      </div>
#     </div>
#    </div>
#   </div>
#   <footer>
#    <div class="container flex-container">
#     <div class="footer-section footer-section--brand text-center">
#      <div class="margin-bottom--lv1">
#       <span class="cmc-logo cmc-logo_color_grey cmc-logo_size_md footer__cmc-logo">
#       </span>
#      </div>
#      <div class="text-gray-light">
#       © 2019 CoinMarketCap
#      </div>
#     </div>
#     <div class="footer-section footer-section--links">
#      <section class="margin-bottom--lv2">
#       <h5 class="footer-header">
#        Links úteis
#       </h5>
#       <div class="row">
#        <div class="col-xs-6">
#         <ul class="list-unstyled">
#          <li>
#           <a href="/advertising/" target="_blank">
#            Anunciar
#           </a>
#          </li>
#          <li>
#           <a href="/api/" target="_blank">
#            Crypto API
#           </a>
#          </li>
#          <li>
#           <a href="/pt-br/disclaimer/">
#            Aviso legal
#           </a>
#          </li>
#          <li>
#           <a href="/pt-br/privacy/">
#            Privacidade
#           </a>
#          </li>
#          <li>
#           <a href="/pt-br/terms/">
#            Termos
#           </a>
#          </li>
#          <li>
#           <a href="/pt-br/faq/">
#            Perguntas Frequentes
#           </a>
#          </li>
#          <li>
#           <a href="/pt-br/methodology/">
#            Methodology
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="col-xs-6">
#         <ul class="list-unstyled">
#          <li>
#           <a href="/request/" target="_blank">
#            Formulário de Pedido
#           </a>
#          </li>
#          <li>
#           <a href="/careers/">
#            Carreiras
#           </a>
#          </li>
#          <li>
#           <a href="https://blog.coinmarketcap.com" rel="noopener" target="_blank">
#            Blog
#           </a>
#          </li>
#          <li>
#           <a href="/newsletter/" target="_blank">
#            Newsletter
#           </a>
#          </li>
#          <li>
#           <a href="https://www.facebook.com/CoinMarketCap" rel="noopener" target="_blank">
#            Facebook
#           </a>
#          </li>
#          <li>
#           <a href="https://twitter.com/CoinMarketCap" rel="noopener" target="_blank">
#            Twitter
#           </a>
#          </li>
#          <li>
#           <a href="https://t.me/CoinMarketCap" rel="nofollow noopener" target="_blank">
#            Telegram
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </section>
#      <section class="margin-bottom--lv2">
#       <div class="row">
#        <div class="col-xs-6">
#         <h5 class="footer-header">
#          Modo noturno
#         </h5>
#         <div class="btn-group" data-toggle="buttons">
#          <label class="btn btn-default btn-sm" data-night-mode-off="">
#           <input type="radio"/>
#           Off
#          </label>
#          <label class="btn btn-default btn-sm" data-night-mode-on="">
#           <input type="radio"/>
#           On
#          </label>
#         </div>
#        </div>
#        <div class="col-xs-6">
#         <h5 class="footer-header">
#          Downloads
#         </h5>
#         <a href="https://appstore.com/coinmarketcapcom/" rel="noopener" target="_blank">
#          <span class="app-store-badge">
#          </span>
#         </a>
#        </div>
#       </div>
#      </section>
#     </div>
#     <div class="footer-section footer-section--donate overflow-ellipsis">
#      <section class="margin-bottom--lv2">
#       <h5 class="footer-header">
#        Doar
#       </h5>
#       <ul class="list-unstyled">
#        <li class="overflow-ellipsis">
#         BTC:
#         <a data-target="#donate_btc" data-toggle="modal">
#          3CMCRgEm8HVz3DrWaCCid3vAANE42jcEv9
#         </a>
#        </li>
#        <li class="overflow-ellipsis">
#         LTC:
#         <a data-target="#donate_ltc" data-toggle="modal">
#          LTdsVS8VDw6syvfQADdhf2PHAm3rMGJvPX
#         </a>
#        </li>
#        <li class="overflow-ellipsis">
#         ETH:
#         <a data-target="#donate_eth" data-toggle="modal">
#          0x0074709077B8AE5a245E4ED161C971Dc4c3C8E2B
#         </a>
#        </li>
#        <li class="overflow-ellipsis">
#         BCH:
#         <a data-target="#donate_bch" data-toggle="modal">
#          1LVXG4Z4oF6TrJfmUfSuLX8nqb8c5eCwha
#         </a>
#        </li>
#       </ul>
#      </section>
#     </div>
#    </div>
#   </footer>
#   <div class="banner-alert banner-alert-fixed-bottom hide js-cookie-policy-banner">
#    <div class="banner-alert-close">
#     <button aria-label="Close" class="banner-alert-close-button js-close" type="button">
#      <span aria-hidden="true">
#       ×
#      </span>
#     </button>
#    </div>
#    <div class="banner-alert-body">
#     Usamos cookies para lhe oferecer uma experiência de navegação melhor, analisar o tráfego do site, personalizar conteúdo e exibir publicidade direcionada. Leia mais sobre como usamos cookies e como você pode controlá-los na nossa
#     <a href="/pt-br/privacy/">
#      Política de Privacidade
#     </a>
#     . Se você continuar a usar este site, estará permitindo o uso de cookies por nós.
#    </div>
#   </div>
#   <div data-aed="0.272256121134" data-all="0.00906526666556" data-amd="0.00205310574404" data-ars="0.0250033123138" data-aud="0.708275490835" data-azn="0.587371512482" data-bam="0.578649120482" data-bch="157.002173998" data-bdt="0.0119103505532" data-bgn="0.579491114083" data-bhd="2.65399120467" data-bmd="1.0" data-bob="0.144699330708" data-brl="0.262261650056" data-btc="4033.33281612" data-byn="0.468951649209" data-cad="0.749471809742" data-chf="0.997980088301" data-clp="0.00149254999788" data-cny="0.148954155635" data-cop="0.000318506998496" data-crc="0.00166300250672" data-cup="0.0388349514563" data-czk="0.0441551789609" data-dkk="0.151776989819" data-dop="0.0197620756756" data-dzd="0.00840437177603" data-egp="0.0574630081885" data-eth="140.4555147" data-eur="1.1326875504" data-gbp="1.32945133543" data-gel="0.373134328358" data-ghs="0.178923524507" data-gtq="0.129971744143" data-hkd="0.127399002848" data-hnl="0.0408105647452" data-hrk="0.152766610963" data-huf="0.00360212038672" data-idr="7.0175993105e-05" data-ils="0.278124119563" data-inr="0.014500145335" data-iqd="0.000838895790564" data-irr="2.37501484384e-05" data-isk="0.00852232701389" data-jmd="0.0080195011171" data-jod="1.41043524621" data-jpy="0.00896865008363" data-kes="0.00997914149865" data-kgs="0.014556509235" data-khr="0.000250453748747" data-krw="0.000881754319207" data-kwd="3.29085930918" data-kzt="0.00263587557716" data-lbp="0.000662930268369" data-lkr="0.00559852830367" data-ltc="61.4149966485" data-mad="0.104283235771" data-mdl="0.0580498006918" data-mkd="0.0184416591474" data-mmk="0.000652250966286" data-mnt="0.000398687256822" data-mur="0.0288177603165" data-mxn="0.0520222072398" data-myr="0.244379933573" data-nad="0.0692529072544" data-ngn="0.00277184076435" data-nio="0.0304299462318" data-nok="0.117240001538" data-npr="0.0090501802357" data-nzd="0.68450017797" data-omr="2.59886065949" data-pab="1.0" data-pen="0.303232825802" data-php="0.0190054999636" data-pkr="0.00716231582481" data-pln="0.263450949253" data-qar="0.274633529019" data-ron="0.237959374624" data-rsd="0.00960173519486" data-rub="0.0154251053369" data-sar="0.26664533504" data-sek="0.108300496623" data-sgd="0.739326163348" data-ssp="0.00767675340886" data-thb="0.0315616715061" data-tnd="0.332724115478" data-try="0.183490615372" data-ttd="0.147385738101" data-twd="0.0324001107825" data-uah="0.0370464125236" data-ugx="0.000270235589257" data-usd="1.0" data-uyu="0.0298861761074" data-uzs="0.000119338331898" data-ves="0.00030381133855" data-vnd="4.31374807341e-05" data-xag="15.3009732031" data-xau="1302.0494258" data-xpd="1562.5" data-xpt="851.723462426" data-xrp="0.317585973329" data-zar="0.0692934905002" id="currency-exchange-rates">
#   </div>
#   <div data-bch1h="-0.912785" data-bch24h="-0.0763888" data-bch7d="18.0777" data-btc1h="-0.131693" data-btc24h="-0.326283" data-btc7d="2.11772" data-eth1h="-0.124212" data-eth24h="-1.34248" data-eth7d="2.68964" data-ltc1h="-0.338247" data-ltc24h="-0.39398" data-ltc7d="7.2939" data-xrp1h="-0.246665" data-xrp24h="-0.978406" data-xrp7d="1.18801" id="percentage_gains_data">
#   </div>
#   <div class="scroll-to-top">
#    <button class="btn">
#     <span class="glyphicons glyphicons-chevron-up">
#     </span>
#    </button>
#   </div>
#   <script>
#    var LANG_CODE = 'pt-br';
#             var STATIC_DOMAIN = 's2.coinmarketcap.com';
#   </script>
#   <script src="https://s2.coinmarketcap.com/static/cloud/compressed/base.70d9e6c1.min.js">
#   </script>
#   <script src="https://s2.coinmarketcap.com/static/cloud/compressed/currencies_main.0ee673d6.min.js">
#   </script>
#   <script>
#    const PHRASES = {
#             emptyTable: "Nenhum registro encontrado",
#     zeroRecords: "Nenhum registro encontrado",
#     sortAscending: ": Ordenar colunas de forma ascendente",
#     sortDescending: ": Ordenar colunas de forma descendente",
#             'K': "Mil",
#     'M': "Mi",
#     'B': "Bi",
#     'T': "Tr"
#         };
#         var polyglot = new Polyglot({phrases: PHRASES});
#
#         var watchlistStore = WatchlistStore();
#         var watchlistActions = $.map($('[data-more-options]'), function (elem) {
#             return new WatchlistAction({
#                 element: elem,
#                 watchlistStore: watchlistStore,
#                 watchlistIsFull: watchlistStore.isFull()
#             });
#         });
#         $(document).on(watchlistStore.WATCHLIST_AT_CAPACITY, function (event) {
#             for (var i=0; i < watchlistActions.length; i++) {
#                 watchlistActions[i].render({watchlistIsFull: true});
#             }
#         });
#         $(document).on(watchlistStore.WATCHLIST_UNDER_CAPACITY, function (event) {
#             for (var i=0; i < watchlistActions.length; i++) {
#                 watchlistActions[i].render({watchlistIsFull: false});
#             }
#         });
#   </script>
#   <script>
#    $( document ).ready(function() {
#                 // GTM Session Set
#                 var maxExpire = new Date('2038-01-19 00:00:00');
#                 if (Cookies.get("gtm_session_first") === undefined) {
#                     Cookies.set("gtm_session_first", new Date(), {expires: maxExpire})
#                 }
#
#                 Cookies.set("gtm_session_last", new Date(), {expires: maxExpire})
#
#                 // Header Banner Prefs
#                 $(".header-banner-close").on('click', function () {
#                     Cookies.set("header-banner-noshow", "1", {expires: 1})
#                     $('#header-banner-wrapper').fadeOut();
#                     dataLayer.push({
#                         'event': 'customEvent',
#                         'eventCategory': 'Header Banner',
#                         'eventAction': 'Close',
#                     });
#                 });
#
#             });
#
#             (function () {
#                 var polyglot = new Polyglot({phrases: {
#                     cryptocurrencies: "Criptomoedas",
#                     exchanges: "Trocas"
#                 }});
#
#                 initQuickSearch({
#                     currencyDataURL: 'https://' + STATIC_DOMAIN + '/generated/search/quick_search.json',
#                     exchangeDataURL: 'https://' + STATIC_DOMAIN + '/generated/search/quick_search_exchanges.json',
#                     currencySuggestionTemplate: function (context) {
#                         var template = "/pt-br/currencies/%25s/";
#                         context.url = template.replace('%25s', context.slug);
#                         return Handlebars.templates['quick_search'](context);
#                     },
#                     exchangeSuggestionTemplate: function (context) {
#                         var template = "/pt-br/exchanges/%25s/";
#                         context.url = template.replace('%25s', context.slug);
#                         return Handlebars.templates['quick_search_exchanges'](context);
#                     },
#                     currencyLimit: 6,
#                     exchangeLimit: 4
#                 }, polyglot);
#                 SiteNav('.js-sitenav');
#
#                 $('[data-language-toggle]').on('click', function () {
#                     dataLayer.push({
#                         'event': 'customEvent',
#                         'eventCategory': 'Language Dropdown',
#                         'eventAction': 'Language Selected',
#                         'eventLabel': $(this).data('language-toggle')
#                     });
#                 });
#
#                 var language = $('[data-language-toggle="' + 'pt-br' + '"]').html();
#                 $('[data-language-dropdown]').html(language);
#
#                 NightMode.initSwitch();
#                 ThemeSwitch('.js-theme-switch');
#                 ScrollToTop('.scroll-to-top');
#                 CookiedDismissableAlert({
#                     selector: '.js-cookie-policy-banner',
#                     cookieKey: 'cmc_gdpr_hide'
#                 });
#             })();
#
#             function userResizedBrowser(actionType) {
#                 var actions = {
#                     mobileToDesktop: 'Mobile to Desktop',
#                     desktopToMobile: 'Desktop to Mobile',
#                     noSidebarToSidebar: 'No Sidebar to Sidebar',
#                     sidebarToNoSidebar: 'Sidebar to No Sidebar'
#                 };
#                 var action = actions[actionType];
#                 if (action) {
#                     return function () {
#                         dataLayer.push({
#                             'event': 'customEvent',
#                             'eventCategory': 'Browser Resize',
#                             'eventAction': action,
#                             'eventLabel': undefined
#                         });
#                     }
#                 }
#             }
#             MOBILE.onBrowserResize(userResizedBrowser('mobileToDesktop'), userResizedBrowser('desktopToMobile'));
#             $(function () {
#                 var sidebarThreshold = 1440;
#                 var isWider = $(window).width() >= sidebarThreshold;
#                 $(window).on('resize', function() {
#                     var screenWidth = $(window).width();
#                     if (isWider && screenWidth < sidebarThreshold) {
#                         isWider = false;
#                         userResizedBrowser('sidebarToNoSidebar')();
#                     } else if (!isWider && screenWidth >= sidebarThreshold) {
#                         isWider = true;
#                         userResizedBrowser('noSidebarToSidebar')();
#                     }
#                 });
#             });
#   </script>
#  </body>
# </html>

# %%
table = soup.find('table', attrs={'id':'currencies'})
table_body = table.find('tbody')

# %%
print(table_body.prettify())
# Out:
# <tbody>
#  <tr class="" id="id-bitcoin">
#   <td class="text-center">
#    1
#   </td>
#   <td class="no-wrap currency-name" data-sort="Bitcoin">
#    <img alt="Bitcoin" class="logo-sprite" height="16" src="https://s2.coinmarketcap.com/static/img/coins/32x32/1.png" width="16"/>
#    <span class="currency-symbol visible-xs">
#     <a class="link-secondary" href="/pt-br/currencies/bitcoin/">
#      BTC
#     </a>
#    </span>
#    <br class="visible-xs"/>
#    <a class="currency-name-container link-secondary" href="/pt-br/currencies/bitcoin/">
#     Bitcoin
#    </a>
#   </td>
#   <td class="no-wrap market-cap text-right" data-btc="17594437.0" data-sort="70964220133.3" data-usd="70964220133.3">
#    $70,964,220,133
#   </td>
#   <td class="no-wrap text-right" data-sort="4033.33281612">
#    <a class="price" data-btc="1.0" data-usd="4033.33281612" href="/pt-br/currencies/bitcoin/#markets">
#     $4033.33
#    </a>
#   </td>
#   <td class="no-wrap text-right" data-sort="8235070287.75">
#    <a class="volume" data-btc="2044159.63716" data-usd="8235070287.75" href="/pt-br/currencies/bitcoin/#markets">
#     $8,235,070,288
#    </a>
#   </td>
#   <td class="no-wrap text-right circulating-supply" data-sort="17594437.0">
#    <span data-supply="17594437.0">
#     <span data-supply-container="">
#      17,594,437
#     </span>
#     <span class="hidden-xs">
#      BTC
#     </span>
#    </span>
#   </td>
#   <td class="no-wrap percent-change negative_change text-right" data-percentusd="-0.326283" data-sort="-0.326283" data-symbol="BTC" data-timespan="24h">
#    -0.33%
#   </td>
#   <td>
#    <a href="/pt-br/currencies/bitcoin/#charts">
#     <img alt="sparkline" class="sparkline" src="https://s2.coinmarketcap.com/generated/sparklines/web/7d/usd/1.png"/>
#    </a>
#   </td>
#   <td class="dropdown" data-cc-id="1" data-cc-slug="bitcoin" data-more-options="">
#    <button class="btn btn-transparent dropdown-toggle" data-toggle="dropdown" id="dropdown-menu-1" type="button">
#     <span class="glyphicons glyphicons-more text-gray">
#     </span>
#    </button>
#    <ul aria-labelledby="dropdown-menu-1" class="dropdown-menu dropdown-menu-right" role="menu">
#     <li role="presentation">
#      <a data-watchlist-add="" href="#" role="menuitem" tabindex="-1">
#       Adicionar à lista de interesse
#      </a>
#     </li>
#     <li role="presentation">
#      <a data-watchlist-remove="" href="#" role="menuitem" tabindex="-1">
#       Remover da lista de interesse
#      </a>
#     </li>
#     <li class="disabled" role="presentation">
#      <a data-watchlist-full="" href="#" role="menuitem" tabindex="-1">
#       Lista de interesse cheia!
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/bitcoin/#charts" role="menuitem" tabindex="-1">
#       Ver gráfico
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/bitcoin/#markets" role="menuitem" tabindex="-1">
#       Ver mercados
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/bitcoin/historical-data/" role="menuitem" tabindex="-1">
#       Ver dados históricos
#      </a>
#     </li>
#    </ul>
#   </td>
#  </tr>
#  <tr class="" id="id-ethereum">
#   <td class="text-center">
#    2
#   </td>
#   <td class="no-wrap currency-name" data-sort="Ethereum">
#    <img alt="Ethereum" class="logo-sprite" height="16" src="https://s2.coinmarketcap.com/static/img/coins/32x32/1027.png" width="16"/>
#    <span class="currency-symbol visible-xs">
#     <a class="link-secondary" href="/pt-br/currencies/ethereum/">
#      ETH
#     </a>
#    </span>
#    <br class="visible-xs"/>
#    <a class="currency-name-container link-secondary" href="/pt-br/currencies/ethereum/">
#     Ethereum
#    </a>
#   </td>
#   <td class="no-wrap market-cap text-right" data-btc="3670517.04171" data-sort="14786988883.6" data-usd="14786988883.6">
#    $14,786,988,884
#   </td>
#   <td class="no-wrap text-right" data-sort="140.4555147">
#    <a class="price" data-btc="0.0348647290105" data-usd="140.4555147" href="/pt-br/currencies/ethereum/#markets">
#     $140.46
#    </a>
#   </td>
#   <td class="no-wrap text-right" data-sort="3837718887.51">
#    <a class="volume" data-btc="952622.111834" data-usd="3837718887.51" href="/pt-br/currencies/ethereum/#markets">
#     $3,837,718,888
#    </a>
#   </td>
#   <td class="no-wrap text-right circulating-supply" data-sort="105278805.999">
#    <span data-supply="105278805.999">
#     <span data-supply-container="">
#      105,278,806
#     </span>
#     <span class="hidden-xs">
#      ETH
#     </span>
#    </span>
#   </td>
#   <td class="no-wrap percent-change negative_change text-right" data-percentusd="-1.34248" data-sort="-1.34248" data-symbol="ETH" data-timespan="24h">
#    -1.34%
#   </td>
#   <td>
#    <a href="/pt-br/currencies/ethereum/#charts">
#     <img alt="sparkline" class="sparkline" src="https://s2.coinmarketcap.com/generated/sparklines/web/7d/usd/1027.png"/>
#    </a>
#   </td>
#   <td class="dropdown" data-cc-id="1027" data-cc-slug="ethereum" data-more-options="">
#    <button class="btn btn-transparent dropdown-toggle" data-toggle="dropdown" id="dropdown-menu-1027" type="button">
#     <span class="glyphicons glyphicons-more text-gray">
#     </span>
#    </button>
#    <ul aria-labelledby="dropdown-menu-1027" class="dropdown-menu dropdown-menu-right" role="menu">
#     <li role="presentation">
#      <a data-watchlist-add="" href="#" role="menuitem" tabindex="-1">
#       Adicionar à lista de interesse
#      </a>
#     </li>
#     <li role="presentation">
#      <a data-watchlist-remove="" href="#" role="menuitem" tabindex="-1">
#       Remover da lista de interesse
#      </a>
#     </li>
#     <li class="disabled" role="presentation">
#      <a data-watchlist-full="" href="#" role="menuitem" tabindex="-1">
#       Lista de interesse cheia!
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/ethereum/#charts" role="menuitem" tabindex="-1">
#       Ver gráfico
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/ethereum/#markets" role="menuitem" tabindex="-1">
#       Ver mercados
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/ethereum/historical-data/" role="menuitem" tabindex="-1">
#       Ver dados históricos
#      </a>
#     </li>
#    </ul>
#   </td>
#  </tr>
#  <tr class="" id="id-ripple">
#   <td class="text-center">
#    3
#   </td>
#   <td class="no-wrap currency-name" data-sort="XRP">
#    <img alt="XRP" class="logo-sprite" height="16" src="https://s2.coinmarketcap.com/static/img/coins/32x32/52.png" width="16"/>
#    <span class="currency-symbol visible-xs">
#     <a class="link-secondary" href="/pt-br/currencies/ripple/">
#      XRP
#     </a>
#    </span>
#    <br class="visible-xs"/>
#    <a class="currency-name-container link-secondary" href="/pt-br/currencies/ripple/">
#     XRP
#    </a>
#   </td>
#   <td class="no-wrap market-cap text-right" data-btc="3266225.74021" data-sort="13158267122.3" data-usd="13158267122.3">
#    $13,158,267,122
#   </td>
#   <td class="no-wrap text-right" data-sort="0.317585973329">
#    <a class="price" data-btc="7.88331374625e-05" data-usd="0.317585973329" href="/pt-br/currencies/ripple/#markets">
#     $0.317586
#    </a>
#   </td>
#   <td class="no-wrap text-right" data-sort="536291872.979">
#    <a class="volume" data-btc="133121.656789" data-usd="536291872.979" href="/pt-br/currencies/ripple/#markets">
#     $536,291,873
#    </a>
#   </td>
#   <td class="no-wrap text-right circulating-supply" data-sort="41432141931.0">
#    <span data-supply="41432141931.0">
#     <span data-supply-container="">
#      41,432,141,931
#     </span>
#     <span class="hidden-xs">
#      XRP
#     </span>
#    </span>
#    *
#   </td>
#   <td class="no-wrap percent-change negative_change text-right" data-percentusd="-0.978406" data-sort="-0.978406" data-symbol="XRP" data-timespan="24h">
#    -0.98%
#   </td>
#   <td>
#    <a href="/pt-br/currencies/ripple/#charts">
#     <img alt="sparkline" class="sparkline" src="https://s2.coinmarketcap.com/generated/sparklines/web/7d/usd/52.png"/>
#    </a>
#   </td>
#   <td class="dropdown" data-cc-id="52" data-cc-slug="ripple" data-more-options="">
#    <button class="btn btn-transparent dropdown-toggle" data-toggle="dropdown" id="dropdown-menu-52" type="button">
#     <span class="glyphicons glyphicons-more text-gray">
#     </span>
#    </button>
#    <ul aria-labelledby="dropdown-menu-52" class="dropdown-menu dropdown-menu-right" role="menu">
#     <li role="presentation">
#      <a data-watchlist-add="" href="#" role="menuitem" tabindex="-1">
#       Adicionar à lista de interesse
#      </a>
#     </li>
#     <li role="presentation">
#      <a data-watchlist-remove="" href="#" role="menuitem" tabindex="-1">
#       Remover da lista de interesse
#      </a>
#     </li>
#     <li class="disabled" role="presentation">
#      <a data-watchlist-full="" href="#" role="menuitem" tabindex="-1">
#       Lista de interesse cheia!
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/ripple/#charts" role="menuitem" tabindex="-1">
#       Ver gráfico
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/ripple/#markets" role="menuitem" tabindex="-1">
#       Ver mercados
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/ripple/historical-data/" role="menuitem" tabindex="-1">
#       Ver dados históricos
#      </a>
#     </li>
#    </ul>
#   </td>
#  </tr>
#  <tr class="" id="id-litecoin">
#   <td class="text-center">
#    4
#   </td>
#   <td class="no-wrap currency-name" data-sort="Litecoin">
#    <img alt="Litecoin" class="logo-sprite" height="16" src="https://s2.coinmarketcap.com/static/img/coins/32x32/2.png" width="16"/>
#    <span class="currency-symbol visible-xs">
#     <a class="link-secondary" href="/pt-br/currencies/litecoin/">
#      LTC
#     </a>
#    </span>
#    <br class="visible-xs"/>
#    <a class="currency-name-container link-secondary" href="/pt-br/currencies/litecoin/">
#     Litecoin
#    </a>
#   </td>
#   <td class="no-wrap market-cap text-right" data-btc="928812.528432" data-sort="3741799963.53" data-usd="3741799963.53">
#    $3,741,799,964
#   </td>
#   <td class="no-wrap text-right" data-sort="61.4149966485">
#    <a class="price" data-btc="0.0152448070118" data-usd="61.4149966485" href="/pt-br/currencies/litecoin/#markets">
#     $61.41
#    </a>
#   </td>
#   <td class="no-wrap text-right" data-sort="1605279667.47">
#    <a class="volume" data-btc="398472.361247" data-usd="1605279667.47" href="/pt-br/currencies/litecoin/#markets">
#     $1,605,279,667
#    </a>
#   </td>
#   <td class="no-wrap text-right circulating-supply" data-sort="60926486.489">
#    <span data-supply="60926486.489">
#     <span data-supply-container="">
#      60,926,486
#     </span>
#     <span class="hidden-xs">
#      LTC
#     </span>
#    </span>
#   </td>
#   <td class="no-wrap percent-change negative_change text-right" data-percentusd="-0.39398" data-sort="-0.39398" data-symbol="LTC" data-timespan="24h">
#    -0.39%
#   </td>
#   <td>
#    <a href="/pt-br/currencies/litecoin/#charts">
#     <img alt="sparkline" class="sparkline" src="https://s2.coinmarketcap.com/generated/sparklines/web/7d/usd/2.png"/>
#    </a>
#   </td>
#   <td class="dropdown" data-cc-id="2" data-cc-slug="litecoin" data-more-options="">
#    <button class="btn btn-transparent dropdown-toggle" data-toggle="dropdown" id="dropdown-menu-2" type="button">
#     <span class="glyphicons glyphicons-more text-gray">
#     </span>
#    </button>
#    <ul aria-labelledby="dropdown-menu-2" class="dropdown-menu dropdown-menu-right" role="menu">
#     <li role="presentation">
#      <a data-watchlist-add="" href="#" role="menuitem" tabindex="-1">
#       Adicionar à lista de interesse
#      </a>
#     </li>
#     <li role="presentation">
#      <a data-watchlist-remove="" href="#" role="menuitem" tabindex="-1">
#       Remover da lista de interesse
#      </a>
#     </li>
#     <li class="disabled" role="presentation">
#      <a data-watchlist-full="" href="#" role="menuitem" tabindex="-1">
#       Lista de interesse cheia!
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/litecoin/#charts" role="menuitem" tabindex="-1">
#       Ver gráfico
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/litecoin/#markets" role="menuitem" tabindex="-1">
#       Ver mercados
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/litecoin/historical-data/" role="menuitem" tabindex="-1">
#       Ver dados históricos
#      </a>
#     </li>
#    </ul>
#   </td>
#  </tr>
#  <tr class="" id="id-eos">
#   <td class="text-center">
#    5
#   </td>
#   <td class="no-wrap currency-name" data-sort="EOS">
#    <img alt="EOS" class="logo-sprite" height="16" src="https://s2.coinmarketcap.com/static/img/coins/32x32/1765.png" width="16"/>
#    <span class="currency-symbol visible-xs">
#     <a class="link-secondary" href="/pt-br/currencies/eos/">
#      EOS
#     </a>
#    </span>
#    <br class="visible-xs"/>
#    <a class="currency-name-container link-secondary" href="/pt-br/currencies/eos/">
#     EOS
#    </a>
#   </td>
#   <td class="no-wrap market-cap text-right" data-btc="852158.455595" data-sort="3432992536.67" data-usd="3432992536.67">
#    $3,432,992,537
#   </td>
#   <td class="no-wrap text-right" data-sort="3.7881501042">
#    <a class="price" data-btc="0.000940317844527" data-usd="3.7881501042" href="/pt-br/currencies/eos/#markets">
#     $3.79
#    </a>
#   </td>
#   <td class="no-wrap text-right" data-sort="1184644055.13">
#    <a class="volume" data-btc="294059.610578" data-usd="1184644055.13" href="/pt-br/currencies/eos/#markets">
#     $1,184,644,055
#    </a>
#   </td>
#   <td class="no-wrap text-right circulating-supply" data-sort="906245117.6">
#    <span data-supply="906245117.6">
#     <span data-supply-container="">
#      906,245,118
#     </span>
#     <span class="hidden-xs">
#      EOS
#     </span>
#    </span>
#    *
#   </td>
#   <td class="no-wrap percent-change negative_change text-right" data-percentusd="-1.10273" data-sort="-1.10273" data-symbol="EOS" data-timespan="24h">
#    -1.10%
#   </td>
#   <td>
#    <a href="/pt-br/currencies/eos/#charts">
#     <img alt="sparkline" class="sparkline" src="https://s2.coinmarketcap.com/generated/sparklines/web/7d/usd/1765.png"/>
#    </a>
#   </td>
#   <td class="dropdown" data-cc-id="1765" data-cc-slug="eos" data-more-options="">
#    <button class="btn btn-transparent dropdown-toggle" data-toggle="dropdown" id="dropdown-menu-1765" type="button">
#     <span class="glyphicons glyphicons-more text-gray">
#     </span>
#    </button>
#    <ul aria-labelledby="dropdown-menu-1765" class="dropdown-menu dropdown-menu-right" role="menu">
#     <li role="presentation">
#      <a data-watchlist-add="" href="#" role="menuitem" tabindex="-1">
#       Adicionar à lista de interesse
#      </a>
#     </li>
#     <li role="presentation">
#      <a data-watchlist-remove="" href="#" role="menuitem" tabindex="-1">
#       Remover da lista de interesse
#      </a>
#     </li>
#     <li class="disabled" role="presentation">
#      <a data-watchlist-full="" href="#" role="menuitem" tabindex="-1">
#       Lista de interesse cheia!
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/eos/#charts" role="menuitem" tabindex="-1">
#       Ver gráfico
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/eos/#markets" role="menuitem" tabindex="-1">
#       Ver mercados
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/eos/historical-data/" role="menuitem" tabindex="-1">
#       Ver dados históricos
#      </a>
#     </li>
#    </ul>
#   </td>
#  </tr>
#  <tr class="" id="id-bitcoin-cash">
#   <td class="text-center">
#    6
#   </td>
#   <td class="no-wrap currency-name" data-sort="Bitcoin Cash">
#    <img alt="Bitcoin Cash" class="logo-sprite" height="16" src="https://s2.coinmarketcap.com/static/img/coins/32x32/1831.png" width="16"/>
#    <span class="currency-symbol visible-xs">
#     <a class="link-secondary" href="/pt-br/currencies/bitcoin-cash/">
#      BCH
#     </a>
#    </span>
#    <br class="visible-xs"/>
#    <a class="currency-name-container link-secondary" href="/pt-br/currencies/bitcoin-cash/">
#     Bitcoin Cash
#    </a>
#   </td>
#   <td class="no-wrap market-cap text-right" data-btc="688951.659769" data-sort="2775500132.15" data-usd="2775500132.15">
#    $2,775,500,132
#   </td>
#   <td class="no-wrap text-right" data-sort="157.002173998">
#    <a class="price" data-btc="0.0389720422313" data-usd="157.002173998" href="/pt-br/currencies/bitcoin-cash/#markets">
#     $157.00
#    </a>
#   </td>
#   <td class="no-wrap text-right" data-sort="435023280.421">
#    <a class="volume" data-btc="107984.145853" data-usd="435023280.421" href="/pt-br/currencies/bitcoin-cash/#markets">
#     $435,023,280
#    </a>
#   </td>
#   <td class="no-wrap text-right circulating-supply" data-sort="17678100.0">
#    <span data-supply="17678100.0">
#     <span data-supply-container="">
#      17,678,100
#     </span>
#     <span class="hidden-xs">
#      BCH
#     </span>
#    </span>
#   </td>
#   <td class="no-wrap percent-change negative_change text-right" data-percentusd="-0.0763888" data-sort="-0.0763888" data-symbol="BCH" data-timespan="24h">
#    -0.08%
#   </td>
#   <td>
#    <a href="/pt-br/currencies/bitcoin-cash/#charts">
#     <img alt="sparkline" class="sparkline" src="https://s2.coinmarketcap.com/generated/sparklines/web/7d/usd/1831.png"/>
#    </a>
#   </td>
#   <td class="dropdown" data-cc-id="1831" data-cc-slug="bitcoin-cash" data-more-options="">
#    <button class="btn btn-transparent dropdown-toggle" data-toggle="dropdown" id="dropdown-menu-1831" type="button">
#     <span class="glyphicons glyphicons-more text-gray">
#     </span>
#    </button>
#    <ul aria-labelledby="dropdown-menu-1831" class="dropdown-menu dropdown-menu-right" role="menu">
#     <li role="presentation">
#      <a data-watchlist-add="" href="#" role="menuitem" tabindex="-1">
#       Adicionar à lista de interesse
#      </a>
#     </li>
#     <li role="presentation">
#      <a data-watchlist-remove="" href="#" role="menuitem" tabindex="-1">
#       Remover da lista de interesse
#      </a>
#     </li>
#     <li class="disabled" role="presentation">
#      <a data-watchlist-full="" href="#" role="menuitem" tabindex="-1">
#       Lista de interesse cheia!
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/bitcoin-cash/#charts" role="menuitem" tabindex="-1">
#       Ver gráfico
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/bitcoin-cash/#markets" role="menuitem" tabindex="-1">
#       Ver mercados
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/bitcoin-cash/historical-data/" role="menuitem" tabindex="-1">
#       Ver dados históricos
#      </a>
#     </li>
#    </ul>
#   </td>
#  </tr>
#  <tr class="" id="id-binance-coin">
#   <td class="text-center">
#    7
#   </td>
#   <td class="no-wrap currency-name" data-sort="Binance Coin">
#    <img alt="Binance Coin" class="logo-sprite" height="16" src="https://s2.coinmarketcap.com/static/img/coins/32x32/1839.png" width="16"/>
#    <span class="currency-symbol visible-xs">
#     <a class="link-secondary" href="/pt-br/currencies/binance-coin/">
#      BNB
#     </a>
#    </span>
#    <br class="visible-xs"/>
#    <a class="currency-name-container link-secondary" href="/pt-br/currencies/binance-coin/">
#     Binance Coin
#    </a>
#   </td>
#   <td class="no-wrap market-cap text-right" data-btc="555237.177803" data-sort="2236820012.71" data-usd="2236820012.71">
#    $2,236,820,013
#   </td>
#   <td class="no-wrap text-right" data-sort="15.8442517811">
#    <a class="price" data-btc="0.00393295732036" data-usd="15.8442517811" href="/pt-br/currencies/binance-coin/#markets">
#     $15.84
#    </a>
#   </td>
#   <td class="no-wrap text-right" data-sort="134841276.923">
#    <a class="volume" data-btc="33471.1284879" data-usd="134841276.923" href="/pt-br/currencies/binance-coin/#markets">
#     $134,841,277
#    </a>
#   </td>
#   <td class="no-wrap text-right circulating-supply" data-sort="141175490.242">
#    <span data-supply="141175490.242">
#     <span data-supply-container="">
#      141,175,490
#     </span>
#     <span class="hidden-xs">
#      BNB
#     </span>
#    </span>
#    *
#   </td>
#   <td class="no-wrap percent-change negative_change text-right" data-percentusd="-1.48434" data-sort="-1.48434" data-symbol="BNB" data-timespan="24h">
#    -1.48%
#   </td>
#   <td>
#    <a href="/pt-br/currencies/binance-coin/#charts">
#     <img alt="sparkline" class="sparkline" src="https://s2.coinmarketcap.com/generated/sparklines/web/7d/usd/1839.png"/>
#    </a>
#   </td>
#   <td class="dropdown" data-cc-id="1839" data-cc-slug="binance-coin" data-more-options="">
#    <button class="btn btn-transparent dropdown-toggle" data-toggle="dropdown" id="dropdown-menu-1839" type="button">
#     <span class="glyphicons glyphicons-more text-gray">
#     </span>
#    </button>
#    <ul aria-labelledby="dropdown-menu-1839" class="dropdown-menu dropdown-menu-right" role="menu">
#     <li role="presentation">
#      <a data-watchlist-add="" href="#" role="menuitem" tabindex="-1">
#       Adicionar à lista de interesse
#      </a>
#     </li>
#     <li role="presentation">
#      <a data-watchlist-remove="" href="#" role="menuitem" tabindex="-1">
#       Remover da lista de interesse
#      </a>
#     </li>
#     <li class="disabled" role="presentation">
#      <a data-watchlist-full="" href="#" role="menuitem" tabindex="-1">
#       Lista de interesse cheia!
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/binance-coin/#charts" role="menuitem" tabindex="-1">
#       Ver gráfico
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/binance-coin/#markets" role="menuitem" tabindex="-1">
#       Ver mercados
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/binance-coin/historical-data/" role="menuitem" tabindex="-1">
#       Ver dados históricos
#      </a>
#     </li>
#    </ul>
#   </td>
#  </tr>
#  <tr class="" id="id-stellar">
#   <td class="text-center">
#    8
#   </td>
#   <td class="no-wrap currency-name" data-sort="Stellar">
#    <img alt="Stellar" class="logo-sprite" height="16" src="https://s2.coinmarketcap.com/static/img/coins/32x32/512.png" width="16"/>
#    <span class="currency-symbol visible-xs">
#     <a class="link-secondary" href="/pt-br/currencies/stellar/">
#      XLM
#     </a>
#    </span>
#    <br class="visible-xs"/>
#    <a class="currency-name-container link-secondary" href="/pt-br/currencies/stellar/">
#     Stellar
#    </a>
#   </td>
#   <td class="no-wrap market-cap text-right" data-btc="521169.067967" data-sort="2099573745.86" data-usd="2099573745.86">
#    $2,099,573,746
#   </td>
#   <td class="no-wrap text-right" data-sort="0.109234805117">
#    <a class="price" data-btc="2.71149330595e-05" data-usd="0.109234805117" href="/pt-br/currencies/stellar/#markets">
#     $0.109235
#    </a>
#   </td>
#   <td class="no-wrap text-right" data-sort="148212840.724">
#    <a class="volume" data-btc="36790.3000375" data-usd="148212840.724" href="/pt-br/currencies/stellar/#markets">
#     $148,212,841
#    </a>
#   </td>
#   <td class="no-wrap text-right circulating-supply" data-sort="19220739613.2">
#    <span data-supply="19220739613.2">
#     <span data-supply-container="">
#      19,220,739,613
#     </span>
#     <span class="hidden-xs">
#      XLM
#     </span>
#    </span>
#    *
#   </td>
#   <td class="no-wrap percent-change negative_change text-right" data-percentusd="-0.532403" data-sort="-0.532403" data-symbol="XLM" data-timespan="24h">
#    -0.53%
#   </td>
#   <td>
#    <a href="/pt-br/currencies/stellar/#charts">
#     <img alt="sparkline" class="sparkline" src="https://s2.coinmarketcap.com/generated/sparklines/web/7d/usd/512.png"/>
#    </a>
#   </td>
#   <td class="dropdown" data-cc-id="512" data-cc-slug="stellar" data-more-options="">
#    <button class="btn btn-transparent dropdown-toggle" data-toggle="dropdown" id="dropdown-menu-512" type="button">
#     <span class="glyphicons glyphicons-more text-gray">
#     </span>
#    </button>
#    <ul aria-labelledby="dropdown-menu-512" class="dropdown-menu dropdown-menu-right" role="menu">
#     <li role="presentation">
#      <a data-watchlist-add="" href="#" role="menuitem" tabindex="-1">
#       Adicionar à lista de interesse
#      </a>
#     </li>
#     <li role="presentation">
#      <a data-watchlist-remove="" href="#" role="menuitem" tabindex="-1">
#       Remover da lista de interesse
#      </a>
#     </li>
#     <li class="disabled" role="presentation">
#      <a data-watchlist-full="" href="#" role="menuitem" tabindex="-1">
#       Lista de interesse cheia!
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/stellar/#charts" role="menuitem" tabindex="-1">
#       Ver gráfico
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/stellar/#markets" role="menuitem" tabindex="-1">
#       Ver mercados
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/stellar/historical-data/" role="menuitem" tabindex="-1">
#       Ver dados históricos
#      </a>
#     </li>
#    </ul>
#   </td>
#  </tr>
#  <tr class="" id="id-tether">
#   <td class="text-center">
#    9
#   </td>
#   <td class="no-wrap currency-name" data-sort="Tether">
#    <img alt="Tether" class="logo-sprite" height="16" src="https://s2.coinmarketcap.com/static/img/coins/32x32/825.png" width="16"/>
#    <span class="currency-symbol visible-xs">
#     <a class="link-secondary" href="/pt-br/currencies/tether/">
#      USDT
#     </a>
#    </span>
#    <br class="visible-xs"/>
#    <a class="currency-name-container link-secondary" href="/pt-br/currencies/tether/">
#     Tether
#    </a>
#   </td>
#   <td class="no-wrap market-cap text-right" data-btc="501971.862106" data-sort="2022236175.56" data-usd="2022236175.56">
#    $2,022,236,176
#   </td>
#   <td class="no-wrap text-right" data-sort="1.01026714338">
#    <a class="price" data-btc="0.000250774704416" data-usd="1.01026714338" href="/pt-br/currencies/tether/#markets">
#     $1.01
#    </a>
#   </td>
#   <td class="no-wrap text-right" data-sort="7072114444.45">
#    <a class="volume" data-btc="1755483.6075" data-usd="7072114444.45" href="/pt-br/currencies/tether/#markets">
#     $7,072,114,444
#    </a>
#   </td>
#   <td class="no-wrap text-right circulating-supply" data-sort="2001684592.85">
#    <span data-supply="2001684592.85">
#     <span data-supply-container="">
#      2,001,684,593
#     </span>
#     <span class="hidden-xs">
#      USDT
#     </span>
#    </span>
#    *
#   </td>
#   <td class="no-wrap percent-change negative_change text-right" data-percentusd="-0.06902" data-sort="-0.06902" data-symbol="USDT" data-timespan="24h">
#    -0.07%
#   </td>
#   <td>
#    <a href="/pt-br/currencies/tether/#charts">
#     <img alt="sparkline" class="sparkline" src="https://s2.coinmarketcap.com/generated/sparklines/web/7d/usd/825.png"/>
#    </a>
#   </td>
#   <td class="dropdown" data-cc-id="825" data-cc-slug="tether" data-more-options="">
#    <button class="btn btn-transparent dropdown-toggle" data-toggle="dropdown" id="dropdown-menu-825" type="button">
#     <span class="glyphicons glyphicons-more text-gray">
#     </span>
#    </button>
#    <ul aria-labelledby="dropdown-menu-825" class="dropdown-menu dropdown-menu-right" role="menu">
#     <li role="presentation">
#      <a data-watchlist-add="" href="#" role="menuitem" tabindex="-1">
#       Adicionar à lista de interesse
#      </a>
#     </li>
#     <li role="presentation">
#      <a data-watchlist-remove="" href="#" role="menuitem" tabindex="-1">
#       Remover da lista de interesse
#      </a>
#     </li>
#     <li class="disabled" role="presentation">
#      <a data-watchlist-full="" href="#" role="menuitem" tabindex="-1">
#       Lista de interesse cheia!
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/tether/#charts" role="menuitem" tabindex="-1">
#       Ver gráfico
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/tether/#markets" role="menuitem" tabindex="-1">
#       Ver mercados
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/tether/historical-data/" role="menuitem" tabindex="-1">
#       Ver dados históricos
#      </a>
#     </li>
#    </ul>
#   </td>
#  </tr>
#  <tr class="" id="id-tron">
#   <td class="text-center">
#    10
#   </td>
#   <td class="no-wrap currency-name" data-sort="TRON">
#    <img alt="TRON" class="logo-sprite" height="16" src="https://s2.coinmarketcap.com/static/img/coins/32x32/1958.png" width="16"/>
#    <span class="currency-symbol visible-xs">
#     <a class="link-secondary" href="/pt-br/currencies/tron/">
#      TRX
#     </a>
#    </span>
#    <br class="visible-xs"/>
#    <a class="currency-name-container link-secondary" href="/pt-br/currencies/tron/">
#     TRON
#    </a>
#   </td>
#   <td class="no-wrap market-cap text-right" data-btc="384251.439519" data-sort="1547989479.44" data-usd="1547989479.44">
#    $1,547,989,479
#   </td>
#   <td class="no-wrap text-right" data-sort="0.0232144777234">
#    <a class="price" data-btc="5.76243999161e-06" data-usd="0.0232144777234" href="/pt-br/currencies/tron/#markets">
#     $0.023214
#    </a>
#   </td>
#   <td class="no-wrap text-right" data-sort="158426223.41">
#    <a class="volume" data-btc="39325.5285074" data-usd="158426223.41" href="/pt-br/currencies/tron/#markets">
#     $158,426,223
#    </a>
#   </td>
#   <td class="no-wrap text-right circulating-supply" data-sort="66682072191.4">
#    <span data-supply="66682072191.4">
#     <span data-supply-container="">
#      66,682,072,191
#     </span>
#     <span class="hidden-xs">
#      TRX
#     </span>
#    </span>
#   </td>
#   <td class="no-wrap percent-change negative_change text-right" data-percentusd="-0.600945" data-sort="-0.600945" data-symbol="TRX" data-timespan="24h">
#    -0.60%
#   </td>
#   <td>
#    <a href="/pt-br/currencies/tron/#charts">
#     <img alt="sparkline" class="sparkline" src="https://s2.coinmarketcap.com/generated/sparklines/web/7d/usd/1958.png"/>
#    </a>
#   </td>
#   <td class="dropdown" data-cc-id="1958" data-cc-slug="tron" data-more-options="">
#    <button class="btn btn-transparent dropdown-toggle" data-toggle="dropdown" id="dropdown-menu-1958" type="button">
#     <span class="glyphicons glyphicons-more text-gray">
#     </span>
#    </button>
#    <ul aria-labelledby="dropdown-menu-1958" class="dropdown-menu dropdown-menu-right" role="menu">
#     <li role="presentation">
#      <a data-watchlist-add="" href="#" role="menuitem" tabindex="-1">
#       Adicionar à lista de interesse
#      </a>
#     </li>
#     <li role="presentation">
#      <a data-watchlist-remove="" href="#" role="menuitem" tabindex="-1">
#       Remover da lista de interesse
#      </a>
#     </li>
#     <li class="disabled" role="presentation">
#      <a data-watchlist-full="" href="#" role="menuitem" tabindex="-1">
#       Lista de interesse cheia!
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/tron/#charts" role="menuitem" tabindex="-1">
#       Ver gráfico
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/tron/#markets" role="menuitem" tabindex="-1">
#       Ver mercados
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/tron/historical-data/" role="menuitem" tabindex="-1">
#       Ver dados históricos
#      </a>
#     </li>
#    </ul>
#   </td>
#  </tr>
#  <tr class="" id="id-cardano">
#   <td class="text-center">
#    11
#   </td>
#   <td class="no-wrap currency-name" data-sort="Cardano">
#    <img alt="Cardano" class="logo-sprite lazyload" data-src="https://s2.coinmarketcap.com/static/img/coins/32x32/2010.png" height="16" src="..." width="16"/>
#    <span class="currency-symbol visible-xs">
#     <a class="link-secondary" href="/pt-br/currencies/cardano/">
#      ADA
#     </a>
#    </span>
#    <br class="visible-xs"/>
#    <a class="currency-name-container link-secondary" href="/pt-br/currencies/cardano/">
#     Cardano
#    </a>
#   </td>
#   <td class="no-wrap market-cap text-right" data-btc="324557.903985" data-sort="1307509014.06" data-usd="1307509014.06">
#    $1,307,509,014
#   </td>
#   <td class="no-wrap text-right" data-sort="0.0504302640804">
#    <a class="price" data-btc="1.25181093448e-05" data-usd="0.0504302640804" href="/pt-br/currencies/cardano/#markets">
#     $0.050430
#    </a>
#   </td>
#   <td class="no-wrap text-right" data-sort="28893437.0331">
#    <a class="volume" data-btc="7172.10608993" data-usd="28893437.0331" href="/pt-br/currencies/cardano/#markets">
#     $28,893,437
#    </a>
#   </td>
#   <td class="no-wrap text-right circulating-supply" data-sort="25927070538.0">
#    <span data-supply="25927070538.0">
#     <span data-supply-container="">
#      25,927,070,538
#     </span>
#     <span class="hidden-xs">
#      ADA
#     </span>
#    </span>
#   </td>
#   <td class="no-wrap percent-change negative_change text-right" data-percentusd="-1.90976" data-sort="-1.90976" data-symbol="ADA" data-timespan="24h">
#    -1.91%
#   </td>
#   <td>
#    <a href="/pt-br/currencies/cardano/#charts">
#     <img alt="sparkline" class="sparkline lazyload" data-src="https://s2.coinmarketcap.com/generated/sparklines/web/7d/usd/2010.png" height="48" src="https://s2.coinmarketcap.com/static/cloud/img/loading-sparkline.svg" width="164"/>
#    </a>
#   </td>
#   <td class="dropdown" data-cc-id="2010" data-cc-slug="cardano" data-more-options="">
#    <button class="btn btn-transparent dropdown-toggle" data-toggle="dropdown" id="dropdown-menu-2010" type="button">
#     <span class="glyphicons glyphicons-more text-gray">
#     </span>
#    </button>
#    <ul aria-labelledby="dropdown-menu-2010" class="dropdown-menu dropdown-menu-right" role="menu">
#     <li role="presentation">
#      <a data-watchlist-add="" href="#" role="menuitem" tabindex="-1">
#       Adicionar à lista de interesse
#      </a>
#     </li>
#     <li role="presentation">
#      <a data-watchlist-remove="" href="#" role="menuitem" tabindex="-1">
#       Remover da lista de interesse
#      </a>
#     </li>
#     <li class="disabled" role="presentation">
#      <a data-watchlist-full="" href="#" role="menuitem" tabindex="-1">
#       Lista de interesse cheia!
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/cardano/#charts" role="menuitem" tabindex="-1">
#       Ver gráfico
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/cardano/#markets" role="menuitem" tabindex="-1">
#       Ver mercados
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/cardano/historical-data/" role="menuitem" tabindex="-1">
#       Ver dados históricos
#      </a>
#     </li>
#    </ul>
#   </td>
#  </tr>
#  <tr class="" id="id-bitcoin-sv">
#   <td class="text-center">
#    12
#   </td>
#   <td class="no-wrap currency-name" data-sort="Bitcoin SV">
#    <img alt="Bitcoin SV" class="logo-sprite lazyload" data-src="https://s2.coinmarketcap.com/static/img/coins/32x32/3602.png" height="16" src="..." width="16"/>
#    <span class="currency-symbol visible-xs">
#     <a class="link-secondary" href="/pt-br/currencies/bitcoin-sv/">
#      BSV
#     </a>
#    </span>
#    <br class="visible-xs"/>
#    <a class="currency-name-container link-secondary" href="/pt-br/currencies/bitcoin-sv/">
#     Bitcoin SV
#    </a>
#   </td>
#   <td class="no-wrap market-cap text-right" data-btc="300889.778331" data-sort="1212159964.61" data-usd="1212159964.61">
#    $1,212,159,965
#   </td>
#   <td class="no-wrap text-right" data-sort="68.598533804">
#    <a class="price" data-btc="0.0170279486477" data-usd="68.598533804" href="/pt-br/currencies/bitcoin-sv/#markets">
#     $68.60
#    </a>
#   </td>
#   <td class="no-wrap text-right" data-sort="88822569.5893">
#    <a class="volume" data-btc="22048.0828067" data-usd="88822569.5893" href="/pt-br/currencies/bitcoin-sv/#markets">
#     $88,822,570
#    </a>
#   </td>
#   <td class="no-wrap text-right circulating-supply" data-sort="17670348.0">
#    <span data-supply="17670348.0">
#     <span data-supply-container="">
#      17,670,348
#     </span>
#     <span class="hidden-xs">
#      BSV
#     </span>
#    </span>
#   </td>
#   <td class="no-wrap percent-change negative_change text-right" data-percentusd="-0.766832" data-sort="-0.766832" data-symbol="BSV" data-timespan="24h">
#    -0.77%
#   </td>
#   <td>
#    <a href="/pt-br/currencies/bitcoin-sv/#charts">
#     <img alt="sparkline" class="sparkline lazyload" data-src="https://s2.coinmarketcap.com/generated/sparklines/web/7d/usd/3602.png" height="48" src="https://s2.coinmarketcap.com/static/cloud/img/loading-sparkline.svg" width="164"/>
#    </a>
#   </td>
#   <td class="dropdown" data-cc-id="3602" data-cc-slug="bitcoin-sv" data-more-options="">
#    <button class="btn btn-transparent dropdown-toggle" data-toggle="dropdown" id="dropdown-menu-3602" type="button">
#     <span class="glyphicons glyphicons-more text-gray">
#     </span>
#    </button>
#    <ul aria-labelledby="dropdown-menu-3602" class="dropdown-menu dropdown-menu-right" role="menu">
#     <li role="presentation">
#      <a data-watchlist-add="" href="#" role="menuitem" tabindex="-1">
#       Adicionar à lista de interesse
#      </a>
#     </li>
#     <li role="presentation">
#      <a data-watchlist-remove="" href="#" role="menuitem" tabindex="-1">
#       Remover da lista de interesse
#      </a>
#     </li>
#     <li class="disabled" role="presentation">
#      <a data-watchlist-full="" href="#" role="menuitem" tabindex="-1">
#       Lista de interesse cheia!
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/bitcoin-sv/#charts" role="menuitem" tabindex="-1">
#       Ver gráfico
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/bitcoin-sv/#markets" role="menuitem" tabindex="-1">
#       Ver mercados
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/bitcoin-sv/historical-data/" role="menuitem" tabindex="-1">
#       Ver dados históricos
#      </a>
#     </li>
#    </ul>
#   </td>
#  </tr>
#  <tr class="" id="id-monero">
#   <td class="text-center">
#    13
#   </td>
#   <td class="no-wrap currency-name" data-sort="Monero">
#    <img alt="Monero" class="logo-sprite lazyload" data-src="https://s2.coinmarketcap.com/static/img/coins/32x32/328.png" height="16" src="..." width="16"/>
#    <span class="currency-symbol visible-xs">
#     <a class="link-secondary" href="/pt-br/currencies/monero/">
#      XMR
#     </a>
#    </span>
#    <br class="visible-xs"/>
#    <a class="currency-name-container link-secondary" href="/pt-br/currencies/monero/">
#     Monero
#    </a>
#   </td>
#   <td class="no-wrap market-cap text-right" data-btc="225002.407832" data-sort="906441263.061" data-usd="906441263.061">
#    $906,441,263
#   </td>
#   <td class="no-wrap text-right" data-sort="53.76478396">
#    <a class="price" data-btc="0.0133458243138" data-usd="53.76478396" href="/pt-br/currencies/monero/#markets">
#     $53.76
#    </a>
#   </td>
#   <td class="no-wrap text-right" data-sort="117986864.673">
#    <a class="volume" data-btc="29287.4229427" data-usd="117986864.673" href="/pt-br/currencies/monero/#markets">
#     $117,986,865
#    </a>
#   </td>
#   <td class="no-wrap text-right circulating-supply" data-sort="16859386.3175">
#    <span data-supply="16859386.3175">
#     <span data-supply-container="">
#      16,859,386
#     </span>
#     <span class="hidden-xs">
#      XMR
#     </span>
#    </span>
#   </td>
#   <td class="no-wrap percent-change negative_change text-right" data-percentusd="-1.43593" data-sort="-1.43593" data-symbol="XMR" data-timespan="24h">
#    -1.44%
#   </td>
#   <td>
#    <a href="/pt-br/currencies/monero/#charts">
#     <img alt="sparkline" class="sparkline lazyload" data-src="https://s2.coinmarketcap.com/generated/sparklines/web/7d/usd/328.png" height="48" src="https://s2.coinmarketcap.com/static/cloud/img/loading-sparkline.svg" width="164"/>
#    </a>
#   </td>
#   <td class="dropdown" data-cc-id="328" data-cc-slug="monero" data-more-options="">
#    <button class="btn btn-transparent dropdown-toggle" data-toggle="dropdown" id="dropdown-menu-328" type="button">
#     <span class="glyphicons glyphicons-more text-gray">
#     </span>
#    </button>
#    <ul aria-labelledby="dropdown-menu-328" class="dropdown-menu dropdown-menu-right" role="menu">
#     <li role="presentation">
#      <a data-watchlist-add="" href="#" role="menuitem" tabindex="-1">
#       Adicionar à lista de interesse
#      </a>
#     </li>
#     <li role="presentation">
#      <a data-watchlist-remove="" href="#" role="menuitem" tabindex="-1">
#       Remover da lista de interesse
#      </a>
#     </li>
#     <li class="disabled" role="presentation">
#      <a data-watchlist-full="" href="#" role="menuitem" tabindex="-1">
#       Lista de interesse cheia!
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/monero/#charts" role="menuitem" tabindex="-1">
#       Ver gráfico
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/monero/#markets" role="menuitem" tabindex="-1">
#       Ver mercados
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/monero/historical-data/" role="menuitem" tabindex="-1">
#       Ver dados históricos
#      </a>
#     </li>
#    </ul>
#   </td>
#  </tr>
#  <tr class="" id="id-iota">
#   <td class="text-center">
#    14
#   </td>
#   <td class="no-wrap currency-name" data-sort="IOTA">
#    <img alt="IOTA" class="logo-sprite lazyload" data-src="https://s2.coinmarketcap.com/static/img/coins/32x32/1720.png" height="16" src="..." width="16"/>
#    <span class="currency-symbol visible-xs">
#     <a class="link-secondary" href="/pt-br/currencies/iota/">
#      MIOTA
#     </a>
#    </span>
#    <br class="visible-xs"/>
#    <a class="currency-name-container link-secondary" href="/pt-br/currencies/iota/">
#     IOTA
#    </a>
#   </td>
#   <td class="no-wrap market-cap text-right" data-btc="206318.90211" data-sort="831173177.321" data-usd="831173177.321">
#    $831,173,177
#   </td>
#   <td class="no-wrap text-right" data-sort="0.299033682923">
#    <a class="price" data-btc="7.42279741911e-05" data-usd="0.299033682923" href="/pt-br/currencies/iota/#markets">
#     $0.299034
#    </a>
#   </td>
#   <td class="no-wrap text-right" data-sort="17908335.9322">
#    <a class="volume" data-btc="4445.31694353" data-usd="17908335.9322" href="/pt-br/currencies/iota/#markets">
#     $17,908,336
#    </a>
#   </td>
#   <td class="no-wrap text-right circulating-supply" data-sort="2779530283.0">
#    <span data-supply="2779530283.0">
#     <span data-supply-container="">
#      2,779,530,283
#     </span>
#     <span class="hidden-xs">
#      MIOTA
#     </span>
#    </span>
#    *
#   </td>
#   <td class="no-wrap percent-change negative_change text-right" data-percentusd="-2.17312" data-sort="-2.17312" data-symbol="MIOTA" data-timespan="24h">
#    -2.17%
#   </td>
#   <td>
#    <a href="/pt-br/currencies/iota/#charts">
#     <img alt="sparkline" class="sparkline lazyload" data-src="https://s2.coinmarketcap.com/generated/sparklines/web/7d/usd/1720.png" height="48" src="https://s2.coinmarketcap.com/static/cloud/img/loading-sparkline.svg" width="164"/>
#    </a>
#   </td>
#   <td class="dropdown" data-cc-id="1720" data-cc-slug="iota" data-more-options="">
#    <button class="btn btn-transparent dropdown-toggle" data-toggle="dropdown" id="dropdown-menu-1720" type="button">
#     <span class="glyphicons glyphicons-more text-gray">
#     </span>
#    </button>
#    <ul aria-labelledby="dropdown-menu-1720" class="dropdown-menu dropdown-menu-right" role="menu">
#     <li role="presentation">
#      <a data-watchlist-add="" href="#" role="menuitem" tabindex="-1">
#       Adicionar à lista de interesse
#      </a>
#     </li>
#     <li role="presentation">
#      <a data-watchlist-remove="" href="#" role="menuitem" tabindex="-1">
#       Remover da lista de interesse
#      </a>
#     </li>
#     <li class="disabled" role="presentation">
#      <a data-watchlist-full="" href="#" role="menuitem" tabindex="-1">
#       Lista de interesse cheia!
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/iota/#charts" role="menuitem" tabindex="-1">
#       Ver gráfico
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/iota/#markets" role="menuitem" tabindex="-1">
#       Ver mercados
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/iota/historical-data/" role="menuitem" tabindex="-1">
#       Ver dados históricos
#      </a>
#     </li>
#    </ul>
#   </td>
#  </tr>
#  <tr class="" id="id-dash">
#   <td class="text-center">
#    15
#   </td>
#   <td class="no-wrap currency-name" data-sort="Dash">
#    <img alt="Dash" class="logo-sprite lazyload" data-src="https://s2.coinmarketcap.com/static/img/coins/32x32/131.png" height="16" src="..." width="16"/>
#    <span class="currency-symbol visible-xs">
#     <a class="link-secondary" href="/pt-br/currencies/dash/">
#      DASH
#     </a>
#    </span>
#    <br class="visible-xs"/>
#    <a class="currency-name-container link-secondary" href="/pt-br/currencies/dash/">
#     Dash
#    </a>
#   </td>
#   <td class="no-wrap market-cap text-right" data-btc="201628.130542" data-sort="812276006.637" data-usd="812276006.637">
#    $812,276,007
#   </td>
#   <td class="no-wrap text-right" data-sort="93.4287020498">
#    <a class="price" data-btc="0.0231914452469" data-usd="93.4287020498" href="/pt-br/currencies/dash/#markets">
#     $93.43
#    </a>
#   </td>
#   <td class="no-wrap text-right" data-sort="222383386.662">
#    <a class="volume" data-btc="55201.3677" data-usd="222383386.662" href="/pt-br/currencies/dash/#markets">
#     $222,383,387
#    </a>
#   </td>
#   <td class="no-wrap text-right circulating-supply" data-sort="8694073.54288">
#    <span data-supply="8694073.54288">
#     <span data-supply-container="">
#      8,694,074
#     </span>
#     <span class="hidden-xs">
#      DASH
#     </span>
#    </span>
#   </td>
#   <td class="no-wrap percent-change positive_change text-right" data-percentusd="0.440805" data-sort="0.440805" data-symbol="DASH" data-timespan="24h">
#    0.44%
#   </td>
#   <td>
#    <a href="/pt-br/currencies/dash/#charts">
#     <img alt="sparkline" class="sparkline lazyload" data-src="https://s2.coinmarketcap.com/generated/sparklines/web/7d/usd/131.png" height="48" src="https://s2.coinmarketcap.com/static/cloud/img/loading-sparkline.svg" width="164"/>
#    </a>
#   </td>
#   <td class="dropdown" data-cc-id="131" data-cc-slug="dash" data-more-options="">
#    <button class="btn btn-transparent dropdown-toggle" data-toggle="dropdown" id="dropdown-menu-131" type="button">
#     <span class="glyphicons glyphicons-more text-gray">
#     </span>
#    </button>
#    <ul aria-labelledby="dropdown-menu-131" class="dropdown-menu dropdown-menu-right" role="menu">
#     <li role="presentation">
#      <a data-watchlist-add="" href="#" role="menuitem" tabindex="-1">
#       Adicionar à lista de interesse
#      </a>
#     </li>
#     <li role="presentation">
#      <a data-watchlist-remove="" href="#" role="menuitem" tabindex="-1">
#       Remover da lista de interesse
#      </a>
#     </li>
#     <li class="disabled" role="presentation">
#      <a data-watchlist-full="" href="#" role="menuitem" tabindex="-1">
#       Lista de interesse cheia!
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/dash/#charts" role="menuitem" tabindex="-1">
#       Ver gráfico
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/dash/#markets" role="menuitem" tabindex="-1">
#       Ver mercados
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/dash/historical-data/" role="menuitem" tabindex="-1">
#       Ver dados históricos
#      </a>
#     </li>
#    </ul>
#   </td>
#  </tr>
#  <tr class="" id="id-maker">
#   <td class="text-center">
#    16
#   </td>
#   <td class="no-wrap currency-name" data-sort="Maker">
#    <img alt="Maker" class="logo-sprite lazyload" data-src="https://s2.coinmarketcap.com/static/img/coins/32x32/1518.png" height="16" src="..." width="16"/>
#    <span class="currency-symbol visible-xs">
#     <a class="link-secondary" href="/pt-br/currencies/maker/">
#      MKR
#     </a>
#    </span>
#    <br class="visible-xs"/>
#    <a class="currency-name-container link-secondary" href="/pt-br/currencies/maker/">
#     Maker
#    </a>
#   </td>
#   <td class="no-wrap market-cap text-right" data-btc="173229.952816" data-sort="697871541.661" data-usd="697871541.661">
#    $697,871,542
#   </td>
#   <td class="no-wrap text-right" data-sort="697.871541661">
#    <a class="price" data-btc="0.173229952816" data-usd="697.871541661" href="/pt-br/currencies/maker/#markets">
#     $697.87
#    </a>
#   </td>
#   <td class="no-wrap text-right" data-sort="1113085.59997">
#    <a class="volume" data-btc="276.296932102" data-usd="1113085.59997" href="/pt-br/currencies/maker/#markets">
#     $1,113,086
#    </a>
#   </td>
#   <td class="no-wrap text-right circulating-supply" data-sort="1000000.0">
#    <span data-supply="1000000.0">
#     <span data-supply-container="">
#      1,000,000
#     </span>
#     <span class="hidden-xs">
#      MKR
#     </span>
#    </span>
#    *
#   </td>
# ...
#    <img alt="Ormeus Coin" class="logo-sprite lazyload" data-src="https://s2.coinmarketcap.com/static/img/coins/32x32/1998.png" height="16" src="..." width="16"/>
#    <span class="currency-symbol visible-xs">
#     <a class="link-secondary" href="/pt-br/currencies/ormeus-coin/">
#      ORME
#     </a>
#    </span>
#    <br class="visible-xs"/>
#    <a class="currency-name-container link-secondary" href="/pt-br/currencies/ormeus-coin/">
#     Ormeus Coin
#    </a>
#   </td>
#   <td class="no-wrap market-cap text-right" data-btc="11696.3079479" data-sort="47119567.5266" data-usd="47119567.5266">
#    $47,119,568
#   </td>
#   <td class="no-wrap text-right" data-sort="1.31234006827">
#    <a class="price" data-btc="0.00032575709788" data-usd="1.31234006827" href="/pt-br/currencies/ormeus-coin/#markets">
#     $1.31
#    </a>
#   </td>
#   <td class="no-wrap text-right" data-sort="2688675.02113">
#    <a class="volume" data-btc="667.399398376" data-usd="2688675.02113" href="/pt-br/currencies/ormeus-coin/#markets">
#     $2,688,675
#    </a>
#   </td>
#   <td class="no-wrap text-right circulating-supply" data-sort="35904998.0">
#    <span data-supply="35904998.0">
#     <span data-supply-container="">
#      35,904,998
#     </span>
#     <span class="hidden-xs">
#      ORME
#     </span>
#    </span>
#    *
#   </td>
#   <td class="no-wrap percent-change positive_change text-right" data-percentusd="4.71499" data-sort="4.71499" data-symbol="ORME" data-timespan="24h">
#    4.71%
#   </td>
#   <td>
#    <a href="/pt-br/currencies/ormeus-coin/#charts">
#     <img alt="sparkline" class="sparkline lazyload" data-src="https://s2.coinmarketcap.com/generated/sparklines/web/7d/usd/1998.png" height="48" src="https://s2.coinmarketcap.com/static/cloud/img/loading-sparkline.svg" width="164"/>
#    </a>
#   </td>
#   <td class="dropdown" data-cc-id="1998" data-cc-slug="ormeus-coin" data-more-options="">
#    <button class="btn btn-transparent dropdown-toggle" data-toggle="dropdown" id="dropdown-menu-1998" type="button">
#     <span class="glyphicons glyphicons-more text-gray">
#     </span>
#    </button>
#    <ul aria-labelledby="dropdown-menu-1998" class="dropdown-menu dropdown-menu-right" role="menu">
#     <li role="presentation">
#      <a data-watchlist-add="" href="#" role="menuitem" tabindex="-1">
#       Adicionar à lista de interesse
#      </a>
#     </li>
#     <li role="presentation">
#      <a data-watchlist-remove="" href="#" role="menuitem" tabindex="-1">
#       Remover da lista de interesse
#      </a>
#     </li>
#     <li class="disabled" role="presentation">
#      <a data-watchlist-full="" href="#" role="menuitem" tabindex="-1">
#       Lista de interesse cheia!
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/ormeus-coin/#charts" role="menuitem" tabindex="-1">
#       Ver gráfico
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/ormeus-coin/#markets" role="menuitem" tabindex="-1">
#       Ver mercados
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/ormeus-coin/historical-data/" role="menuitem" tabindex="-1">
#       Ver dados históricos
#      </a>
#     </li>
#    </ul>
#   </td>
#  </tr>
#  <tr class="" id="id-thorecoin">
#   <td class="text-center">
#    97
#   </td>
#   <td class="no-wrap currency-name" data-sort="ThoreCoin">
#    <img alt="ThoreCoin" class="logo-sprite lazyload" data-src="https://s2.coinmarketcap.com/static/img/coins/32x32/3144.png" height="16" src="..." width="16"/>
#    <span class="currency-symbol visible-xs">
#     <a class="link-secondary" href="/pt-br/currencies/thorecoin/">
#      THR
#     </a>
#    </span>
#    <br class="visible-xs"/>
#    <a class="currency-name-container link-secondary" href="/pt-br/currencies/thorecoin/">
#     ThoreCoin
#    </a>
#   </td>
#   <td class="no-wrap market-cap text-right" data-btc="11467.0001514" data-sort="46195781.6405" data-usd="46195781.6405">
#    $46,195,782
#   </td>
#   <td class="no-wrap text-right" data-sort="532.909237742">
#    <a class="price" data-btc="0.132281998331" data-usd="532.909237742" href="/pt-br/currencies/thorecoin/#markets">
#     $532.91
#    </a>
#   </td>
#   <td class="no-wrap text-right" data-sort="98908.5285849">
#    <a class="volume" data-btc="24.5516813869" data-usd="98908.5285849" href="/pt-br/currencies/thorecoin/#markets">
#     $98,909
#    </a>
#   </td>
#   <td class="no-wrap text-right circulating-supply" data-sort="86686.0215">
#    <span data-supply="86686.0215">
#     <span data-supply-container="">
#      86,686
#     </span>
#     <span class="hidden-xs">
#      THR
#     </span>
#    </span>
#    *
#   </td>
#   <td class="no-wrap percent-change negative_change text-right" data-percentusd="-4.49358" data-sort="-4.49358" data-symbol="THR" data-timespan="24h">
#    -4.49%
#   </td>
#   <td>
#    <a href="/pt-br/currencies/thorecoin/#charts">
#     <img alt="sparkline" class="sparkline lazyload" data-src="https://s2.coinmarketcap.com/generated/sparklines/web/7d/usd/3144.png" height="48" src="https://s2.coinmarketcap.com/static/cloud/img/loading-sparkline.svg" width="164"/>
#    </a>
#   </td>
#   <td class="dropdown" data-cc-id="3144" data-cc-slug="thorecoin" data-more-options="">
#    <button class="btn btn-transparent dropdown-toggle" data-toggle="dropdown" id="dropdown-menu-3144" type="button">
#     <span class="glyphicons glyphicons-more text-gray">
#     </span>
#    </button>
#    <ul aria-labelledby="dropdown-menu-3144" class="dropdown-menu dropdown-menu-right" role="menu">
#     <li role="presentation">
#      <a data-watchlist-add="" href="#" role="menuitem" tabindex="-1">
#       Adicionar à lista de interesse
#      </a>
#     </li>
#     <li role="presentation">
#      <a data-watchlist-remove="" href="#" role="menuitem" tabindex="-1">
#       Remover da lista de interesse
#      </a>
#     </li>
#     <li class="disabled" role="presentation">
#      <a data-watchlist-full="" href="#" role="menuitem" tabindex="-1">
#       Lista de interesse cheia!
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/thorecoin/#charts" role="menuitem" tabindex="-1">
#       Ver gráfico
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/thorecoin/#markets" role="menuitem" tabindex="-1">
#       Ver mercados
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/thorecoin/historical-data/" role="menuitem" tabindex="-1">
#       Ver dados históricos
#      </a>
#     </li>
#    </ul>
#   </td>
#  </tr>
#  <tr class="" id="id-moac">
#   <td class="text-center">
#    98
#   </td>
#   <td class="no-wrap currency-name" data-sort="MOAC">
#    <img alt="MOAC" class="logo-sprite lazyload" data-src="https://s2.coinmarketcap.com/static/img/coins/32x32/2403.png" height="16" src="..." width="16"/>
#    <span class="currency-symbol visible-xs">
#     <a class="link-secondary" href="/pt-br/currencies/moac/">
#      MOAC
#     </a>
#    </span>
#    <br class="visible-xs"/>
#    <a class="currency-name-container link-secondary" href="/pt-br/currencies/moac/">
#     MOAC
#    </a>
#   </td>
#   <td class="no-wrap market-cap text-right" data-btc="11388.2074204" data-sort="45878358.4481" data-usd="45878358.4481">
#    $45,878,358
#   </td>
#   <td class="no-wrap text-right" data-sort="0.734484629636">
#    <a class="price" data-btc="0.000182318277993" data-usd="0.734484629636" href="/pt-br/currencies/moac/#markets">
#     $0.734485
#    </a>
#   </td>
#   <td class="no-wrap text-right" data-sort="35603.5268553">
#    <a class="volume" data-btc="8.83772572608" data-usd="35603.5268553" href="/pt-br/currencies/moac/#markets">
#     $35,604
#    </a>
#   </td>
#   <td class="no-wrap text-right circulating-supply" data-sort="62463333.6042">
#    <span data-supply="62463333.6042">
#     <span data-supply-container="">
#      62,463,334
#     </span>
#     <span class="hidden-xs">
#      MOAC
#     </span>
#    </span>
#    *
#   </td>
#   <td class="no-wrap percent-change negative_change text-right" data-percentusd="-2.26796" data-sort="-2.26796" data-symbol="MOAC" data-timespan="24h">
#    -2.27%
#   </td>
#   <td>
#    <a href="/pt-br/currencies/moac/#charts">
#     <img alt="sparkline" class="sparkline lazyload" data-src="https://s2.coinmarketcap.com/generated/sparklines/web/7d/usd/2403.png" height="48" src="https://s2.coinmarketcap.com/static/cloud/img/loading-sparkline.svg" width="164"/>
#    </a>
#   </td>
#   <td class="dropdown" data-cc-id="2403" data-cc-slug="moac" data-more-options="">
#    <button class="btn btn-transparent dropdown-toggle" data-toggle="dropdown" id="dropdown-menu-2403" type="button">
#     <span class="glyphicons glyphicons-more text-gray">
#     </span>
#    </button>
#    <ul aria-labelledby="dropdown-menu-2403" class="dropdown-menu dropdown-menu-right" role="menu">
#     <li role="presentation">
#      <a data-watchlist-add="" href="#" role="menuitem" tabindex="-1">
#       Adicionar à lista de interesse
#      </a>
#     </li>
#     <li role="presentation">
#      <a data-watchlist-remove="" href="#" role="menuitem" tabindex="-1">
#       Remover da lista de interesse
#      </a>
#     </li>
#     <li class="disabled" role="presentation">
#      <a data-watchlist-full="" href="#" role="menuitem" tabindex="-1">
#       Lista de interesse cheia!
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/moac/#charts" role="menuitem" tabindex="-1">
#       Ver gráfico
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/moac/#markets" role="menuitem" tabindex="-1">
#       Ver mercados
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/moac/historical-data/" role="menuitem" tabindex="-1">
#       Ver dados históricos
#      </a>
#     </li>
#    </ul>
#   </td>
#  </tr>
#  <tr class="" id="id-metaverse">
#   <td class="text-center">
#    99
#   </td>
#   <td class="no-wrap currency-name" data-sort="Metaverse ETP">
#    <img alt="Metaverse ETP" class="logo-sprite lazyload" data-src="https://s2.coinmarketcap.com/static/img/coins/32x32/1703.png" height="16" src="..." width="16"/>
#    <span class="currency-symbol visible-xs">
#     <a class="link-secondary" href="/pt-br/currencies/metaverse/">
#      ETP
#     </a>
#    </span>
#    <br class="visible-xs"/>
#    <a class="currency-name-container link-secondary" href="/pt-br/currencies/metaverse/">
#     Metaverse ETP
#    </a>
#   </td>
#   <td class="no-wrap market-cap text-right" data-btc="11007.1499753" data-sort="44343236.2458" data-usd="44343236.2458">
#    $44,343,236
#   </td>
#   <td class="no-wrap text-right" data-sort="0.739875849321">
#    <a class="price" data-btc="0.000183656519598" data-usd="0.739875849321" href="/pt-br/currencies/metaverse/#markets">
#     $0.739876
#    </a>
#   </td>
#   <td class="no-wrap text-right" data-sort="2601057.75713">
#    <a class="volume" data-btc="645.650503913" data-usd="2601057.75713" href="/pt-br/currencies/metaverse/#markets">
#     $2,601,058
#    </a>
#   </td>
#   <td class="no-wrap text-right circulating-supply" data-sort="59933347.3129">
#    <span data-supply="59933347.3129">
#     <span data-supply-container="">
#      59,933,347
#     </span>
#     <span class="hidden-xs">
#      ETP
#     </span>
#    </span>
#   </td>
#   <td class="no-wrap percent-change positive_change text-right" data-percentusd="0.595362" data-sort="0.595362" data-symbol="ETP" data-timespan="24h">
#    0.60%
#   </td>
#   <td>
#    <a href="/pt-br/currencies/metaverse/#charts">
#     <img alt="sparkline" class="sparkline lazyload" data-src="https://s2.coinmarketcap.com/generated/sparklines/web/7d/usd/1703.png" height="48" src="https://s2.coinmarketcap.com/static/cloud/img/loading-sparkline.svg" width="164"/>
#    </a>
#   </td>
#   <td class="dropdown" data-cc-id="1703" data-cc-slug="metaverse" data-more-options="">
#    <button class="btn btn-transparent dropdown-toggle" data-toggle="dropdown" id="dropdown-menu-1703" type="button">
#     <span class="glyphicons glyphicons-more text-gray">
#     </span>
#    </button>
#    <ul aria-labelledby="dropdown-menu-1703" class="dropdown-menu dropdown-menu-right" role="menu">
#     <li role="presentation">
#      <a data-watchlist-add="" href="#" role="menuitem" tabindex="-1">
#       Adicionar à lista de interesse
#      </a>
#     </li>
#     <li role="presentation">
#      <a data-watchlist-remove="" href="#" role="menuitem" tabindex="-1">
#       Remover da lista de interesse
#      </a>
#     </li>
#     <li class="disabled" role="presentation">
#      <a data-watchlist-full="" href="#" role="menuitem" tabindex="-1">
#       Lista de interesse cheia!
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/metaverse/#charts" role="menuitem" tabindex="-1">
#       Ver gráfico
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/metaverse/#markets" role="menuitem" tabindex="-1">
#       Ver mercados
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/metaverse/historical-data/" role="menuitem" tabindex="-1">
#       Ver dados históricos
#      </a>
#     </li>
#    </ul>
#   </td>
#  </tr>
#  <tr class="" id="id-wanchain">
#   <td class="text-center">
#    100
#   </td>
#   <td class="no-wrap currency-name" data-sort="Wanchain">
#    <img alt="Wanchain" class="logo-sprite lazyload" data-src="https://s2.coinmarketcap.com/static/img/coins/32x32/2606.png" height="16" src="..." width="16"/>
#    <span class="currency-symbol visible-xs">
#     <a class="link-secondary" href="/pt-br/currencies/wanchain/">
#      WAN
#     </a>
#    </span>
#    <br class="visible-xs"/>
#    <a class="currency-name-container link-secondary" href="/pt-br/currencies/wanchain/">
#     Wanchain
#    </a>
#   </td>
#   <td class="no-wrap market-cap text-right" data-btc="10853.0830661" data-sort="43722564.6487" data-usd="43722564.6487">
#    $43,722,565
#   </td>
#   <td class="no-wrap text-right" data-sort="0.411884483944">
#    <a class="price" data-btc="0.000102240491924" data-usd="0.411884483944" href="/pt-br/currencies/wanchain/#markets">
#     $0.411884
#    </a>
#   </td>
#   <td class="no-wrap text-right" data-sort="4296159.48437">
#    <a class="volume" data-btc="1066.41904755" data-usd="4296159.48437" href="/pt-br/currencies/wanchain/#markets">
#     $4,296,159
#    </a>
#   </td>
#   <td class="no-wrap text-right circulating-supply" data-sort="106152492.636">
#    <span data-supply="106152492.636">
#     <span data-supply-container="">
#      106,152,493
#     </span>
#     <span class="hidden-xs">
#      WAN
#     </span>
#    </span>
#    *
#   </td>
#   <td class="no-wrap percent-change negative_change text-right" data-percentusd="-3.12783" data-sort="-3.12783" data-symbol="WAN" data-timespan="24h">
#    -3.13%
#   </td>
#   <td>
#    <a href="/pt-br/currencies/wanchain/#charts">
#     <img alt="sparkline" class="sparkline lazyload" data-src="https://s2.coinmarketcap.com/generated/sparklines/web/7d/usd/2606.png" height="48" src="https://s2.coinmarketcap.com/static/cloud/img/loading-sparkline.svg" width="164"/>
#    </a>
#   </td>
#   <td class="dropdown" data-cc-id="2606" data-cc-slug="wanchain" data-more-options="">
#    <button class="btn btn-transparent dropdown-toggle" data-toggle="dropdown" id="dropdown-menu-2606" type="button">
#     <span class="glyphicons glyphicons-more text-gray">
#     </span>
#    </button>
#    <ul aria-labelledby="dropdown-menu-2606" class="dropdown-menu dropdown-menu-right" role="menu">
#     <li role="presentation">
#      <a data-watchlist-add="" href="#" role="menuitem" tabindex="-1">
#       Adicionar à lista de interesse
#      </a>
#     </li>
#     <li role="presentation">
#      <a data-watchlist-remove="" href="#" role="menuitem" tabindex="-1">
#       Remover da lista de interesse
#      </a>
#     </li>
#     <li class="disabled" role="presentation">
#      <a data-watchlist-full="" href="#" role="menuitem" tabindex="-1">
#       Lista de interesse cheia!
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/wanchain/#charts" role="menuitem" tabindex="-1">
#       Ver gráfico
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/wanchain/#markets" role="menuitem" tabindex="-1">
#       Ver mercados
#      </a>
#     </li>
#     <li role="presentation">
#      <a href="/pt-br/currencies/wanchain/historical-data/" role="menuitem" tabindex="-1">
#       Ver dados históricos
#      </a>
#     </li>
#    </ul>
#   </td>
#  </tr>
# </tbody>

# %%
rows = table_body.find_all('tr')
data = []
for row in rows:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    data.append([cols[1][5::],cols[2],cols[3],cols[4],cols[5],cols[6]])

# %%
print (data)
# Out:
# [['Bitcoin', '$70,964,220,133', '$4033.33', '$8,235,070,288', '17,594,437\nBTC', '-0.33%'], ['Ethereum', '$14,786,988,884', '$140.46', '$3,837,718,888', '105,278,806\nETH', '-1.34%'], ['XRP', '$13,158,267,122', '$0.317586', '$536,291,873', '41,432,141,931\nXRP\n\n*', '-0.98%'], ['Litecoin', '$3,741,799,964', '$61.41', '$1,605,279,667', '60,926,486\nLTC', '-0.39%'], ['EOS', '$3,432,992,537', '$3.79', '$1,184,644,055', '906,245,118\nEOS\n\n*', '-1.10%'], ['Bitcoin Cash', '$2,775,500,132', '$157.00', '$435,023,280', '17,678,100\nBCH', '-0.08%'], ['Binance Coin', '$2,236,820,013', '$15.84', '$134,841,277', '141,175,490\nBNB\n\n*', '-1.48%'], ['Stellar', '$2,099,573,746', '$0.109235', '$148,212,841', '19,220,739,613\nXLM\n\n*', '-0.53%'], ['\nTether', '$2,022,236,176', '$1.01', '$7,072,114,444', '2,001,684,593\nUSDT\n\n*', '-0.07%'], ['TRON', '$1,547,989,479', '$0.023214', '$158,426,223', '66,682,072,191\nTRX', '-0.60%'], ['Cardano', '$1,307,509,014', '$0.050430', '$28,893,437', '25,927,070,538\nADA', '-1.91%'], ['Bitcoin SV', '$1,212,159,965', '$68.60', '$88,822,570', '17,670,348\nBSV', '-0.77%'], ['Monero', '$906,441,263', '$53.76', '$117,986,865', '16,859,386\nXMR', '-1.44%'], ['\n\nIOTA', '$831,173,177', '$0.299034', '$17,908,336', '2,779,530,283\nMIOTA\n\n*', '-2.17%'], ['\nDash', '$812,276,007', '$93.43', '$222,383,387', '8,694,074\nDASH', '0.44%'], ['Maker', '$697,871,542', '$697.87', '$1,113,086', '1,000,000\nMKR\n\n*', '-0.02%'], ['NEO', '$602,710,021', '$9.27', '$280,116,581', '65,000,000\nNEO\n\n*', '-2.72%'], ['Ontology', '$558,484,278', '$1.13', '$57,815,208', '494,823,234\nONT\n\n*', '4.75%'], ['Ethereum Classic', '$488,444,287', '$4.48', '$184,618,616', '109,038,179\nETC', '-0.94%'], ['NEM', '$456,639,131', '$0.050738', '$17,078,314', '8,999,999,999\nXEM\n\n*', '1.51%'], ['Zcash', '$336,177,779', '$54.96', '$74,392,200', '6,117,244\nZEC', '-0.16%'], ['Tezos', '$299,841,960', '$0.493576', '$5,471,995', '607,489,041\nXTZ\n\n*', '-1.61%'], ['VeChain', '$293,092,879', '$0.005285', '$9,087,347', '55,454,734,800\nVET\n\n*', '-1.35%'], ['\n\nWaves', '$278,437,434', '$2.78', '$10,798,095', '100,000,000\nWAVES\n\n*', '-1.04%'], ['Crypto.com Chain', '$271,598,979', '$0.067285', '$89,010,013', '4,036,529,680\nCRO\n\n*', '-20.46%'], ['\nDogecoin', '$246,725,919', '$0.002079', '$17,571,887', '118,696,359,546\nDOGE', '-0.04%'], ['\nUSD Coin', '$244,366,685', '$1.02', '$37,929,237', '239,327,277\nUSDC\n\n*', '0.57%'], ['Basic Attenti...', '$243,111,062', '$0.195526', '$5,512,222', '1,243,366,787\nBAT\n\n*', '-1.93%'], ['Bitcoin Gold', '$233,653,299', '$13.42', '$10,121,182', '17,413,924\nBTG', '-1.75%'], ['\nQtum', '$226,873,417', '$2.54', '$248,617,857', '89,330,464\nQTUM\n\n*', '0.70%'], ['OmiseGO', '$213,691,100', '$1.52', '$36,015,296', '140,245,398\nOMG\n\n*', '-1.14%'], ['\nTrueUSD', '$202,581,737', '$1.02', '$44,415,017', '198,896,503\nTUSD\n\n*', '-0.33%'], ['Decred', '$186,797,169', '$19.70', '$1,604,529', '9,480,455\nDCR', '1.31%'], ['Lisk', '$179,746,775', '$1.56', '$6,494,669', '115,424,228\nLSK\n\n*', '1.98%'], ['\nChainlink', '$169,646,778', '$0.484705', '$7,305,191', '350,000,000\nLINK\n\n*', '0.08%'], ['DigiByte', '$168,450,588', '$0.014570', '$929,474', '11,561,267,042\nDGB', '1.01%'], ['Augur', '$162,162,772', '$14.74', '$1,914,109', '11,000,000\nREP\n\n*', '5.56%'], ['Zilliqa', '$158,245,523', '$0.018281', '$6,704,420', '8,656,463,775\nZIL\n\n*', '-0.86%'], ['ICON', '$158,061,918', '$0.333882', '$9,458,202', '473,406,688\nICX\n\n*', '-2.42%'], ['Holo', '$157,060,353', '$0.001179', '$8,607,667', '133,214,575,156\nHOT\n\n*', '-6.20%'], ['0x', '$155,576,575', '$0.265535', '$14,197,343', '585,898,791\nZRX\n\n*', '-2.18%'], ['\nABBC Coin', '$152,284,828', '$0.332880', '$37,536,465', '457,476,577\nABBC', '-7.61%'], ['Bytecoin', '$148,020,963', '$0.000804', '$293,213', '184,066,828,814\nBCN', '0.04%'], ['\n\nSteem', '$147,089,025', '$0.478867', '$2,787,266', '307,160,742\nSTEEM\n\n*', '2.36%'], ['BitTorrent', '$143,538, ...

# %%
np.array(data)
# Out:
# array([['1', 'BTC\n\nBitcoin', '$70,960,944,963', '$4033.15',
#         '$8,211,133,788', '17,594,425\nBTC', '-0.31%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['2', 'ETH\n\nEthereum', '$14,792,584,392', '$140.51',
#         '$3,824,321,599', '105,278,621\nETH', '-1.30%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['3', 'XRP\n\nXRP', '$13,145,605,818', '$0.317280',
#         '$538,436,772', '41,432,141,931\nXRP\n\n*', '-1.08%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['4', 'LTC\n\nLitecoin', '$3,750,515,531', '$61.56',
#         '$1,601,061,973', '60,926,486\nLTC', '-0.09%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['5', 'EOS\n\nEOS', '$3,431,897,576', '$3.79', '$1,180,841,075',
#         '906,245,118\nEOS\n\n*', '-1.12%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['6', 'BCH\n\nBitcoin Cash', '$2,778,098,000', '$157.15',
#         '$432,346,742', '17,678,075\nBCH', '0.11%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['7', 'BNB\n\nBinance Coin', '$2,240,434,869', '$15.87',
#         '$134,828,609', '141,175,490\nBNB\n\n*', '-1.32%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['8', 'XLM\n\nStellar', '$2,103,266,383', '$0.109427',
#         '$147,125,843', '19,220,739,613\nXLM\n\n*', '-0.38%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['9', 'USDT\n\nTether', '$2,024,292,518', '$1.01',
#         '$7,041,403,500', '2,001,684,593\nUSDT\n\n*', '0.05%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['10', 'TRX\n\nTRON', '$1,546,697,481', '$0.023195',
#         '$157,297,262', '66,682,072,191\nTRX', '-0.64%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['11', 'ADA\n\nCardano', '$1,298,177,604', '$0.050070',
#         '$28,535,341', '25,927,070,538\nADA', '-2.56%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['12', 'BSV\n\nBitcoin SV', '$1,211,211,844', '$68.54',
#         '$88,629,483', '17,670,348\nBSV', '-0.80%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['13', 'XMR\n\nMonero', '$908,547,462', '$53.89', '$118,772,030',
#         '16,859,356\nXMR', '-1.15%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['14', 'MIOTA\n\nIOTA', '$832,696,236', '$0.299582',
#         '$17,875,934', '2,779,530,283\nMIOTA\n\n*', '-1.93%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['15', 'DASH\n\nDash', '$811,779,728', '$93.37', '$222,103,034',
#         '8,694,060\nDASH', '0.39%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['16', 'MKR\n\nMaker', '$694,787,367', '$694.79', '$1,106,717',
#         '1,000,000\nMKR\n\n*', '-0.43%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['17', 'NEO\n\nNEO', '$604,147,995', '$9.29', '$279,006,869',
#         '65,000,000\nNEO\n\n*', '-2.47%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['18', 'ONT\n\nOntology', '$555,795,213', '$1.12', '$56,691,937',
#         '494,823,234\nONT\n\n*', '4.41%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['19', 'ETC\n\nEthereum Classic', '$488,712,612', '$4.48',
#         '$184,577,142', '109,037,867\nETC', '-0.87%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['20', 'XEM\n\nNEM', '$456,735,233', '$0.050748', '$17,137,666',
#         '8,999,999,999\nXEM\n\n*', '1.57%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['21', 'ZEC\n\nZcash', '$336,951,871', '$55.08', '$74,500,166',
#         '6,117,156\nZEC', '0.09%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['22', 'XTZ\n\nTezos', '$299,796,949', '$0.493502', '$5,481,263',
#         '607,489,041\nXTZ\n\n*', '-1.56%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['23', 'VET\n\nVeChain', '$295,028,465', '$0.005320',
#         '$9,081,214', '55,454,734,800\nVET\n\n*', '-0.67%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['24', 'WAVES\n\nWaves', '$278,991,431', '$2.79', '$10,830,086',
#         '100,000,000\nWAVES\n\n*', '-0.85%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['25', 'CRO\n\nCrypto.com Chain', '$270,198,720', '$0.066938',
#         '$89,080,899', '4,036,529,680\nCRO\n\n*', '-21.12%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['26', 'DOGE\n\nDogecoin', '$246,444,864', '$0.002076',
#         '$17,545,202', '118,696,359,546\nDOGE', '-0.15%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['27', 'USDC\n\nUSD Coin', '$244,224,018', '$1.02', '$37,703,676',
#         '239,327,277\nUSDC\n\n*', '0.52%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['28', 'BAT\n\nBasic Attenti...', '$243,005,634', '$0.195442',
#         '$5,496,836', '1,243,366,787\nBAT\n\n*', '-1.98%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['29', 'BTG\n\nBitcoin Gold', '$233,451,368', '$13.41',
#         '$10,070,959', '17,413,924\nBTG', '-1.82%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['30', 'QTUM\n\nQtum', '$227,517,705', '$2.55', '$248,843,438',
#         '89,330,464\nQTUM\n\n*', '0.97%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['31', 'OMG\n\nOmiseGO', '$214,311,696', '$1.53', '$36,055,447',
#         '140,245,398\nOMG\n\n*', '-0.84%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['32', 'TUSD\n\nTrueUSD', '$202,572,781', '$1.02', '$44,311,930',
#         '198,896,503\nTUSD\n\n*', '-0.33%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['33', 'DCR\n\nDecred', '$187,347,452', '$19.76', '$1,604,266',
#         '9,480,316\nDCR', '1.63%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['34', 'LSK\n\nLisk', '$180,367,910', '$1.56', '$6,453,260',
#         '115,423,865\nLSK\n\n*', '2.28%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['35', 'LINK\n\nChainlink', '$169,752,986', '$0.485009',
#         '$7,311,933', '350,000,000\nLINK\n\n*', '0.16%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['36', 'DGB\n\nDigiByte', '$168,243,304', '$0.014552', '$936,480',
#         '11,561,202,295\nDGB', '0.94%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['37', 'REP\n\nAugur', '$161,997,014', '$14.73', '$1,853,766',
#         '11,000,000\nREP\n\n*', '5.52%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['38', 'ICX\n\nICON', '$159,131,011', '$0.336140', '$9,420,253',
#         '473,406,688\nICX\n\n*', '-1.72%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['39', 'HOT\n\nHolo', '$158,472,481', '$0.001190', '$8,656,248',
#         '133,214,575,156\nHOT\n\n*', '-5.24%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['40', 'ZIL\n\nZilliqa', '$158,406,752', '$0.018299',
#         '$6,701,955', '8,656,463,775\nZIL\n\n*', '-0.75%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['41', 'ZRX\n\n0x', '$156,000,433', '$0.266256', '$14,321,046',
#         '585,904,357\nZRX\n\n*', '-1.91%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['42', 'ABBC\n\nABBC Coin', '$152,508,911', '$0.333370',
#         '$37,743,067', '457,476,577\nABBC', '-7.42%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['43', 'BCN\n\nBytecoin', '$148,101,274', '$0.000805', '$292,738',
#         '184,066,828,814\nBCN', '0.21%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['44', 'STEEM\n\nSteem', '$147,192,897', '$0.479206',
#         '$2,795,627', '307,159,693\nSTEEM\n\n*', '2.43%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['45', 'BTT\n\nBitTorrent', '$143,797,378', '$0.000844',
#         '$95,454,631', '170,421,000,000\nBTT\n\n*', '6.16%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['46', 'NANO\n\nNano', '$139,087,085', '$1.04', '$2,832,527',
#         '133,248,289\nNANO\n\n*', '3.91%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['47', 'BTS\n\nBitShares', '$138,047,038', '$0.051161',
#         '$2,146,648', '2,698,280,000\nBTS\n\n*', '-0.79%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['48', 'BCD\n\nBitcoin Diamond', '$136,103,613', '$0.885187',
#         '$1,985,676', '153,756,875\nBCD', '-0.59%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['49', 'ENJ\n\nEnjin Coin', '$131,184,313', '$0.171034',
#         '$10,338,146', '767,007,985\nENJ\n\n*', '2.07%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['50', 'THETA\n\nTHETA', '$128,229,971', '$0.128230',
#         '$5,777,062', '1,000,000,000\nTHETA\n\n*', '-1.81%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['51', 'KMD\n\nKomodo', '$125,610,163', '$1.12', '$1,205,235',
#         '112,300,674\nKMD', '0.96%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['52', 'PAX\n\nPaxos Standar...', '$118,337,248', '$1.01',
#         '$50,165,243', '116,660,797\nPAX\n\n*', '0.05%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['53', 'AE\n\nAeternity', '$117,958,015', '$0.464808',
#         '$68,938,983', '253,777,892\nAE\n\n*', '-2.29%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['54', 'NPXS\n\nPundi X', '$116,125,538', '$0.000666',
#         '$2,277,981', '174,450,657,817\nNPXS\n\n*', '1.20%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['55', 'XVG\n\nVerge', '$113,063,103', '$0.007165', '$1,440,280',
#         '15,780,853,598\nXVG', '1.63%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['56', 'SC\n\nSiacoin', '$108,560,958', '$0.002722', '$810,292',
#         '39,875,938,005\nSC', '-0.95%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['57', 'HT\n\nHuobi Token', '$103,745,171', '$2.07',
#         '$28,573,377', '50,000,200\nHT\n\n*', '-1.10%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['58', 'BTM\n\nBytom', '$103,328,069', '$0.103070', '$3,547,545',
#         '1,002,499,275\nBTM', '1.18%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['59', 'AOA\n\nAurora', '$100,982,040', '$0.015435', '$1,953,064',
#         '6,542,330,148\nAOA\n\n*', '7.78%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['60', 'STRAT\n\nStratis', '$96,002,264', '$0.967252',
#         '$1,106,101', '99,252,596\nSTRAT\n\n*', '0.77%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['61', 'DAI\n\nDai', '$94,390,560', '$0.991846', '$34,550,437',
#         '95,166,558\nDAI\n\n*', '-0.41%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['62', 'IOST\n\nIOST', '$93,582,385', '$0.007789', '$6,551,154',
#         '12,013,965,609\nIOST\n\n*', '0.49%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['63', 'RVN\n\nRavencoin', '$89,721,844', '$0.028722',
#         '$6,146,923', '3,123,825,000\nRVN', '2.56%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['64', 'SNT\n\nStatus', '$78,634,604', '$0.022658', '$9,191,160',
#         '3,470,483,788\nSNT\n\n*', '-1.41%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['65', 'PPT\n\nPopulous', '$77,837,010', '$1.46', '$1,838,711',
#         '53,252,246\nPPT\n\n*', '0.00%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['66', 'KCS\n\nKuCoin Shares', '$73,269,046', '$0.814644',
#         '$779,770', '89,939,916\nKCS\n\n*', '1.53%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['67', 'GNT\n\nGolem', '$73,025,801', '$0.075783', '$701,136',
#         '963,622,000\nGNT\n\n*', '0.35%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['68', 'REPO\n\nREPO', '$72,418,662', '$0.658599', '$78,770',
#         '109,958,607\nREPO\n\n*', '-2.01%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['69', 'ARK\n\nArk', '$69,899,618', '$0.641152', '$636,681',
#         '109,021,916\nARK\n\n*', '-1.23%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['70', 'ARDR\n\nArdor', '$69,054,400', '$0.069124', '$828,415',
#         '998,999,495\nARDR\n\n*', '1.26%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['71', 'PAI\n\nProject Pai', '$67,199,960', '$0.046346',
#         '$1,262,439', '1,449,954,955\nPAI\n\n*', '-0.03%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['72', 'R\n\nRevain', '$66,985,216', '$0.138271', '$218,323',
#         '484,450,000\nR\n\n*', '-1.56%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['73', 'GUSD\n\nGemini Dollar', '$66,957,483', '$1.02',
#         '$2,933,427', '65,877,557\nGUSD\n\n*', '0.15%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['74', 'INB\n\nInsight Chain', '$65,754,535', '$0.251305',
#         '$4,309,105', '261,652,689\nINB\n\n*', '-8.28%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['75', 'XIN\n\nMixin', '$64,213,403', '$148.19', '$349,693',
#         '433,314\nXIN\n\n*', '-26.30%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['76', 'CNX\n\nCryptonex', '$63,835,656', '$1.15', '$5,857,681',
#         '55,686,329\nCNX', '-0.68%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['77', 'MXM\n\nMaximine Coin', '$63,396,592', '$0.038445',
#         '$5,179,101', '1,649,000,000\nMXM\n\n*', '3.31%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['78', 'WAX\n\nWAX', '$61,720,244', '$0.065476', '$1,356,159',
#         '942,640,072\nWAX\n\n*', '6.44%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['79', 'FCT\n\nFactom', '$61,446,167', '$6.53', '$115,146',
#         '9,405,062\nFCT\n\n*', '-1.84%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['80', 'DGTX\n\nDigitex Futures', '$59,731,027', '$0.080991',
#         '$1,451,547', '737,500,000\nDGTX\n\n*', '-0.52%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['81', 'ETN\n\nElectroneum', '$59,105,494', '$0.006483',
#         '$333,473', '9,117,606,610\nETN', '-1.57%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['82', 'HC\n\nHyperCash', '$58,877,627', '$1.35', '$1,777,385',
#         '43,529,781\nHC', '1.26%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['83', 'MAID\n\nMaidSafeCoin', '$57,782,617', '$0.127682',
#         '$218,614', '452,552,412\nMAID\n\n*', '0.90%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['84', 'GXC\n\nGXChain', '$56,567,410', '$0.942790', '$9,639,636',
#         '60,000,000\nGXC\n\n*', '3.97%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['85', 'WTC\n\nWaltonchain', '$54,552,726', '$1.33', '$3,386,747',
#         '41,007,759\nWTC\n\n*', '-2.89%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['86', 'MCO\n\nCrypto.com', '$53,880,006', '$3.41', '$3,029,363',
#         '15,793,831\nMCO\n\n*', '4.51%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['87', 'MANA\n\nDecentraland', '$53,702,744', '$0.051139',
#         '$2,681,572', '1,050,141,509\nMANA\n\n*', '3.26%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['88', 'LRC\n\nLoopring', '$53,077,145', '$0.064029', '$855,262',
#         '828,954,240\nLRC\n\n*', '-1.75%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['89', 'QASH\n\nQASH', '$53,005,691', '$0.151445', '$199,861',
#         '350,000,000\nQASH\n\n*', '1.08%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['90', 'LOOM\n\nLoom Network', '$52,299,347', '$0.068538',
#         '$1,227,924', '763,068,448\nLOOM\n\n*', '2.19%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['91', 'QBIT\n\nQubitica', '$51,071,480', '$18.20', '$88,769',
#         '2,805,389\nQBIT\n\n*', '0.53%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['92', 'NEXO\n\nNexo', '$48,796,250', '$0.087136', '$7,433,427',
#         '560,000,011\nNEXO\n\n*', '2.02%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['93', 'XZC\n\nZcoin', '$48,297,069', '$6.89', '$975,475',
#         '7,010,421\nXZC', '0.36%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['94', 'ELF\n\naelf', '$48,268,169', '$0.172386', '$4,658,685',
#         '280,000,000\nELF\n\n*', '1.24%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['95', 'PIVX\n\nPIVX', '$47,412,892', '$0.835011', '$347,687',
#         '56,781,166\nPIVX\n\n*', '-2.17%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['96', 'THR\n\nThoreCoin', '$46,263,825', '$533.69', '$99,054',
#         '86,686\nTHR\n\n*', '-4.34%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['97', 'ORME\n\nOrmeus Coin', '$46,045,188', '$1.28',
#         '$2,626,103', '35,904,998\nORME\n\n*', '2.94%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['98', 'MOAC\n\nMOAC', '$45,935,598', '$0.735401', '$35,639',
#         '62,463,334\nMOAC\n\n*', '-2.07%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['99', 'ETP\n\nMetaverse ETP', '$44,660,231', '$0.745165',
#         '$2,586,899', '59,933,347\nETP', '1.31%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos'],
#        ['100', 'WAN\n\nWanchain', '$43,861,948', '$0.413198',
#         '$4,303,802', '106,152,493\nWAN\n\n*', '-2.84%',
#         'Adicionar à lista de interesse\nRemover da lista de interesse\nLista de interesse cheia!\nVer gráfico\nVer mercados\nVer dados históricos']],
#       dtype='<U132')
