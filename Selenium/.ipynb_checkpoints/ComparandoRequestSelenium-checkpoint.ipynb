# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
url = 'https://www.infomoney.com.br/cryptos/cotacoes'

res = requests.get(url)
soup = BeautifulSoup(res.text, 'html.parser')
table = soup.find('table', attrs={'class':'display border-t-brown-3'})
print (table.find('tbody').prettify)
# Out:
# <bound method Tag.prettify of <tbody>
# <tr ng-repeat="item in cryptos | orderBy:sortType:sortReverse | filter:searchCrypto">
# <td class="text-center priority-2">{{item.Position}}</td>
# <td class="priority-1"><img alt="{{item.FullName}}" ng-hide="{{item.ImageUrl == ''}}" ng-src="{{item.ImageUrl + '?width=25'}}"/> {{item.FullName}}</td>
# <td class="text-right priority-3">{{item.MarketCap == 0 ? '-' : item.MarketCap | currency :"R$ ": 0}}</td>
# <td class="text-right priority-1">{{item.PriceBRL == 0 ? '-' : item.PriceBRL | currency:"R$ " }}</td>
# <td class="text-right priority-4"> BTC {{item.PriceBTC == 0 ? '0' : item.PriceBTC | decimalFilter }}</td>
# <td class="text-right priority-4">{{item.TotalVolume24H == 0 ? '-' : item.TotalVolume24H | currency:"R$ ": 0 }}</td>
# <td class="text-right priority-1"><span ng-class="{'negativo': item.ChangePct24H &lt;= 0,'positivo': item.ChangePct24H &gt; 0 ,'neutro': item.ChangePct24H == 0 }">{{item.ChangePct24H | number :2}} %</span></td>
# </tr>
# </tbody>>

# %%
from selenium import webdriver
driver = webdriver.Chrome(executable_path="/home/s2it_csilva/Downloads/chromedriver")

driver.get(url)
soup = BeautifulSoup(driver.page_source, 'html.parser')
table = soup.find('table', attrs={'class':'display border-t-brown-3'})

data = []
table_body = table.find('tbody')
rows = table_body.find_all('tr')
for row in rows:
	cols = row.find_all('td')
	cols = [ele.text.strip() for ele in cols]
	data.append([ele for ele in cols if ele])
	info = [ele for ele in cols if ele]
	post = {
			"index" : info[0],
			"name" : info[1],
			"marketvalue" : info[2],
			"pricers" : info[3],
			"pricebtc" : info[4],
			"total" : info[5],
			"variation" : info[6]
	}

	print(post)
	print("---------------")

driver.close()
# Out:
# {'index': '1', 'name': 'Bitcoin', 'marketvalue': 'R$ 593.058.962.078', 'pricers': 'R$ 33.439,02', 'pricebtc': 'BTC 1.00000000', 'total': 'R$ 87.772.169.257', 'variation': '0,87 %'}
# ---------------
# {'index': '2', 'name': 'Ethereum', 'marketvalue': 'R$ 110.087.862.899', 'pricers': 'R$ 1.035,50', 'pricebtc': 'BTC 0.03104400', 'total': 'R$ 38.786.861.601', 'variation': '0,68 %'}
# ---------------
# {'index': '3', 'name': 'XRP', 'marketvalue': 'R$ 70.693.961.510', 'pricers': 'R$ 1,68', 'pricebtc': 'BTC 0.00005024', 'total': 'R$ 6.883.520.629', 'variation': '-0,39 %'}
# ---------------
# {'index': '4', 'name': 'Bitcoin Cash', 'marketvalue': 'R$ 30.350.368.363', 'pricers': 'R$ 1.703,70', 'pricebtc': 'BTC 0.05107607', 'total': 'R$ 7.035.525.304', 'variation': '0,47 %'}
# ---------------
# {'index': '5', 'name': 'EOS', 'marketvalue': 'R$ 28.710.368.557', 'pricers': 'R$ 31,30', 'pricebtc': 'BTC 0.00093828', 'total': 'R$ 19.517.486.022', 'variation': '-1,07 %'}
# ---------------
# {'index': '6', 'name': 'Litecoin', 'marketvalue': 'R$ 27.280.709.091', 'pricers': 'R$ 439,77', 'pricebtc': 'BTC 0.01318403', 'total': 'R$ 14.368.517.263', 'variation': '1,45 %'}
# ---------------
# {'index': '7', 'name': 'Binance Coin', 'marketvalue': 'R$ 18.201.484.597', 'pricers': 'R$ 128,93', 'pricebtc': 'BTC 0.00386605', 'total': 'R$ 2.178.199.290', 'variation': '2,58 %'}
# ---------------
# {'index': '8', 'name': 'Bitcoin SV', 'marketvalue': 'R$ 13.155.513.673', 'pricers': 'R$ 738,56', 'pricebtc': 'BTC 0.02214183', 'total': 'R$ 1.831.730.757', 'variation': '-0,43 %'}
# ---------------
# {'index': '9', 'name': 'Tether', 'marketvalue': 'R$ 12.294.103.799', 'pricers': 'R$ 3,93', 'pricebtc': 'BTC 0.00011773', 'total': 'R$ 87.829.579.687', 'variation': '0,02 %'}
# ---------------
# {'index': '10', 'name': 'TRON', 'marketvalue': 'R$ 10.157.878.444', 'pricers': 'R$ 0,15', 'pricebtc': 'BTC 0.00000457', 'total': 'R$ 5.866.313.330', 'variation': '21,27 %'}
# ---------------
# {'index': '11', 'name': 'Stellar', 'marketvalue': 'R$ 9.899.737.176', 'pricers': 'R$ 0,51', 'pricebtc': 'BTC 0.00001536', 'total': 'R$ 1.748.937.045', 'variation': '-0,10 %'}
# ---------------
# {'index': '12', 'name': 'Cardano', 'marketvalue': 'R$ 8.972.440.482', 'pricers': 'R$ 0,35', 'pricebtc': 'BTC 0.00001038', 'total': 'R$ 523.281.740', 'variation': '1,64 %'}
# ---------------
# {'index': '13', 'name': 'Monero', 'marketvalue': 'R$ 6.178.817.838', 'pricers': 'R$ 363,11', 'pricebtc': 'BTC 0.01088827', 'total': 'R$ 383.256.121', 'variation': '-0,25 %'}
# ---------------
# {'index': '14', 'name': 'Dash', 'marketvalue': 'R$ 5.663.880.609', 'pricers': 'R$ 640,89', 'pricebtc': 'BTC 0.01921364', 'total': 'R$ 1.743.239.802', 'variation': '0,90 %'}
# ---------------
# {'index': '15', 'name': 'IOTA', 'marketvalue': 'R$ 5.205.122.109', 'pricers': 'R$ 1,87', 'pricebtc': 'BTC 0.00005615', 'total': 'R$ 190.078.581', 'variation': '-3,70 %'}
# ---------------
# {'index': '16', 'name': 'Cosmos', 'marketvalue': 'R$ 4.267.786.552', 'pricers': 'R$ 22,38', 'pricebtc': 'BTC 0.00067097', 'total': 'R$ 502.889.452', 'variation': '-0,75 %'}
# ---------------
# {'index': '17', 'name': 'Tezos', 'marketvalue': 'R$ 3.883.116.690', 'pricers': 'R$ 5,87', 'pricebtc': 'BTC 0.00017594', 'total': 'R$ 22.475.696', 'variation': '0,44 %'}
# ---------------
# {'index': '18', 'name': 'Ethereum Classic', 'marketvalue': 'R$ 3.717.691.559', 'pricers': 'R$ 33,52', 'pricebtc': 'BTC 0.00100506', 'total': 'R$ 3.285.221.992', 'variation': '2,13 %'}
# ---------------
# {'index': '19', 'name': 'NEO', 'marketvalue': 'R$ 3.520.192.442', 'pricers': 'R$ 54,16', 'pricebtc': 'BTC 0.00162360', 'total': 'R$ 2.437.249.307', 'variation': '5,42 %'}
# ---------------
# {'index': '19', 'name': 'SpankChain', 'marketvalue': 'R$ 3.401.748.601', 'pricers': 'R$ 11,34', 'pricebtc': 'BTC 0.00043243', 'total': 'R$ 11.363', 'variation': '6.139,12 %'}
# ---------------
# {'index': '19', 'name': 'VeChain', 'marketvalue': 'R$ 3.332.469.001', 'pricers': 'R$ 6,01', 'pricebtc': 'BTC 0.00021655', 'total': 'R$ 11.904.579', 'variation': '-10,19 %'}
# ---------------
# {'index': '20', 'name': 'NEM', 'marketvalue': 'R$ 3.308.215.639', 'pricers': 'R$ 0,37', 'pricebtc': 'BTC 0.00001102', 'total': 'R$ 120.249.647', 'variation': '0,04 %'}
# ---------------
# {'index': '21', 'name': 'Ontology', 'marketvalue': 'R$ 2.891.155.779', 'pricers': 'R$ 5,84', 'pricebtc': 'BTC 0.00017519', 'total': 'R$ 966.325.005', 'variation': '1,93 %'}
# ---------------
# {'index': '22', 'name': 'Maker', 'marketvalue': 'R$ 2.830.001.647', 'pricers': 'R$ 2.830,00', 'pricebtc': 'BTC 0.08486061', 'total': 'R$ 25.139.408', 'variation': '-1,77 %'}
# ---------------
# {'index': '15', 'name': 'empowr coin', 'marketvalue': 'R$ 2.304.137.767', 'pricers': 'R$ 0,00', 'pricebtc': 'BTC 0.00000002', 'total': 'R$ 2.180', 'variation': '48,55 %'}
# ---------------
# {'index': '23', 'name': 'Zcash', 'marketvalue': 'R$ 2.258.330.448', 'pricers': 'R$ 339,04', 'pricebtc': 'BTC 0.01016420', 'total': 'R$ 1.956.447.489', 'variation': '-2,32 %'}
# ---------------
# {'index': '24', 'name': 'Bitcoin Gold', 'marketvalue': 'R$ 1.974.990.863', 'pricers': 'R$ 112,77', 'pricebtc': 'BTC 0.00338144', 'total': 'R$ 117.107.583', 'variation': '1,90 %'}
# ---------------
# {'index': '25', 'name': 'Crypto.com Chain', 'marketvalue': 'R$ 1.839.977.744', 'pricers': 'R$ 0,29', 'pricebtc': 'BTC 0.00000855', 'total': 'R$ 80.565.695', 'variation': '-0,42 %'}
# ---------------
# {'index': '26', 'name': 'Basic Attention Token', 'marketvalue': 'R$ 1.779.742.853', 'pricers': 'R$ 1,40', 'pricebtc': 'BTC 0.00004209', 'total': 'R$ 170.458.397', 'variation': '3,60 %'}
# ---------------
# {'index': '27', 'name': 'VeChain', 'marketvalue': 'R$ 1.619.155.492', 'pricers': 'R$ 0,03', 'pricebtc': 'BTC 0.00000088', 'total': 'R$ 58.766.907', 'variation': '-0,68 %'}
# ---------------
# {'index': '28', 'name': 'Dogecoin', 'marketvalue': 'R$ 1.598.983.306', 'pricers': 'R$ 0,01', 'pricebtc': 'BTC 0.00000040', 'total': 'R$ 325.625.968', 'variation': '1,15 %'}
# ---------------
# {'index': '29', 'name': 'BitTorrent', 'marketvalue': 'R$ 1.421.637.652', 'pricers': 'R$ 0,01', 'pricebtc': 'BTC 0.00000020', 'total': 'R$ 836.403.434', 'variation': '12,27 %'}
# ---------------
# {'index': '21', 'name': 'Iconomi', 'marketvalue': 'R$ 1.380.892.003', 'pricers': 'R$ 13,96', 'pricebtc': 'BTC 0.00084725', 'total': 'R$ 22.362', 'variation': '1.558,16 %'}
# ---------------
# {'index': '59', 'name': 'DNotes', 'marketvalue': 'R$ 1.348.661.145', 'pricers': 'R$ 8,76', 'pricebtc': 'BTC 0.00026178', 'total': 'R$ 1.842', 'variation': '-0,57 %'}
# ---------------
# {'index': '30', 'name': 'Chainlink', 'marketvalue': 'R$ 1.340.659.736', 'pricers': 'R$ 3,83', 'pricebtc': 'BTC 0.00011486', 'total': 'R$ 110.594.236', 'variation': '-2,95 %'}
# ---------------
# {'index': '31', 'name': 'Qtum', 'marketvalue': 'R$ 1.340.320.825', 'pricers': 'R$ 14,00', 'pricebtc': 'BTC 0.00041960', 'total': 'R$ 1.490.996.107', 'variation': '10,31 %'}
# ---------------
# {'index': '32', 'name': 'USD Coin', 'marketvalue': 'R$ 1.308.815.215', 'pricers': 'R$ 3,92', 'pricebtc': 'BTC 0.00011757', 'total': 'R$ 299.173.339', 'variation': '-0,28 %'}
# ---------------
# {'index': '33', 'name': 'OmiseGO', 'marketvalue': 'R$ 1.243.296.529', 'pricers': 'R$ 8,87', 'pricebtc': 'BTC 0.00026577', 'total': 'R$ 469.441.356', 'variation': '0,90 %'}
# ---------------
# {'index': '34', 'name': 'Holo', 'marketvalue': 'R$ 1.193.230.566', 'pricers': 'R$ 0,01', 'pricebtc': 'BTC 0.00000027', 'total': 'R$ 126.771.776', 'variation': '-0,14 %'}
# ---------------
# {'index': '75', 'name': 'Time New Bank', 'marketvalue': 'R$ 1.105.668.795', 'pricers': 'R$ 0,47', 'pricebtc': 'BTC 0.00001693', 'total': 'R$ 11.880.438', 'variation': '657,14 %'}
# ---------------
# {'index': '35', 'name': 'Decred', 'marketvalue': 'R$ 1.097.733.819', 'pricers': 'R$ 111,24', 'pricebtc': 'BTC 0.00333562', 'total': 'R$ 8.380.285', 'variation': '1,30 %'}
# ---------------
# {'index': '76', 'name': 'DeepBrain Chain', 'marketvalue': 'R$ 1.050.101.003', 'pricers': 'R$ 0,70', 'pricebtc': 'BTC 0.00002531', 'total': 'R$ 6.407.629', 'variation': '728,09 %'}
# ---------------
# {'index': '36', 'name': 'Waves', 'marketvalue': 'R$ 1.028.065.697', 'pricers': 'R$ 10,28', 'pricebtc': 'BTC 0.00030828', 'total': 'R$ 121.458.341', 'variation': '0,83 %'}
# ---------------
# {'index': '37', 'name': 'Bitcoin Diamond', 'marketvalue': 'R$ 1.000.559.447', 'pricers': 'R$ 5,37', 'pricebtc': 'BTC 0.00016088', 'total': 'R$ 42.444.416', 'variation': '0,73 %'}
# ---------------
# {'index': '38', 'name': 'TrueUSD', 'marketvalue': 'R$ 956.801.226', 'pricers': 'R$ 3,94', 'pricebtc': 'BTC 0.00011801', 'total': 'R$ 717.222.568', 'variation': '0,18 %'}
# ---------------
# {'index': '39', 'name': 'Ravencoin', 'marketvalue': 'R$ 952.877.739', 'pricers': 'R$ 0,26', 'pricebtc': 'BTC 0.00000779', 'total': 'R$ 226.164.493', 'variation': '9,92 %'}
# ---------------
# {'index': '40', 'name': 'Lisk', 'marketvalue': 'R$ 944.482.573', 'pricers': 'R$ 8,05', 'pricebtc': 'BTC 0.00024126', 'total': 'R$ 17.609.063', 'variation': '0,22 %'}
# ---------------
# {'index': '84', 'name': 'Jibrel Network', 'marketvalue': 'R$ 890.161.994', 'pricers': 'R$ 5,56', 'pricebtc': 'BTC 0.00020113', 'total': 'R$ 3.749.321', 'variation': '972,45 %'}
# ---------------
# {'index': '41', 'name': 'Nano', 'marketvalue': 'R$ 881.235.528', 'pricers': 'R$ 6,61', 'pricebtc': 'BTC 0.00019831', 'total': 'R$ 55.158.383', 'variation': '-0,78 %'}
# ---------------
# {'index': '86', 'name': 'eosDAC', 'marketvalue': 'R$ 847.537.591', 'pricers': 'R$ 1,28', 'pricebtc': 'BTC 0.00004637', 'total': 'R$ 6.164.439', 'variation': '894,75 %'}
# ---------------
# {'index': '42', 'name': 'Augur', 'marketvalue': 'R$ 838.677.859', 'pricers': 'R$ 76,24', 'pricebtc': 'BTC 0.00228624', 'total': 'R$ 89.453.021', 'variation': '0,28 %'}
# ---------------
# {'index': '43', 'name': 'Pundi X', 'marketvalue': 'R$ 828.396.604', 'pricers': 'R$ 0,00', 'pricebtc': 'BTC 0.00000012', 'total': 'R$ 75.211.572', 'variation': '-0,52 %'}
# ---------------
# {'index': '91', 'name': 'Mobius', 'marketvalue': 'R$ 808.432.903', 'pricers': 'R$ 2,15', 'pricebtc': 'BTC 0.00007759', 'total': 'R$ 5.038.211', 'variation': '870,65 %'}
# ---------------
# {'index': '92', 'name': 'Quantum Resistant Ledger', 'marketvalue': 'R$ 805.871.185', 'pricers': 'R$ 15,50', 'pricebtc': 'BTC 0.00056026', 'total': 'R$ 1.674.009', 'variation': '818,93 %'}
# ---------------
# {'index': '93', 'name': 'SONM', 'marketvalue': 'R$ 796.105.778', 'pricers': 'R$ 2,21', 'pricebtc': 'BTC 0.00008004', 'total': 'R$ 3.672.679', 'variation': '554,95 %'}
# ---------------
# {'index': '44', 'name': '0x', 'marketvalue': 'R$ 792.403.011', 'pricers': 'R$ 1,33', 'pricebtc': 'BTC 0.00003975', 'total': 'R$ 84.736.633', 'variation': '0,81 %'}
# ---------------
# {'index': '95', 'name': 'Eidoo', 'marketvalue': 'R$ 780.593.108', 'pricers': 'R$ 26,68', 'pricebtc': 'BTC 0.00096440', 'total': 'R$ 4.219.230', 'variation': '800,58 %'}
# ---------------
# {'index': '96', 'name': 'United Traders Token', 'marketvalue': 'R$ 776.029.306', 'pricers': 'R$ 20,78', 'pricebtc': 'BTC 0.00075130', 'total': 'R$ 415.912', 'variation': '890,63 %'}
# ---------------
# {'index': '97', 'name': 'Primecoin', 'marketvalue': 'R$ 774.343.728', 'pricers': 'R$ 31,65', 'pricebtc': 'BTC 0.00114420', 'total': 'R$ 3.296.645', 'variation': '692,99 %'}
# ---------------
# {'index': '98', 'name': 'Genaro Network', 'marketvalue': 'R$ 767.877.968', 'pricers': 'R$ 2,41', 'pricebtc': 'BTC 0.00008705', 'total': 'R$ 3.692.811', 'variation': '630,01 %'}
# ---------------
# {'index': '45', 'name': 'MonaCoin', 'marketvalue': 'R$ 765.406.394', 'pricers': 'R$ 11,64', 'pricebtc': 'BTC 0.00034918', 'total': 'R$ 723.206.429', 'variation': '42,09 %'}
# ---------------
# {'index': '46', 'name': 'Bytecoin', 'marketvalue': 'R$ 749.736.498', 'pricers': 'R$ 0,00', 'pricebtc': 'BTC 0.00000012', 'total': 'R$ 1.097.369', 'variation': '0,73 %'}
# ---------------
# {'index': '100', 'name': 'Achain', 'marketvalue': 'R$ 746.032.631', 'pricers': 'R$ 1,56', 'pricebtc': 'BTC 0.00004460', 'total': 'R$ 278.291.031', 'variation': '20,50 %'}
# ---------------
# {'index': '37', 'name': 'UGAS', 'marketvalue': 'R$ 740.242.534', 'pricers': 'R$ 4,77', 'pricebtc': 'BTC 0.00023117', 'total': 'R$ 3.438.859', 'variation': '519,56 %'}
# ---------------
# {'index': '47', 'name': 'BitShares', 'marketvalue': 'R$ 730.117.889', 'pricers': 'R$ 0,27', 'pricebtc': 'BTC 0.00000804', 'total': 'R$ 24.362.100', 'variation': '0,27 %'}
# ---------------
# {'index': '48', 'name': 'ICON', 'marketvalue': 'R$ 725.449.531', 'pricers': 'R$ 1,53', 'pricebtc': 'BTC 0.00004595', 'total': 'R$ 62.757.115', 'variation': '-0,58 %'}
# ---------------
# {'index': '49', 'name': 'Aurora', 'marketvalue': 'R$ 723.175.624', 'pricers': 'R$ 0,11', 'pricebtc': 'BTC 0.00000331', 'total': 'R$ 4.918.258', 'variation': '-13,87 %'}
# ---------------
# {'index': '50', 'name': 'DigiByte', 'marketvalue': 'R$ 714.190.776', 'pricers': 'R$ 0,06', 'pricebtc': 'BTC 0.00000181', 'total': 'R$ 15.198.151', 'variation': '2,98 %'}
# ---------------
# {'index': '100', 'name': 'Request Network', 'marketvalue': 'R$ 685.623.931', 'pricers': 'R$ 1,03', 'pricebtc': 'BTC 0.00003143', 'total': 'R$ 21.759.067', 'variation': '5,65 %'}
# ---------------
# {'index': '100', 'name': 'Nucleus Vision', 'marketvalue': 'R$ 677.921.158', 'pricers': 'R$ 0,16', 'pricebtc': 'BTC 0.00000482', 'total': 'R$ 96.326.935', 'variation': '-1,75 %'}
# ---------------
# {'index': '82', 'name': 'Credits', 'marketvalue': 'R$ 675.677.545', 'pricers': 'R$ 4,88', 'pricebtc': 'BTC 0.00017612', 'total': 'R$ 7.630.176', 'variation': '451,16 %'}
# ---------------
# {'index': '76', 'name': 'Game.com', 'marketvalue': 'R$ 673.129.111', 'pricers': 'R$ 0,88', 'pricebtc': 'BTC 0.00003194', 'total': 'R$ 50.316.537', 'variation': '250,27 %'}
# ---------------
# {'index': '51', 'name': 'Komodo', 'marketvalue': 'R$ 669.764.520', 'pricers': 'R$ 5,89', 'pricebtc': 'BTC 0.00017662', 'total': 'R$ 25.220.337', 'variation': '5,50 %'}
# ---------------
# {'index': '52', 'name': 'Zilliqa', 'marketvalue': 'R$ 664.820.888', 'pricers': 'R$ 0,08', 'pricebtc': 'BTC 0.00000229', 'total': 'R$ 140.945.222', 'variation': '-1,58 %'}
# ---------------
# {'index': '53', 'name': 'Paxos Standard Token', 'marketvalue': 'R$ 655.028.884', 'pricers': 'R$ 3,93', 'pricebtc': 'BTC 0.00011778', 'total': 'R$ 493.875.580', 'variation': '0,03 %'}
# ---------------
# {'index': '54', 'name': 'Verge', 'marketvalue': 'R$ 646.672.088', 'pricers': 'R$ 0,04', 'pricebtc': 'BTC 0.00000120', 'total': 'R$ 21.133.637', 'variation': '3,76 %'}
# ---------------
# {'index': '33', 'name': 'Paragon', 'marketvalue': 'R$ 640.981.879', 'pricers': 'R$ 9,72', 'pricebtc': 'BTC 0.00066454', 'total': 'R$ 11.557.232', 'variation': '1.413,44 %'}
# ---------------
# {'index': '93', 'name': 'Neblio', 'marketvalue': 'R$ 629.984.210', 'pricers': 'R$ 48,07', 'pricebtc': 'BTC 0.00161525', 'total': 'R$ 35.988.570', 'variation': '10,79 %'}
# ---------------
# {'index': '55', 'name': 'Huobi Token', 'marketvalue': 'R$ 622.406.744', 'pricers': 'R$ 12,45', 'pricebtc': 'BTC 0.00037327', 'total': 'R$ 593.557.325', 'variation': '-2,55 %'}
# ---------------
# {'index': '56', 'name': 'IOST', 'marketvalue': 'R$ 609.003.183', 'pricers': 'R$ 0,05', 'pricebtc': 'BTC 0.00000152', 'total': 'R$ 128.558.855', 'variation': '-1,59 %'}
# ---------------
# {'index': '69', 'name': 'ERC20', 'marketvalue': 'R$ 600.544.378', 'pricers': 'R$ 0,38', 'pricebtc': 'BTC 0.00001574', 'total': 'R$ 2.368', 'variation': '2.221,52 %'}
# ---------------
# {'index': '77', 'name': 'SmartMesh', 'marketvalue': 'R$ 600.240.619', 'pricers': 'R$ 0,42', 'pricebtc': 'BTC 0.00001534', 'total': 'R$ 5.751.042', 'variation': '317,07 %'}
# ---------------
# {'index': '99', 'name': 'DATA', 'marketvalue': 'R$ 599.336.786', 'pricers': 'R$ 0,13', 'pricebtc': 'BTC 0.00000468', 'total': 'R$ 20.873.767', 'variation': '787,97 %'}
# ---------------
# {'index': '79', 'name': 'MediShares', 'marketvalue': 'R$ 597.289.533', 'pricers': 'R$ 0,58', 'pricebtc': 'BTC 0.00002092', 'total': 'R$ 8.882.535', 'variation': '393,13 %'}
# ---------------
# {'index': '100', 'name': 'Delphy', 'marketvalue': 'R$ 596.917.115', 'pricers': 'R$ 13,59', 'pricebtc': 'BTC 0.00049122', 'total': 'R$ 19.059.095', 'variation': '808,90 %'}
# ---------------
# {'index': '100', 'name': 'Matrix AI Network', 'marketvalue': 'R$ 595.651.964', 'pricers': 'R$ 3,97', 'pricebtc': 'BTC 0.00012774', 'total': 'R$ 30.777.383', 'variation': '-4,22 %'}
# ---------------
# {'index': '83', 'name': 'Tokenomy', 'marketvalue': 'R$ 584.018.317', 'pricers': 'R$ 4,00', 'pricebtc': 'BTC 0.00014451', 'total': 'R$ 9.951.646', 'variation': '426,75 %'}
# ---------------
# {'index': '57', 'name': 'Siacoin', 'marketvalue': 'R$ 574.677.430', 'pricers': 'R$ 0,01', 'pricebtc': 'BTC 0.00000042', 'total': 'R$ 21.789.359', 'variation': '4,42 %'}
# ---------------
# {'index': '58', 'name': 'Aeternity', 'marketvalue': 'R$ 571.942.375', 'pricers': 'R$ 2,14', 'pricebtc': 'BTC 0.00006415', 'total': 'R$ 157.792.044', 'variation': '-0,53 %'}
# ---------------
# {'index': '100', 'name': 'TokenPay', 'marketvalue': 'R$ 567.697.812', 'pricers': 'R$ 37,11', 'pricebtc': 'BTC 0.00121885', 'total': 'R$ 8.116.163', 'variation': '22,54 %'}
# ---------------
# {'index': '97', 'name': 'MyBit Token', 'marketvalue': 'R$ 566.547.859', 'pricers': 'R$ 10,98', 'pricebtc': 'BTC 0.00037796', 'total': 'R$ 1.990.228', 'variation': '-2,35 %'}
# ---------------
# {'index': '50', 'name': 'Stealth', 'marketvalue': 'R$ 562.063.425', 'pricers': 'R$ 17,72', 'pricebtc': 'BTC 0.00086032', 'total': 'R$ 7.720', 'variation': '3.901,05 %'}
# ---------------
# {'index': '99', 'name': 'NavCoin', 'marketvalue': 'R$ 561.058.964', 'pricers': 'R$ 8,94', 'pricebtc': 'BTC 0.00031080', 'total': 'R$ 8.392.600', 'variation': '101,85 %'}
# ---------------
# {'index': '84', 'name': 'Ruff', 'marketvalue': 'R$ 552.791.599', 'pricers': 'R$ 0,60', 'pricebtc': 'BTC 0.00002162', 'total': 'R$ 31.536.256', 'variation': '356,20 %'}
# ---------------
# {'index': '59', 'name': 'Qubitica', 'marketvalue': 'R$ 525.338.179', 'pricers': 'R$ 187,04', 'pricebtc': 'BTC 0.00560747', 'total': 'R$ 380.523', 'variation': '0,99 %'}
# ---------------
# {'index': '60', 'name': 'ABBC Coin', 'marketvalue': 'R$ 524.173.386', 'pricers': 'R$ 1,04', 'pricebtc': 'BTC 0.00003111', 'total': 'R$ 207.649.044', 'variation': '-2,58 %'}
# ---------------
# {'index': '100', 'name': 'Storiqa', 'marketvalue': 'R$ 519.472.363', 'pricers': 'R$ 0,07', 'pricebtc': 'BTC 0.00000238', 'total': 'R$ 305.319.501', 'variation': '121,54 %'}
# ---------------
# {'index': '89', 'name': 'Cube', 'marketvalue': 'R$ 519.234.382', 'pricers': 'R$ 0,08', 'pricebtc': 'BTC 0.00000277', 'total': 'R$ 3.600.899', 'variation': '238,72 %'}
# ---------------
# {'index': '84', 'name': 'Litecoin Cash', 'marketvalue': 'R$ 519.148.400', 'pricers': 'R$ 0,91', 'pricebtc': 'BTC 0.00003596', 'total': 'R$ 843.307', 'variation': '269,92 %'}
# ---------------
# {'index': '90', 'name': 'Scry.info', 'marketvalue': 'R$ 517.336.997', 'pricers': 'R$ 1,18', 'pricebtc': 'BTC 0.00004247', 'total': 'R$ 2.545.768', 'variation': '144,19 %'}
# ---------------
# {'index': '69', 'name': 'CyberVein', 'marketvalue': 'R$ 514.780.528', 'pricers': 'R$ 0,49', 'pricebtc': 'BTC 0.00001773', 'total': 'R$ 3.271.771', 'variation': '151,34 %'}
# ---------------
# {'index': '61', 'name': 'Bytom', 'marketvalue': 'R$ 514.692.120', 'pricers': 'R$ 0,51', 'pricebtc': 'BTC 0.00001540', 'total': 'R$ 82.094.849', 'variation': '1,89 %'}
# ---------------
# {'index': '62', 'name': 'Dent', 'marketvalue': 'R$ 502.518.769', 'pricers': 'R$ 0,01', 'pricebtc': 'BTC 0.00000021', 'total': 'R$ 25.667.862', 'variation': '4,32 %'}
# ---------------
# {'index': '99', 'name': 'The ChampCoin', 'marketvalue': 'R$ 497.955.788', 'pricers': 'R$ 3,02', 'pricebtc': 'BTC 0.00011300', 'total': 'R$ 22.551', 'variation': '1.520,22 %'}
# ---------------
# {'index': '63', 'name': 'Steem', 'marketvalue': 'R$ 493.636.181', 'pricers': 'R$ 1,56', 'pricebtc': 'BTC 0.00004674', 'total': 'R$ 6.719.008', 'variation': '0,38 %'}
# ---------------
# {'index': '64', 'name': 'Enjin Coin', 'marketvalue': 'R$ 460.732.148', 'pricers': 'R$ 0,60', 'pricebtc': 'BTC 0.00001791', 'total': 'R$ 53.343.600', 'variation': '-1,39 %'}
# ---------------
# {'index': '65', 'name': 'THETA', 'marketvalue': 'R$ 450.490.154', 'pricers': 'R$ 0,52', 'pricebtc': 'BTC 0.00001552', 'total': 'R$ 29.118.209', 'variation': '-1,94 %'}
# ---------------
# {'index': '44', 'name': 'Nasdacoin', 'marketvalue': 'R$ 439.480.975', 'pricers': 'R$ 23,10', 'pricebtc': 'BTC 0.00151945', 'total': 'R$ 1.266.559', 'variation': '813,05 %'}
# ---------------
# {'index': '44', 'name': 'ETERNAL TOKEN', 'marketvalue': 'R$ 433.342.730', 'pricers': 'R$ 6,38', 'pricebtc': 'BTC 0.00041855', 'total': 'R$ 1.634.866', 'variation': '148,15 %'}
# ---------------
# {'index': '66', 'name': 'ThoreCoin', 'marketvalue': 'R$ 433.335.022', 'pricers': 'R$ 4.998,90', 'pricebtc': 'BTC 0.14986503', 'total': 'R$ 436.615', 'variation': '0,77 %'}
# ---------------
# {'index': '71', 'name': 'Vulcano', 'marketvalue': 'R$ 416.142.118', 'pricers': 'R$ 0,05', 'pricebtc': 'BTC 0.00000180', 'total': 'R$ 13.115', 'variation': '472,60 %'}
# ---------------
# {'index': '64', 'name': 'FLO', 'marketvalue': 'R$ 415.776.541', 'pricers': 'R$ 2,75', 'pricebtc': 'BTC 0.00008431', 'total': 'R$ 818.665', 'variation': '567,98 %'}
# ---------------
# {'index': '67', 'name': 'Mixin', 'marketvalue': 'R$ 407.838.760', 'pricers': 'R$ 914,21', 'pricebtc': 'BTC 0.02741350', 'total': 'R$ 1.641.019', 'variation': '0,96 %'}
# ---------------
# {'index': '68', 'name': 'Crypto.com', 'marketvalue': 'R$ 402.013.097', 'pricers': 'R$ 25,45', 'pricebtc': 'BTC 0.00076326', 'total': 'R$ 46.627.025', 'variation': '-2,23 %'}
# ---------------
# {'index': '69', 'name': 'KuCoin Shares', 'marketvalue': 'R$ 399.239.287', 'pricers': 'R$ 4,45', 'pricebtc': 'BTC 0.00013352', 'total': 'R$ 82.288.695', 'variation': '-3,48 %'}
# ---------------
# {'index': '70', 'name': 'MaidSafeCoin', 'marketvalue': 'R$ 397.948.817', 'pricers': 'R$ 0,88', 'pricebtc': 'BTC 0.00002637', 'total': 'R$ 1.181.557', 'variation': '0,74 %'}
# ---------------
# {'index': '64', 'name': 'Hshare', 'marketvalue': 'R$ 397.068.914', 'pricers': 'R$ 9,12', 'pricebtc': 'BTC 0.00034814', 'total': 'R$ 29.167.170', 'variation': '-30,01 %'}
# ---------------
# {'index': '72', 'name': 'AurumCoin', 'marketvalue': 'R$ 391.965.402', 'pricers': 'R$ 1.315,33', 'pricebtc': 'BTC 0.04589363', 'total': 'R$ 94.062', 'variation': '743,32 %'}
# ---------------
# {'index': '71', 'name': 'Stratis', 'marketvalue': 'R$ 383.966.285', 'pricers': 'R$ 3,86', 'pricebtc': 'BTC 0.00011589', 'total': 'R$ 5.936.792', 'variation': '0,11 %'}
# ---------------
# {'index': '72', 'name': 'Status', 'marketvalue': 'R$ 383.854.472', 'pricers': 'R$ 0,11', 'pricebtc': 'BTC 0.00000332', 'total': 'R$ 78.713.770', 'variation': '0,43 %'}
# ---------------
# {'index': '100', 'name': 'All Sports', 'marketvalue': 'R$ 369.194.021', 'pricers': 'R$ 0,45', 'pricebtc': 'BTC 0.00001850', 'total': 'R$ 62.966.983', 'variation': '-2,92 %'}
# ---------------
# {'index': '73', 'name': 'Waltonchain', 'marketvalue': 'R$ 369.056.515', 'pricers': 'R$ 8,85', 'pricebtc': 'BTC 0.00026550', 'total': 'R$ 29.443.983', 'variation': '-4,50 %'}
# ---------------
# {'index': '100', 'name': 'Skycoin', 'marketvalue': 'R$ 366.094.128', 'pricers': 'R$ 40,68', 'pricebtc': 'BTC 0.00166314', 'total': 'R$ 6.966.849', 'variation': '-3,50 %'}
# ---------------
# {'index': '100', 'name': 'Storm', 'marketvalue': 'R$ 366.024.850', 'pricers': 'R$ 0,08', 'pricebtc': 'BTC 0.00000318', 'total': 'R$ 89.266.938', 'variation': '7,22 %'}
# ---------------
# {'index': '97', 'name': 'Civic', 'marketvalue': 'R$ 362.131.654', 'pricers': 'R$ 1,06', 'pricebtc': 'BTC 0.00003806', 'total': 'R$ 77.890.996', 'variation': '37,74 %'}
# ---------------
# {'index': '63', 'name': 'Ripio Credit Network', 'marketvalue': 'R$ 358.685.284', 'pricers': 'R$ 0,72', 'pricebtc': 'BTC 0.00003377', 'total': 'R$ 4.907.158', 'variation': '534,24 %'}
# ---------------
# {'index': '74', 'name': 'Golem', 'marketvalue': 'R$ 357.807.202', 'pricers': 'R$ 0,37', 'pricebtc': 'BTC 0.00001113', 'total': 'R$ 8.493.302', 'variation': '-1,64 %'}
# ---------------
# {'index': '75', 'name': 'Maximine Coin', 'marketvalue': 'R$ 357.671.148', 'pricers': 'R$ 0,22', 'pricebtc': 'BTC 0.00000650', 'total': 'R$ 36.480.193', 'variation': '6,16 %'}
# ---------------
# {'index': '76', 'name': 'SOLVE', 'marketvalue': 'R$ 355.442.595', 'pricers': 'R$ 1,10', 'pricebtc': 'BTC 0.00003289', 'total': 'R$ 13.950.782', 'variation': '1,50 %'}
# ---------------
# {'index': '98', 'name': 'Ethos', 'marketvalue': 'R$ 353.022.699', 'pricers': 'R$ 4,56', 'pricebtc': 'BTC 0.00015591', 'total': 'R$ 7.143.600', 'variation': '-3,18 %'}
# ---------------
# {'index': '73', 'name': 'Stakenet', 'marketvalue': 'R$ 351.926.406', 'pricers': 'R$ 4,97', 'pricebtc': 'BTC 0.00018340', 'total': 'R$ 482.916', 'variation': '376,11 %'}
# ---------------
# {'index': '77', 'name': 'Cryptonex', 'marketvalue': 'R$ 349.062.781', 'pricers': 'R$ 6,27', 'pricebtc': 'BTC 0.00018796', 'total': 'R$ 17.460.519', 'variation': '-0,05 %'}
# ---------------
# {'index': '70', 'name': 'NAGA', 'marketvalue': 'R$ 347.127.441', 'pricers': 'R$ 5,90', 'pricebtc': 'BTC 0.00023272', 'total': 'R$ 209.360', 'variation': '425,76 %'}
# ---------------
# {'index': '78', 'name': 'Insight Chain', 'marketvalue': 'R$ 346.441.860', 'pricers': 'R$ 0,99', 'pricebtc': 'BTC 0.00002968', 'total': 'R$ 14.170.518', 'variation': '1,50 %'}
# ---------------
# {'index': '79', 'name': 'TrueChain', 'marketvalue': 'R$ 342.937.882', 'pricers': 'R$ 4,31', 'pricebtc': 'BTC 0.00012923', 'total': 'R$ 244.991.040', 'variation': '-0,67 %'}
# ---------------
# {'index': '100', 'name': 'Gifto', 'marketvalue': 'R$ 338.354.843', 'pricers': 'R$ 0,63', 'pricebtc': 'BTC 0.00002264', 'total': 'R$ 213.417.447', 'variation': '-0,96 %'}
# ---------------
# {'index': '64', 'name': 'Namecoin', 'marketvalue': 'R$ 337.732.870', 'pricers': 'R$ 22,92', 'pricebtc': 'BTC 0.00143749', 'total': 'R$ 63.602', 'variation': '720,58 %'}
# ---------------
# {'index': '80', 'name': 'Envion', 'marketvalue': 'R$ 337.163.475', 'pricers': 'R$ 3,03', 'pricebtc': 'BTC 0.00010982', 'total': 'R$ 7.515', 'variation': '1.089,98 %'}
# ---------------
# {'index': '100', 'name': 'Fusion', 'marketvalue': 'R$ 335.480.992', 'pricers': 'R$ 11,30', 'pricebtc': 'BTC 0.00045752', 'total': 'R$ 16.815.276', 'variation': '-8,58 %'}
# ---------------
# {'index': '80', 'name': 'Ardor', 'marketvalue': 'R$ 331.428.956', 'pricers': 'R$ 0,33', 'pricebtc': 'BTC 0.00000995', 'total': 'R$ 4.845.603', 'variation': '0,81 %'}
# ---------------
# {'index': '70', 'name': 'Ternio', 'marketvalue': 'R$ 331.350.928', 'pricers': 'R$ 0,99', 'pricebtc': 'BTC 0.00003411', 'total': 'R$ 7.903', 'variation': '1.014,30 %'}
# ---------------
# {'index': '98', 'name': 'Jiyo', 'marketvalue': 'R$ 330.860.213', 'pricers': 'R$ 8,05', 'pricebtc': 'BTC 0.00033500', 'total': 'R$ 275.192', 'variation': '5.128,52 %'}
# ---------------
# {'index': '81', 'name': 'VestChain', 'marketvalue': 'R$ 330.510.817', 'pricers': 'R$ 0,05', 'pricebtc': 'BTC 0.00000140', 'total': 'R$ 1.888.829', 'variation': '1,54 %'}
# ---------------
# {'index': '82', 'name': 'Dai', 'marketvalue': 'R$ 320.267.021', 'pricers': 'R$ 3,92', 'pricebtc': 'BTC 0.00011741', 'total': 'R$ 250.635.531', 'variation': '-0,49 %'}
# ---------------
# {'index': '83', 'name': 'Metaverse ETP', 'marketvalue': 'R$ 317.712.561', 'pricers': 'R$ 4,45', 'pricebtc': 'BTC 0.00013332', 'total': 'R$ 91.860.956', 'variation': '-3,59 %'}
# ---------------
# {'index': '84', 'name': 'aelf', 'marketvalue': 'R$ 317.325.328', 'pricers': 'R$ 0,84', 'pricebtc': 'BTC 0.00002528', 'total': 'R$ 76.788.484', 'variation': '-3,44 %'}
# ---------------
# {'index': '100', 'name': 'KickCoin', 'marketvalue': 'R$ 307.436.018', 'pricers': 'R$ 0,59', 'pricebtc': 'BTC 0.00002076', 'total': 'R$ 41.110.759', 'variation': '5,73 %'}
# ---------------
# {'index': '85', 'name': 'Factom', 'marketvalue': 'R$ 302.515.439', 'pricers': 'R$ 31,90', 'pricebtc': 'BTC 0.00095664', 'total': 'R$ 999.891', 'variation': '-0,79 %'}
# ---------------
# {'index': '100', 'name': 'Docademic', 'marketvalue': 'R$ 301.813.857', 'pricers': 'R$ 1,04', 'pricebtc': 'BTC 0.00004441', 'total': 'R$ 2.015.411', 'variation': '-0,65 %'}
# ---------------
# {'index': '75', 'name': 'Dragonchain', 'marketvalue': 'R$ 299.970.987', 'pricers': 'R$ 1,26', 'pricebtc': 'BTC 0.00005395', 'total': 'R$ 4.187.486', 'variation': '60,49 %'}
# ---------------
# {'index': '86', 'name': 'Project Pai', 'marketvalue': 'R$ 299.184.001', 'pricers': 'R$ 0,21', 'pricebtc': 'BTC 0.00000618', 'total': 'R$ 16.341.034', 'variation': '-0,69 %'}
# ---------------
# {'index': '87', 'name': 'HyperCash', 'marketvalue': 'R$ 294.241.689', 'pricers': 'R$ 6,76', 'pricebtc': 'BTC 0.00020269', 'total': 'R$ 51.911.120', 'variation': '-2,38 %'}
# ---------------
# {'index': '85', 'name': 'LINA', 'marketvalue': 'R$ 293.701.203', 'pricers': 'R$ 1,25', 'pricebtc': 'BTC 0.00003572', 'total': 'R$ 5.193.295', 'variation': '357,44 %'}
# ---------------
# {'index': '84', 'name': 'Clams', 'marketvalue': 'R$ 290.518.046', 'pricers': 'R$ 80,52', 'pricebtc': 'BTC 0.00232257', 'total': 'R$ 726.933', 'variation': '7,63 %'}
# ---------------
# {'index': '88', 'name': 'WAX', 'marketvalue': 'R$ 288.101.553', 'pricers': 'R$ 0,31', 'pricebtc': 'BTC 0.00000916', 'total': 'R$ 1.780.937', 'variation': '1,56 %'}
# ---------------
# {'index': '89', 'name': 'Horizen', 'marketvalue': 'R$ 287.816.574', 'pricers': 'R$ 43,77', 'pricebtc': 'BTC 0.00131243', 'total': 'R$ 22.195.523', 'variation': '5,22 %'}
# ---------------
# {'index': '100', 'name': 'Blocknet', 'marketvalue': 'R$ 280.087.869', 'pricers': 'R$ 53,83', 'pricebtc': 'BTC 0.00241893', 'total': 'R$ 213.056', 'variation': '-5,84 %'}
# ---------------
# {'index': '81', 'name': 'PumaPay', 'marketvalue': 'R$ 279.956.131', 'pricers': 'R$ 0,02', 'pricebtc': 'BTC 0.00000067', 'total': 'R$ 31.723', 'variation': '297,96 %'}
# ---------------
# {'index': '100', 'name': 'Byteball Bytes', 'marketvalue': 'R$ 279.524.972', 'pricers': 'R$ 421,73', 'pricebtc': 'BTC 0.01447949', 'total': 'R$ 582.861', 'variation': '8,34 %'}
# ---------------
# {'index': '90', 'name': 'DigixDAO', 'marketvalue': 'R$ 279.465.975', 'pricers': 'R$ 139,73', 'pricebtc': 'BTC 0.00419004', 'total': 'R$ 10.796.102', 'variation': '-2,28 %'}
# ---------------
# {'index': '91', 'name': 'Aion', 'marketvalue': 'R$ 278.728.571', 'pricers': 'R$ 0,88', 'pricebtc': 'BTC 0.00002625', 'total': 'R$ 35.275.752', 'variation': '2,12 %'}
# ---------------
# {'index': '99', 'name': 'Substratum', 'marketvalue': 'R$ 278.613.575', 'pricers': 'R$ 0,73', 'pricebtc': 'BTC 0.00002517', 'total': 'R$ 8.537.692', 'variation': '4,35 %'}
# ---------------
# {'index': '92', 'name': 'GXChain', 'marketvalue': 'R$ 271.311.389', 'pricers': 'R$ 4,52', 'pricebtc': 'BTC 0.00013559', 'total': 'R$ 32.147.186', 'variation': '-0,06 %'}
# ---------------
# {'index': '93', 'name': 'Ark', 'marketvalue': 'R$ 261.809.809', 'pricers': 'R$ 2,33', 'pricebtc': 'BTC 0.00006973', 'total': 'R$ 3.940.610', 'variation': '-3,53 %'}
# ---------------
# {'index': '94', 'name': 'Nash Exchange', 'marketvalue': 'R$ 261.546.452', 'pricers': 'R$ 7,23', 'pricebtc': 'BTC 0.00021662', 'total': 'R$ 6.068.751', 'variation': '4,59 %'}
# ---------------
# {'index': '98', 'name': 'TaTaTu', 'marketvalue': 'R$ 254.063.536', 'pricers': 'R$ 2,63', 'pricebtc': 'BTC 0.00009173', 'total': 'R$ 2.241.991', 'variation': '8,89 %'}
# ---------------
# {'index': '88', 'name': 'Paypex', 'marketvalue': 'R$ 251.727.066', 'pricers': 'R$ 3,68', 'pricebtc': 'BTC 0.00014574', 'total': 'R$ 162.282', 'variation': '154,83 %'}
# ---------------
# {'index': '95', 'name': 'Loopring', 'marketvalue': 'R$ 251.167.806', 'pricers': 'R$ 0,27', 'pricebtc': 'BTC 0.00000799', 'total': 'R$ 167.716.726', 'variation': '-1,26 %'}
# ---------------
# {'index': '98', 'name': 'Rivetz', 'marketvalue': 'R$ 248.437.048', 'pricers': 'R$ 9,47', 'pricebtc': 'BTC 0.00036047', 'total': 'R$ 3.140', 'variation': '1.826,42 %'}
# ---------------
# {'index': '100', 'name': 'iExec RLC', 'marketvalue': 'R$ 245.495.326', 'pricers': 'R$ 3,07', 'pricebtc': 'BTC 0.00009256', 'total': 'R$ 30.381.714', 'variation': '7,65 %'}
# ---------------
# {'index': '97', 'name': 'Emercoin', 'marketvalue': 'R$ 245.484.289', 'pricers': 'R$ 5,83', 'pricebtc': 'BTC 0.00024831', 'total': 'R$ 1.181.589', 'variation': '48,92 %'}
# ---------------
# {'index': '96', 'name': 'Revain', 'marketvalue': 'R$ 244.707.343', 'pricers': 'R$ 0,51', 'pricebtc': 'BTC 0.00001515', 'total': 'R$ 6.476.053', 'variation': '2,13 %'}
# ---------------
# {'index': '97', 'name': 'Decentraland', 'marketvalue': 'R$ 242.231.055', 'pricers': 'R$ 0,23', 'pricebtc': 'BTC 0.00000692', 'total': 'R$ 86.828.516', 'variation': '0,18 %'}
# ---------------
# {'index': '94', 'name': 'Content Neutrality Network', 'marketvalue': 'R$ 240.995.982', 'pricers': 'R$ 0,01', 'pricebtc': 'BTC 0.00000032', 'total': 'R$ 5.269.646', 'variation': '651,62 %'}
# ---------------
# {'index': '88', 'name': 'OVCODE', 'marketvalue': 'R$ 240.647.499', 'pricers': 'R$ 5,47', 'pricebtc': 'BTC 0.00024814', 'total': 'R$ 1.162.974', 'variation': '294,31 %'}
# ---------------
# {'index': '98', 'name': 'LATOKEN', 'marketvalue': 'R$ 239.445.058', 'pricers': 'R$ 0,63', 'pricebtc': 'BTC 0.00001889', 'total': 'R$ 39.855.406', 'variation': '2,99 %'}
# ---------------
# {'index': '99', 'name': 'Loom Network', 'marketvalue': 'R$ 239.354.232', 'pricers': 'R$ 0,30', 'pricebtc': 'BTC 0.00000904', 'total': 'R$ 9.588.964', 'variation': '-0,19 %'}
# ---------------
# {'index': '88', 'name': 'Everus', 'marketvalue': 'R$ 238.606.303', 'pricers': 'R$ 0,52', 'pricebtc': 'BTC 0.00001784', 'total': 'R$ 61.283', 'variation': '431,03 %'}
# ---------------
# {'index': '100', 'name': 'Genesis Vision', 'marketvalue': 'R$ 238.005.189', 'pricers': 'R$ 53,88', 'pricebtc': 'BTC 0.00224604', 'total': 'R$ 19.075.440', 'variation': '-7,94 %'}
# ---------------
# {'index': '100', 'name': 'Elastos', 'marketvalue': 'R$ 237.497.755', 'pricers': 'R$ 15,47', 'pricebtc': 'BTC 0.00046205', 'total': 'R$ 20.223.178', 'variation': '9,59 %'}
# ---------------
# {'index': '97', 'name': 'Spectre.ai Dividend Token', 'marketvalue': 'R$ 236.562.360', 'pricers': 'R$ 2,88', 'pricebtc': 'BTC 0.00012296', 'total': 'R$ 133.610', 'variation': '129,75 %'}
# ---------------
# {'index': '100', 'name': 'SALT', 'marketvalue': 'R$ 234.167.525', 'pricers': 'R$ 2,84', 'pricebtc': 'BTC 0.00012056', 'total': 'R$ 10.855.332', 'variation': '12,85 %'}
# ---------------
# {'index': '97', 'name': 'Gold Bits Coin', 'marketvalue': 'R$ 232.701.486', 'pricers': 'R$ 2,20', 'pricebtc': 'BTC 0.00006798', 'total': 'R$ 162.042', 'variation': '174,08 %'}
# ---------------
# {'index': '100', 'name': 'NULS', 'marketvalue': 'R$ 231.830.609', 'pricers': 'R$ 3,23', 'pricebtc': 'BTC 0.00009168', 'total': 'R$ 30.432.423', 'variation': '3,83 %'}
# ---------------
# {'index': '100', 'name': 'Santiment Network Token', 'marketvalue': 'R$ 231.660.821', 'pricers': 'R$ 3,70', 'pricebtc': 'BTC 0.00011087', 'total': 'R$ 564.547', 'variation': '-3,55 %'}
# ---------------
# {'index': '95', 'name': 'BitcoinDark', 'marketvalue': 'R$ 230.974.331', 'pricers': 'R$ 179,21', 'pricebtc': 'BTC 0.00679895', 'total': 'R$ 1.453.208', 'variation': '17,63 %'}
# ---------------
# {'index': '100', 'name': 'Populous', 'marketvalue': 'R$ 230.845.275', 'pricers': 'R$ 4,33', 'pricebtc': 'BTC 0.00012315', 'total': 'R$ 12.490.910', 'variation': '2,40 %'}
# ---------------
# {'index': '100', 'name': 'HedgeTrade', 'marketvalue': 'R$ 230.797.825', 'pricers': 'R$ 0,80', 'pricebtc': 'BTC 0.00002402', 'total': 'R$ 1.173.927', 'variation': '-0,16 %'}
# ---------------
# {'index': '100', 'name': 'ZClassic', 'marketvalue': 'R$ 230.225.347', 'pricers': 'R$ 50,08', 'pricebtc': 'BTC 0.00202587', 'total': 'R$ 5.642.682', 'variation': '-2,01 %'}
# ---------------
# {'index': '98', 'name': 'Japan Content Token', 'marketvalue': 'R$ 229.868.491', 'pricers': 'R$ 0,78', 'pricebtc': 'BTC 0.00002423', 'total': 'R$ 2.203.230', 'variation': '82,40 %'}
# ---------------
# {'index': '100', 'name': 'Clipper Coin', 'marketvalue': 'R$ 229.741.092', 'pricers': 'R$ 0,06', 'pricebtc': 'BTC 0.00000188', 'total': 'R$ 281.736', 'variation': '37,45 %'}
# ---------------
# {'index': '100', 'name': 'Nebulas', 'marketvalue': 'R$ 229.613.100', 'pricers': 'R$ 5,05', 'pricebtc': 'BTC 0.00015824', 'total': 'R$ 46.221.024', 'variation': '3,26 %'}
# ---------------
# {'index': '100', 'name': 'Zcoin', 'marketvalue': 'R$ 228.547.167', 'pricers': 'R$ 30,02', 'pricebtc': 'BTC 0.00089781', 'total': 'R$ 14.063.255', 'variation': '6,42 %'}
# ---------------
# {'index': '100', 'name': 'Arcblock', 'marketvalue': 'R$ 227.280.232', 'pricers': 'R$ 2,31', 'pricebtc': 'BTC 0.00007169', 'total': 'R$ 48.846.230', 'variation': '14,45 %'}
# ---------------
# {'index': '99', 'name': 'Veritaseum', 'marketvalue': 'R$ 226.787.586', 'pricers': 'R$ 105,50', 'pricebtc': 'BTC 0.00325938', 'total': 'R$ 23.024.037', 'variation': '40,81 %'}
# ---------------
# {'index': '92', 'name': 'APIS', 'marketvalue': 'R$ 226.581.589', 'pricers': 'R$ 0,05', 'pricebtc': 'BTC 0.00000174', 'total': 'R$ 31.761.657', 'variation': '101,81 %'}
# ---------------
# {'index': '100', 'name': 'Orbs', 'marketvalue': 'R$ 226.547.119', 'pricers': 'R$ 0,14', 'pricebtc': 'BTC 0.00000414', 'total': 'R$ 9.043.270', 'variation': '-0,76 %'}
# ---------------
# {'index': '100', 'name': 'Theta Fuel', 'marketvalue': 'R$ 226.513.049', 'pricers': 'R$ 0,06', 'pricebtc': 'BTC 0.00000178', 'total': 'R$ 141.225.221', 'variation': '-16,74 %'}
# ---------------
# {'index': '99', 'name': 'Celer Network', 'marketvalue': 'R$ 226.424.305', 'pricers': 'R$ 0,10', 'pricebtc': 'BTC 0.00000297', 'total': 'R$ 730.564.775', 'variation': '21,78 %'}
# ---------------
# {'index': '100', 'name': 'Matic Network', 'marketvalue': 'R$ 225.481.455', 'pricers': 'R$ 0,10', 'pricebtc': 'BTC 0.00000324', 'total': 'R$ 439.238.907', 'variation': '-5,33 %'}
# ---------------
# {'index': '100', 'name': 'Nexo', 'marketvalue': 'R$ 225.301.691', 'pricers': 'R$ 0,40', 'pricebtc': 'BTC 0.00001206', 'total': 'R$ 27.060.149', 'variation': '2,76 %'}
# ---------------
# {'index': '100', 'name': 'Electroneum', 'marketvalue': 'R$ 225.015.052', 'pricers': 'R$ 0,02', 'pricebtc': 'BTC 0.00000075', 'total': 'R$ 5.086.215', 'variation': '22,03 %'}
# ---------------
# {'index': '100', 'name': 'NEXT', 'marketvalue': 'R$ 224.485.327', 'pricers': 'R$ 4,47', 'pricebtc': 'BTC 0.00013387', 'total': 'R$ 28.576.891', 'variation': '-0,82 %'}
# ---------------
# {'index': '100', 'name': 'Everipedia', 'marketvalue': 'R$ 223.893.659', 'pricers': 'R$ 0,05', 'pricebtc': 'BTC 0.00000184', 'total': 'R$ 10.493.232', 'variation': '23,85 %'}
# ---------------
# {'index': '99', 'name': 'Buggyra Coin Zero', 'marketvalue': 'R$ 222.298.981', 'pricers': 'R$ 0,11', 'pricebtc': 'BTC 0.00000557', 'total': 'R$ 34.655', 'variation': '10,23 %'}
# ---------------
# {'index': '99', 'name': 'Newton', 'marketvalue': 'R$ 222.100.396', 'pricers': 'R$ 0,02', 'pricebtc': 'BTC 0.00000059', 'total': 'R$ 60.350.388', 'variation': '6,63 %'}
# ---------------
# {'index': '60', 'name': 'PayPie', 'marketvalue': 'R$ 220.256.315', 'pricers': 'R$ 2,67', 'pricebtc': 'BTC 0.00019487', 'total': 'R$ 2.444', 'variation': '0,00 %'}
# ---------------
# {'index': '100', 'name': 'Cortex', 'marketvalue': 'R$ 220.039.271', 'pricers': 'R$ 1,47', 'pricebtc': 'BTC 0.00005844', 'total': 'R$ 66.505.862', 'variation': '-5,17 %'}
# ---------------
# {'index': '90', 'name': 'Syscoin', 'marketvalue': 'R$ 217.811.621', 'pricers': 'R$ 0,39', 'pricebtc': 'BTC 0.00001698', 'total': 'R$ 2.254.111', 'variation': '58,05 %'}
# ---------------
# {'index': '100', 'name': 'MOAC', 'marketvalue': 'R$ 217.176.754', 'pricers': 'R$ 3,48', 'pricebtc': 'BTC 0.00011004', 'total': 'R$ 355.264', 'variation': '3,87 %'}
# ---------------
# {'index': '100', 'name': 'BridgeCoin', 'marketvalue': 'R$ 216.704.392', 'pricers': 'R$ 8,03', 'pricebtc': 'BTC 0.00029791', 'total': 'R$ 102.989', 'variation': '23,91 %'}
# ---------------
# {'index': '100', 'name': 'RChain', 'marketvalue': 'R$ 216.364.390', 'pricers': 'R$ 0,56', 'pricebtc': 'BTC 0.00002340', 'total': 'R$ 1.995.671', 'variation': '-0,97 %'}
# ---------------
# {'index': '100', 'name': 'Noah Coin', 'marketvalue': 'R$ 214.551.908', 'pricers': 'R$ 0,01', 'pricebtc': 'BTC 0.00000027', 'total': 'R$ 6.114.301', 'variation': '19,29 %'}
# ---------------
# {'index': '100', 'name': 'Odyssey', 'marketvalue': 'R$ 213.822.437', 'pricers': 'R$ 0,05', 'pricebtc': 'BTC 0.00000188', 'total': 'R$ 24.502.705', 'variation': '-3,15 %'}
# ---------------
# {'index': '100', 'name': 'ReddCoin', 'marketvalue': 'R$ 211.993.424', 'pricers': 'R$ 0,01', 'pricebtc': 'BTC 0.00000024', 'total': 'R$ 3.499.635', 'variation': '-4,75 %'}
# ---------------
# {'index': '98', 'name': 'UNIVERSAL CASH', 'marketvalue': 'R$ 211.508.977', 'pricers': 'R$ 0,03', 'pricebtc': 'BTC 0.00000098', 'total': 'R$ 264.259', 'variation': '397,07 %'}
# ---------------
# {'index': '100', 'name': 'Peercoin', 'marketvalue': 'R$ 210.564.887', 'pricers': 'R$ 8,45', 'pricebtc': 'BTC 0.00034660', 'total': 'R$ 3.665.023', 'variation': '-1,78 %'}
# ---------------
# {'index': '99', 'name': 'TTC Protocol', 'marketvalue': 'R$ 207.442.775', 'pricers': 'R$ 0,72', 'pricebtc': 'BTC 0.00003632', 'total': 'R$ 78.248.782', 'variation': '26,22 %'}
# ---------------
# {'index': '100', 'name': 'S4FE', 'marketvalue': 'R$ 207.269.516', 'pricers': 'R$ 1,77', 'pricebtc': 'BTC 0.00008030', 'total': 'R$ 1.057.543', 'variation': '79,00 %'}
# ---------------
# {'index': '61', 'name': 'FREE Coin', 'marketvalue': 'R$ 207.021.631', 'pricers': 'R$ 0,00', 'pricebtc': 'BTC 0.00000000', 'total': 'R$ 19.634', 'variation': '2.095,43 %'}
# ---------------
# {'index': '99', 'name': 'Bitcoin Interest', 'marketvalue': 'R$ 206.157.228', 'pricers': 'R$ 11,25', 'pricebtc': 'BTC 0.00043270', 'total': 'R$ 346.683', 'variation': '100,47 %'}
# ---------------
# {'index': '99', 'name': 'Bibox Token', 'marketvalue': 'R$ 204.905.699', 'pricers': 'R$ 1,85', 'pricebtc': 'BTC 0.00008907', 'total': 'R$ 72.435.537', 'variation': '7,24 %'}
# ---------------
# {'index': '99', 'name': 'SIX', 'marketvalue': 'R$ 204.538.988', 'pricers': 'R$ 0,75', 'pricebtc': 'BTC 0.00003751', 'total': 'R$ 26.957', 'variation': '935,82 %'}
# ---------------
# {'index': '100', 'name': 'PIVX', 'marketvalue': 'R$ 203.490.096', 'pricers': 'R$ 3,58', 'pricebtc': 'BTC 0.00016270', 'total': 'R$ 5.306.458', 'variation': '-0,58 %'}
# ---------------
# {'index': '100', 'name': 'Enigma', 'marketvalue': 'R$ 202.711.568', 'pricers': 'R$ 2,71', 'pricebtc': 'BTC 0.00014653', 'total': 'R$ 23.291.078', 'variation': '2,55 %'}
# ---------------
# {'index': '100', 'name': 'PRIZM', 'marketvalue': 'R$ 201.641.830', 'pricers': 'R$ 3,63', 'pricebtc': 'BTC 0.00014564', 'total': 'R$ 140.098', 'variation': '24,73 %'}
# ---------------
# {'index': '90', 'name': 'Cajutel', 'marketvalue': 'R$ 201.634.306', 'pricers': 'R$ 616,67', 'pricebtc': 'BTC 0.03925118', 'total': 'R$ 444.194', 'variation': '1.093,99 %'}
# ---------------
# {'index': '93', 'name': 'Metadium', 'marketvalue': 'R$ 200.820.133', 'pricers': 'R$ 0,16', 'pricebtc': 'BTC 0.00000789', 'total': 'R$ 7.718.596', 'variation': '73,32 %'}
# ---------------
# {'index': '83', 'name': 'SmartCash', 'marketvalue': 'R$ 199.263.919', 'pricers': 'R$ 0,19', 'pricebtc': 'BTC 0.00000960', 'total': 'R$ 2.433.285', 'variation': '163,99 %'}
# ---------------
# {'index': '100', 'name': 'Nexus', 'marketvalue': 'R$ 199.003.751', 'pricers': 'R$ 3,40', 'pricebtc': 'BTC 0.00013082', 'total': 'R$ 2.576.640', 'variation': '-3,34 %'}
# ---------------
# {'index': '98', 'name': 'RIF Token', 'marketvalue': 'R$ 198.618.750', 'pricers': 'R$ 0,50', 'pricebtc': 'BTC 0.00002546', 'total': 'R$ 1.186.059', 'variation': '37,01 %'}
# ---------------
# {'index': '100', 'name': 'WaykiChain', 'marketvalue': 'R$ 198.128.000', 'pricers': 'R$ 1,05', 'pricebtc': 'BTC 0.00005076', 'total': 'R$ 10.390.614', 'variation': '-3,11 %'}
# ---------------
# {'index': '100', 'name': 'Kyber Network', 'marketvalue': 'R$ 197.998.282', 'pricers': 'R$ 1,19', 'pricebtc': 'BTC 0.00005703', 'total': 'R$ 103.648.983', 'variation': '7,51 %'}
# ---------------
# {'index': '100', 'name': 'Lambda', 'marketvalue': 'R$ 197.268.833', 'pricers': 'R$ 0,39', 'pricebtc': 'BTC 0.00001940', 'total': 'R$ 36.020.716', 'variation': '0,07 %'}
# ---------------
# {'index': '97', 'name': 'Blue Whale Token', 'marketvalue': 'R$ 196.944.506', 'pricers': 'R$ 0,00', 'pricebtc': 'BTC 0.00000013', 'total': 'R$ 49.394', 'variation': '253,59 %'}
# ---------------
# {'index': '100', 'name': 'REPO', 'marketvalue': 'R$ 196.236.132', 'pricers': 'R$ 1,78', 'pricebtc': 'BTC 0.00008188', 'total': 'R$ 371.108', 'variation': '-8,40 %'}
# ---------------
# {'index': '100', 'name': 'QASH', 'marketvalue': 'R$ 195.116.944', 'pricers': 'R$ 0,56', 'pricebtc': 'BTC 0.00002368', 'total': 'R$ 1.707.389', 'variation': '14,71 %'}
# ---------------
# {'index': '94', 'name': 'Digitex Futures', 'marketvalue': 'R$ 193.219.702', 'pricers': 'R$ 0,26', 'pricebtc': 'BTC 0.00001260', 'total': 'R$ 7.185.669', 'variation': '-27,09 %'}
# ---------------
# {'index': '82', 'name': 'STEM CELL COIN', 'marketvalue': 'R$ 192.949.761', 'pricers': 'R$ 0,60', 'pricebtc': 'BTC 0.00003962', 'total': 'R$ 389.818', 'variation': '162,14 %'}
# ---------------
# {'index': '96', 'name': 'Aurora DAO', 'marketvalue': 'R$ 188.963.810', 'pricers': 'R$ 1,02', 'pricebtc': 'BTC 0.00006404', 'total': 'R$ 132.532', 'variation': '874,62 %'}
# ---------------
# {'index': '100', 'name': 'Power Ledger', 'marketvalue': 'R$ 186.968.052', 'pricers': 'R$ 0,46', 'pricebtc': 'BTC 0.00002226', 'total': 'R$ 11.109.710', 'variation': '6,79 %'}
# ---------------
# {'index': '97', 'name': 'Edgeless', 'marketvalue': 'R$ 186.730.848', 'pricers': 'R$ 1,60', 'pricebtc': 'BTC 0.00007609', 'total': 'R$ 1.416.337', 'variation': '293,11 %'}
# ---------------
# {'index': '100', 'name': 'ODEM', 'marketvalue': 'R$ 186.622.252', 'pricers': 'R$ 0,81', 'pricebtc': 'BTC 0.00003579', 'total': 'R$ 5.382.293', 'variation': '-1,23 %'}
# ---------------
# {'index': '100', 'name': 'Storj', 'marketvalue': 'R$ 185.732.734', 'pricers': 'R$ 1,37', 'pricebtc': 'BTC 0.00008503', 'total': 'R$ 61.386.178', 'variation': '16,68 %'}
# ---------------
# {'index': '71', 'name': 'Safe Exchange Coin', 'marketvalue': 'R$ 185.426.104', 'pricers': 'R$ 0,12', 'pricebtc': 'BTC 0.00000885', 'total': 'R$ 45.288', 'variation': '536,27 %'}
# ---------------
# {'index': '100', 'name': 'Gemini Dollar', 'marketvalue': 'R$ 184.451.509', 'pricers': 'R$ 3,94', 'pricebtc': 'BTC 0.00017715', 'total': 'R$ 76.941.968', 'variation': '-0,24 %'}
# ---------------
# {'index': '95', 'name': 'BnkToTheFuture', 'marketvalue': 'R$ 179.667.245', 'pricers': 'R$ 0,29', 'pricebtc': 'BTC 0.00001852', 'total': 'R$ 572.297', 'variation': '199,37 %'}
# ---------------
# {'index': '81', 'name': 'Veros', 'marketvalue': 'R$ 177.441.261', 'pricers': 'R$ 3,33', 'pricebtc': 'BTC 0.00020403', 'total': 'R$ 10.557.122', 'variation': '34,04 %'}
# ---------------
# {'index': '98', 'name': 'CRYPTO20', 'marketvalue': 'R$ 175.865.499', 'pricers': 'R$ 4,36', 'pricebtc': 'BTC 0.00028457', 'total': 'R$ 1.664.944', 'variation': '184,60 %'}
# ---------------
# {'index': '76', 'name': 'SIRIN LABS Token', 'marketvalue': 'R$ 174.718.972', 'pricers': 'R$ 0,36', 'pricebtc': 'BTC 0.00002443', 'total': 'R$ 6.954.732', 'variation': '131,45 %'}
# ---------------
# {'index': '100', 'name': 'Wanchain', 'marketvalue': 'R$ 173.562.908', 'pricers': 'R$ 1,64', 'pricebtc': 'BTC 0.00010353', 'total': 'R$ 16.574.505', 'variation': '2,50 %'}
# ---------------
# {'index': '97', 'name': 'Ignis', 'marketvalue': 'R$ 171.662.765', 'pricers': 'R$ 0,23', 'pricebtc': 'BTC 0.00001441', 'total': 'R$ 9.187.480', 'variation': '205,16 %'}
# ---------------
# {'index': '99', 'name': 'Credo', 'marketvalue': 'R$ 170.463.795', 'pricers': 'R$ 0,31', 'pricebtc': 'BTC 0.00002024', 'total': 'R$ 815.689', 'variation': '143,03 %'}
# ---------------
# {'index': '97', 'name': 'Ormeus Coin', 'marketvalue': 'R$ 165.076.768', 'pricers': 'R$ 4,60', 'pricebtc': 'BTC 0.00029998', 'total': 'R$ 7.888.625', 'variation': '34,52 %'}
# ---------------
# {'index': '81', 'name': 'DEX', 'marketvalue': 'R$ 160.873.025', 'pricers': 'R$ 0,84', 'pricebtc': 'BTC 0.00006236', 'total': 'R$ 459.270', 'variation': '211,89 %'}
# ---------------
# {'index': '100', 'name': 'Kin', 'marketvalue': 'R$ 160.863.755', 'pricers': 'R$ 0,00', 'pricebtc': 'BTC 0.00000001', 'total': 'R$ 6.908.724', 'variation': '-4,33 %'}
# ---------------
# {'index': '100', 'name': 'Polymath', 'marketvalue': 'R$ 160.027.540', 'pricers': 'R$ 0,46', 'pricebtc': 'BTC 0.00003020', 'total': 'R$ 69.930.160', 'variation': '-6,48 %'}
# ---------------
# {'index': '99', 'name': 'Groestlcoin', 'marketvalue': 'R$ 159.936.375', 'pricers': 'R$ 2,22', 'pricebtc': 'BTC 0.00014823', 'total': 'R$ 1.777.107.978', 'variation': '43,85 %'}
# ---------------
# {'index': '78', 'name': 'ARBITRAGE', 'marketvalue': 'R$ 159.165.574', 'pricers': 'R$ 36,51', 'pricebtc': 'BTC 0.00263794', 'total': 'R$ 785.785', 'variation': '72,93 %'}
# ---------------
# {'index': '100', 'name': 'Linkey', 'marketvalue': 'R$ 158.520.339', 'pricers': 'R$ 3,17', 'pricebtc': 'BTC 0.00021187', 'total': 'R$ 1.681.993', 'variation': '1,55 %'}
# ---------------
# {'index': '100', 'name': 'TenX', 'marketvalue': 'R$ 158.150.012', 'pricers': 'R$ 1,38', 'pricebtc': 'BTC 0.00009059', 'total': 'R$ 23.056.456', 'variation': '34,05 %'}
# ---------------
# {'index': '99', 'name': 'Cosmo Coin', 'marketvalue': 'R$ 158.034.902', 'pricers': 'R$ 0,24', 'pricebtc': 'BTC 0.00001542', 'total': 'R$ 2.162.097.916', 'variation': '10,77 %'}
# ---------------
# {'index': '100', 'name': 'Bancor', 'marketvalue': 'R$ 157.347.630', 'pricers': 'R$ 2,50', 'pricebtc': 'BTC 0.00016385', 'total': 'R$ 32.529.346', 'variation': '-10,05 %'}
# ---------------
# {'index': '87', 'name': 'MassGrid', 'marketvalue': 'R$ 152.707.319', 'pricers': 'R$ 2,88', 'pricebtc': 'BTC 0.00018925', 'total': 'R$ 219.309', 'variation': '1.220,92 %'}
# ---------------
# {'index': '80', 'name': 'Restart Energy MWAT', 'marketvalue': 'R$ 150.949.303', 'pricers': 'R$ 0,33', 'pricebtc': 'BTC 0.00002462', 'total': 'R$ 191.222', 'variation': '455,72 %'}
# ---------------
# {'index': '100', 'name': 'CyberMiles', 'marketvalue': 'R$ 146.504.751', 'pricers': 'R$ 0,19', 'pricebtc': 'BTC 0.00001172', 'total': 'R$ 10.176.137', 'variation': '4,76 %'}
# ---------------
# {'index': '90', 'name': 'Etheera', 'marketvalue': 'R$ 142.486.317', 'pricers': 'R$ 0,02', 'pricebtc': 'BTC 0.00000169', 'total': 'R$ 3.339', 'variation': '8.249,65 %'}
# ---------------
# {'index': '100', 'name': 'BOScoin', 'marketvalue': 'R$ 139.061.003', 'pricers': 'R$ 0,30', 'pricebtc': 'BTC 0.00001893', 'total': 'R$ 135.289', 'variation': '1,72 %'}
# ---------------
# {'index': '100', 'name': 'OneRoot Network', 'marketvalue': 'R$ 135.806.768', 'pricers': 'R$ 0,49', 'pricebtc': 'BTC 0.00003414', 'total': 'R$ 21.795.806', 'variation': '2,64 %'}
# ---------------
# {'index': '100', 'name': 'Dropil', 'marketvalue': 'R$ 135.729.596', 'pricers': 'R$ 0,01', 'pricebtc': 'BTC 0.00000038', 'total': 'R$ 1.130.144', 'variation': '-9,12 %'}
# ---------------
# {'index': '100', 'name': 'Quant', 'marketvalue': 'R$ 135.383.840', 'pricers': 'R$ 13,85', 'pricebtc': 'BTC 0.00091286', 'total': 'R$ 8.208.765', 'variation': '-6,38 %'}
# ---------------
# {'index': '98', 'name': 'Melon', 'marketvalue': 'R$ 134.862.883', 'pricers': 'R$ 165,98', 'pricebtc': 'BTC 0.01106680', 'total': 'R$ 33.695', 'variation': '434,90 %'}
# ---------------
# {'index': '100', 'name': 'STASIS EURS', 'marketvalue': 'R$ 133.722.962', 'pricers': 'R$ 4,32', 'pricebtc': 'BTC 0.00028831', 'total': 'R$ 1.932.272', 'variation': '-0,09 %'}
# ---------------
# {'index': '100', 'name': 'ProximaX', 'marketvalue': 'R$ 133.297.684', 'pricers': 'R$ 0,02', 'pricebtc': 'BTC 0.00000139', 'total': 'R$ 7.425.847', 'variation': '0,32 %'}
# ---------------
# {'index': '100', 'name': 'Endor Protocol', 'marketvalue': 'R$ 132.261.179', 'pricers': 'R$ 0,19', 'pricebtc': 'BTC 0.00001255', 'total': 'R$ 92.668.092', 'variation': '-6,14 %'}
# ---------------
# {'index': '100', 'name': 'Mithril', 'marketvalue': 'R$ 131.530.312', 'pricers': 'R$ 0,27', 'pricebtc': 'BTC 0.00001804', 'total': 'R$ 15.829.212', 'variation': '-0,88 %'}
# ---------------
# {'index': '100', 'name': 'XYO Network', 'marketvalue': 'R$ 130.248.548', 'pricers': 'R$ 0,02', 'pricebtc': 'BTC 0.00000157', 'total': 'R$ 552.311', 'variation': '19,50 %'}
# ---------------
# {'index': '100', 'name': 'Apollo Currency', 'marketvalue': 'R$ 128.265.961', 'pricers': 'R$ 0,01', 'pricebtc': 'BTC 0.00000064', 'total': 'R$ 6.524.475', 'variation': '17,55 %'}
# ---------------
# {'index': '86', 'name': 'Unobtanium', 'marketvalue': 'R$ 127.408.721', 'pricers': 'R$ 637,43', 'pricebtc': 'BTC 0.04955135', 'total': 'R$ 237.685', 'variation': '139,73 %'}
# ---------------
# {'index': '100', 'name': 'FunFair', 'marketvalue': 'R$ 126.620.163', 'pricers': 'R$ 0,02', 'pricebtc': 'BTC 0.00000170', 'total': 'R$ 12.374.495', 'variation': '30,81 %'}
# ---------------
# {'index': '100', 'name': 'Centrality', 'marketvalue': 'R$ 126.274.245', 'pricers': 'R$ 0,16', 'pricebtc': 'BTC 0.00001088', 'total': 'R$ 15.732', 'variation': '0,28 %'}
# ---------------
# {'index': '100', 'name': 'TomoChain', 'marketvalue': 'R$ 124.751.095', 'pricers': 'R$ 2,11', 'pricebtc': 'BTC 0.00014640', 'total': 'R$ 500.945', 'variation': '-7,36 %'}
# ---------------
# {'index': '99', 'name': 'Radium', 'marketvalue': 'R$ 123.879.947', 'pricers': 'R$ 34,78', 'pricebtc': 'BTC 0.00236600', 'total': 'R$ 26.432', 'variation': '1.239,78 %'}
# ---------------
# {'index': '99', 'name': 'Timicoin', 'marketvalue': 'R$ 123.425.361', 'pricers': 'R$ 0,39', 'pricebtc': 'BTC 0.00002653', 'total': 'R$ 143.618', 'variation': '563,53 %'}
# ---------------
# {'index': '100', 'name': 'Moss Coin', 'marketvalue': 'R$ 122.988.642', 'pricers': 'R$ 0,53', 'pricebtc': 'BTC 0.00003621', 'total': 'R$ 88.995.910', 'variation': '232,76 %'}
# ---------------
# {'index': '100', 'name': 'Optimal Shelf Availability Token', 'marketvalue': 'R$ 121.457.766', 'pricers': 'R$ 0,14', 'pricebtc': 'BTC 0.00001026', 'total': 'R$ 4.974.501', 'variation': '-17,52 %'}
# ---------------
# {'index': '85', 'name': 'GXChain', 'marketvalue': 'R$ 120.452.639', 'pricers': 'R$ 2,01', 'pricebtc': 'BTC 0.00015723', 'total': 'R$ 6.217.079', 'variation': '1,96 %'}
# ---------------
# {'index': '99', 'name': 'Bitcoiin', 'marketvalue': 'R$ 119.120.605', 'pricers': 'R$ 2,41', 'pricebtc': 'BTC 0.00017619', 'total': 'R$ 3.154.140', 'variation': '-2,05 %'}
# ---------------
# {'index': '100', 'name': 'Particl', 'marketvalue': 'R$ 118.351.022', 'pricers': 'R$ 14,67', 'pricebtc': 'BTC 0.00107796', 'total': 'R$ 3.381.567', 'variation': '52,35 %'}
# ---------------
# {'index': '100', 'name': 'QuarkChain', 'marketvalue': 'R$ 115.788.476', 'pricers': 'R$ 0,14', 'pricebtc': 'BTC 0.00001074', 'total': 'R$ 211.960.323', 'variation': '3,88 %'}
# ---------------
# {'index': '100', 'name': 'Gas', 'marketvalue': 'R$ 115.616.395', 'pricers': 'R$ 11,42', 'pricebtc': 'BTC 0.00085202', 'total': 'R$ 158.352.083', 'variation': '43,13 %'}
# ---------------
# {'index': '100', 'name': 'Nxt', 'marketvalue': 'R$ 114.048.561', 'pricers': 'R$ 0,11', 'pricebtc': 'BTC 0.00000847', 'total': 'R$ 1.742.493', 'variation': '-1,29 %'}
# ---------------
# {'index': '100', 'name': 'Bitcoin Private', 'marketvalue': 'R$ 113.697.333', 'pricers': 'R$ 5,54', 'pricebtc': 'BTC 0.00040848', 'total': 'R$ 355.829', 'variation': '-1,79 %'}
# ---------------
# {'index': '100', 'name': 'Dentacoin', 'marketvalue': 'R$ 112.019.399', 'pricers': 'R$ 0,00', 'pricebtc': 'BTC 0.00000003', 'total': 'R$ 922.081', 'variation': '-12,57 %'}
# ---------------
# {'index': '100', 'name': 'Vertcoin', 'marketvalue': 'R$ 111.763.723', 'pricers': 'R$ 2,32', 'pricebtc': 'BTC 0.00017246', 'total': 'R$ 85.378.004', 'variation': '120,60 %'}
# ---------------
# {'index': '99', 'name': 'Breezecoin', 'marketvalue': 'R$ 109.946.820', 'pricers': 'R$ 2,80', 'pricebtc': 'BTC 0.00021978', 'total': 'R$ 43.041', 'variation': '242,05 %'}
# ---------------
# {'index': '100', 'name': 'MobileGo', 'marketvalue': 'R$ 104.598.807', 'pricers': 'R$ 1,05', 'pricebtc': 'BTC 0.00008313', 'total': 'R$ 32.146.255', 'variation': '-2,38 %'}
# ---------------
